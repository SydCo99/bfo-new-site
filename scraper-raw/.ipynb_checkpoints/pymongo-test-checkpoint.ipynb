# %%
import requests
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import time
import re

# %%
def striphtml(data):
    p = re.compile(r'<.*?>')
    return p.sub('', data)

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
url = "https://philpapers.org/browse/top-level-ontologies?limit=50&newWindow=&publishedOnly=&freeOnly=&catq=barry+smith&hideAbstracts=&langFilter=&filterByAreas=&sqc=&proOnly=on&uncat=&cn=top-level-ontologies&onlineOnly=&cId=492826&categorizerOn=&new=1&start=0&setAside=&sort=pubYear&showCategories=on&format=html&jlist=&ap_c1=&ap_c2="

# %%
browser.visit(url)

# %%
time.sleep(1)

# %%
html = browser.html

# %%
soup = BeautifulSoup(html, "html.parser")

# %%
full_citation_list = soup.find_all("span", class_="citation")

# %%
html = []  
for i in range(len(full_citation_list)):
    html.append(full_citation_list[i])

# %%
author_full = []
titles = []
pub_date = []
pub_info = []
links = []
authors = []
titles_full = []
pub_info_full = []

for entry in html: 
        author_full.append(entry.find_all("span", class_="name"))
        titles_full.append(entry.find("span", class_="articleTitle").text)
        pub_date.append(entry.find("span", class_="pubYear").text)
        pub_info_full.append(entry.find("span", class_="pubInfo").text)
        link = entry.find("a", href=True)
        links.append("https://philpapers.org" + link["href"])

# %%
for i in range(len(pub_info_full)): 
    line = pub_info_full[i]
    line = line.replace('.','')
    pub_info.append(line)
    i += 1
for i in range(len(titles_full)): 
    line = titles_full[i]
    line = line.replace('.','')
    titles.append(line)
    i += 1

author_full = list(map(str, author_full))
for i in range(len(author_full)): 
    line = striphtml(author_full[i])
    #line = line.replace(', ', ',')
    line = line.replace(' ]', ']')

    authors.append(line)
    i += 1

for i in range(len(authors)):
    authors[i] = authors[i].strip('][').split(',')

# %%
phil_authors = []
phil_titles = []
phil_pub_date = []
phil_pub_info = []
phil_links = []

# %%
phil_authors = authors
phil_titles = titles 
phil_pub_date = pub_date 
phil_pub_info = pub_info 
phil_links = links

# %%
browser.quit()

# %%
time.sleep(1)

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = "https://www.scilit.net/articles/search?facets__language%5B0%5D=English&highlight=1&q=%22basic%20formal%20ontology%22&sort=Newest&nb_articles=500"

# %%
browser.visit(url)

# %%
time.sleep(1)

# %%
html = browser.html

# %%
soup = BeautifulSoup(html, "html.parser")

# %%
full_citation_list = soup.find_all("div", class_="result")

# %%
html = []  
for i in range(len(full_citation_list)):
    html.append(full_citation_list[i])

# %%
authors = []
titles = []
titles_full = []
pub_date = []
pub_info = []
links = []
author_full = []
pub_date_full = []
pub_info_full = []
links_full = []

# %%
for entry in html: 
    author_full.append(entry.find_all("div", class_="authors"))
    titles_full.append(entry.find("div", class_="title").text)
    pub_date_full.append(entry.find("div", class_="pubdate").text)
    pub_info_full.append(entry.find("div", class_="publisher"))
    #links.append(entry.find("div", class_="doilink"))
    link = entry.find("a", href=True)
    links_full.append(link)

# %%
author_full
# Out:
# ['[<div class="authors">\nMichael Cullen Halvorson, Noah Moyers, I. Dale Thomas </div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/232233" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Yongqun He</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/RU56dmNZOUQ5M0lIendtZ2ZkdFViNDFUaUFNcmlIR1lLL1FWempSQ2xJRT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Hong Yu</span></a></div>\n, Anthony Huffman, Asiyah Yu Lin, Darren A. Natale, John Beverley, Ling Zheng, Yehoshua Perl, Zhigang Wang, Yingtong Liu, Edison Ong, Yang Wang, Philip Huang, Long Tran, Jinyang Du, Zalan Shah, Easheta Shah, Roshan Desai, Hsin-Hui Huang, Yujia Tian, et al.\n</div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/S1BlK3pmeUdVZmk3cGViQlI5L3o0V2JacmVaOUhWeFdyYzdXWXRJNy9qMD0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Lidiia Vlasenko</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/clhIanVSYW1RTGhHenJEc2o4bTVrWlhaK1FXZ2VLUUd6L2tmVU1VSkZ2QT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Nataliia Lutska</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/RjkvU1hUQXBUUW4zVjVVeU15NSt5QT09" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Nataliia Zaiets</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/1018024" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Igor Korobiichuk</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/2490080" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Serhii Hrybkov</span></a></div>\n</div>]',
#  '[<div class="authors">\nPatricia Romao, Stefanie Neuenschwander, Chantal Zbinden, Kathleen Seidel,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/1729794" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Murat Sariyar</span></a></div>\n</div>]',
#  '[<div class="authors">\nSachiko Lim,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/ZDJlMFQ1TWJmTVNEdU9UYW9PV0x0UT09" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Paul Johansson</span></a></div>\n</div>]',
#  '[<div class="authors">\nEdward Louis, Ryan Colletti, Mohammad Hussain, Gregory Mocko, Chris Paredis </div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/MTh3WHh4SklkQjhLYytIdDdzTTgvWDBOM2dDZHptQUFpS25kbzQ0NWtsbz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Farhad Ameri</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/U0RVeWJTbmdydkYwNEsrY0tQV29Fdlg0eVB3MmRZZjA2RTVMbVZOUldnTT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Evan Wallace</span></a></div>\n, Reid Yoder,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/UHpXWk5HSjNFbWJySHNsN3F1RXhncEZNTHQyTmVKdG1CeUFSazRab0hQTT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Frank Riddick</span></a></div>\n</div>]',
#  '[<div class="authors">\nJ. Neil Otte, John Beverley, Alan Ruttenberg </div>]',
#  '[<div class="authors">\nMeng Liu, Jialin Liu, Guitian Liu, Hui Wang, Xiaoli Wang,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/1858947" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Zixin Deng</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/232233" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Yongqun He</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/RXZNQkUvbC9KcFk4bVdvQm9DaWdnTTJtYnVULzNLUERVRnAyRjdrdVNpaz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Hong-Yu Ou</span></a></div>\n</div>]',
#  '[<div class="authors">\nAstghik Sargsyan,\nPhilipp Wegner,\nStephan Gebel,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/YUNFYWlncW1LSW4ybk5UellVbk5JcmxPREJ0TlFScGJWUG5UKy81VVRXdFNoU2pYTitadStXcXhLK2lpdXdDVw==" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Shounak Baksi</span></a></div>\n, Geena Mariya Jose,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/eWE4clJORVVRZWMwQUJJVmlqSUpMcXU5K2RURFpHbndoRzRDRVNXQkpHTHg1MUs1SWtJUFFVR2g2cFhCaXlLMA==" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Vanessa Lange-Rupprecht</span></a></div>\n, Johannes Darms,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/bFJUQmNCY3VSR3A2NlBZbGIrM04yNnZPN3lwV2cwbjlXOWhodGRZTVFndjNaWHNoWlh4SXMxOVZvQnkzQW5ZRg==" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Bruce Schultz</span></a></div>\n, Jürgen Klein,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/2259015" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Marc Jacobs</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/ckFWZThWYlY2OHRMVmFZdFI4ZHNFQ0hhSzdVMkorT1V5VzZnYkpFVGE2WT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Philippe Ryvlin</span></a></div>\n, Sumit Madan,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/138945" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Martin Hofmann-Apitius</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/140734" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Alpha Tom Kodamullil</span></a></div>\n</div>]',
#  '[<div class="authors">\nStefanie Neuenschwander, Patricia Romao, Jürgen Holm, Murat Sariyar </div>]',
#  '[<div class="authors">\nFumiaki Toyoshima, Adrien Barton, Ludger Jansen, Jean-François Ethier </div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/569143" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Caterina Pietra</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/232749" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Roberto De Lotto</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/1961213" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="https://sciprofiles.com/profiles/1961213/thumb/5x5.jpg" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Rakan Bahshwan</span></a></div>\n</div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/Ri9KQTZiS3Roay91Qmw3V1podVBhRUxUQTFjbTBVWTZ3bCtxNlJ6Rmdydz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Fernando Cicconeto</span></a></div>\n, Lucas Valadares Vieira, Mara Abel,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/1570743" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Renata Dos Santos Alvarenga</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/SVdCRUNnZzU5RllQUE55RHJ6eE9hdkEvYzh0VmhURDdJQXRSZ3ZhbURvMD0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Joel Luis Carbonera</span></a></div>\n, Luan Fonseca Garcia </div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/dkNnY1ArNW4vTERYemxKeXBFZWF6cGtSeXhXV3pjT2trUTRIM1N5cytVUT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Juan José Montero Jiménez</span></a></div>\n, Rob Vingerhoeds, Bernard Grabot, Sébastien Schwartz </div>]',
#  '[<div class="authors">\nJustine Flore Tchouanguem, Mohamed Hedi Karray, Bernard Kamsu Foguem, Camille Magniont, F. Henry Abanda, Barry Smith </div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/1802147" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Linda Elmhadhbi</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/1854795" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="https://sciprofiles.com/profiles/1854795/thumb/Karray_Profile_photo.jpg" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Mohamed-Hedi Karray</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/QmYwcGFheWFxRzU0dE1LdUl2SzdMWTNHaGZublhhUnN5TlJTZ1p4L0RLST0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Bernard Archimède</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/blpNU3dEWDVBV1dhdlJVL3lKYUFGZmN3MTc3NE5PS0Zzdm1INUlQOGg2MD0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">J. Neil Otte</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/YlNrOXYrSlc2WlV2T01aaVE1RGNDZGIwSi8xRU5yL2lxSDhmTFRCalk0ST0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Barry Smith</span></a></div>\n</div>]',
#  '[<div class="authors">\nRosario Davide D’Amico, Pavan Addepalli, John Ahmet Erkoyuncu </div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/467814" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Yan Zhu</span></a></div>\n, Lihong Liu, Bo Gao, Jing Liu, Xingchao Qiao,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/MmwwZUJQZkZnRG1URzBOWmdkOU02Ryt0YVQ4bXNnZmIvbzVtbkZHb1RkQT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Chaojie Lian</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/MmlPZnU4UDRTNzNtWnBCZ0p0cy8xcnV0aEw5U01OU004S0RIQmZFbTNPUT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Yongqun He</span></a></div>\n</div>]',
#  '[<div class="authors">\nLing Wan, Justin Song, Virginia He, Jennifer Roman, Grace Whah, Suyuan Peng, Luxia Zhang,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/232233" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Yongqun He</span></a></div>\n</div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/OXRUaHhmK0h5UEx4a0toeDF5eHpVREl5eHJ2eGFaQnJKc294OFBteDA4MD0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Saoussen Dimassi</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/918981" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Frédéric Demoly</span></a></div>\n, Christophe Cruz, H. Jerry Qi, Kyoung-Yun Kim, Jean-Claude André,\nSamuel Gomes </div>]',
#  '[<div class="authors">\nNora Shoaip,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/2015783" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Amira Rezk</span></a></div>\n, Shaker El-Sappagh,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/1054246" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="https://sciprofiles.com/profiles/1054246/thumb/louai.jpg" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Louai Alarabi</span></a></div>\n, Sherif Barakat,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/d3o4TmFpMlRQZFNTSTFRcmZwUEZMc3l6UlF0U04zb0RGRVIvTytINXlac1krbTdCRUpndXR6TW9QWnpMR3YvNw==" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Mohammed M. Elmogy</span></a></div>\n</div>]',
#  '[<div class="authors">\nM. N. Roelofs, Roelof Vos </div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/Vmx2TDVCcnN1MEdwNWQ4RCthVi9PcEZwTzNOWVBSbEFhd2xSbGY4Q1JXUT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Janna Hastings</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/709831" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Sharon Cox</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/ZnRJUEh1MDZSdVZrV0ZscGhJWTh3S0haMWJWa3pKQnNvS3hrNzZZV3dYQT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Robert West</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/303715" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Caitlin Notley</span></a></div>\n</div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/TmpMYkFBR1NaZEhFRzVJUy91VlkwYzNWZ2I1OExLbkF0ZEJDWU4wTFVDbz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Jorge Lázaro</span></a></div>\n, Hazel Barahona Gamboa, Gerardo Sierra Martínez </div>]',
#  '[<div class="authors">\nMunira Mohd Ali, Ruoyu Yang, Binbin Zhang, Francesco Furini,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/MDhIUUxXMWFvYi9ZcWhIeno0VXdWWkRNUHBMYi9YMHRMbTBUTjh2U2tmVT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Rahul Rai</span></a></div>\n, J. Neil Otte, Barry Smith </div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/alY0RjEyM0NIQm52aFFFUk5PRmVpWkNLVXhxQmE2ZHN4Q0hCYVV1M05waz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Felipe Carvalho Pellison</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/QWdxazdoVG1hYmpocGNoNmdBWE1jZ3ZoM24ySUNYbC9zc0paeDhLSE1Ucz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Rui Pedro Charters Lopes Rijo</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/Zkh0bk9jb204czd6b25NdEs2d0Z1Y3VJUlVuNmRIYWFCNXU5SElXZlNDTT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Vinicius Costa Lima</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/OUJOZXhTdHJybnozald5d1NNMHpBMEN6eW1rZU9ZWUhEWUZYR0huVzJSQT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Nathalia Yukie Crepaldi</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/UGlRSkI2Q1FWRCtCUjQ5Rm1aQlFNVTBlekhtZlB4Um9oZE05UE9mNWhvTT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Filipe Andrade Bernardi</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/bkVlSnBvTUkrTk1QN3FWVjI1U3FCQ2x6bW40YjExT1ZjTmdvcjAyemRvTT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Rafael Mello Galliez</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/dUJ4Tmw5Y3pSYUY0SWwyYTF2cy9Rd1N3ajM3ZlJ2Vno2cG9EbGtZS3BKcz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Afrânio Kritski</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/2550713" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Kumar Abhishek</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/dk5MdjR6aHh6Z1NOemt6bzhGTFNPVFBmNVN2TytXSElqNEt0UDN2VVh6Zz0=" rel="noopener noreferrer" target="_blank"><img class="scip ...
#  '[<div class="authors">\nAdolfo Americano Brandão, Geilson Loureiro </div>]',
#  '[<div class="authors">\nBalanand Jha,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/2550713" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Kumar Abhishek</span></a></div>\n, Akshay Deepak, Shubhnkar Upadhyay, Avadhesh Singh </div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/232233" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Yongqun He</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/R1gxWWhyN1VBNVpyYjFQaGprUXE0MEtPR1JJN2phSlY2V3JMQXRrckRSND0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Haihe Wang</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/OXdyODljcVYrODNKTXFENHM2NVdVZmJzZGVUdkNsbloxOGkxMk1WREx3OD0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Jie Zheng</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/aWcrUFpCR3NoaGVpNVl2Mm1oTDd4ZzBZTHJ4QVJWSStqRGMxZWtzSkRWcz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Daniel P. Beiting</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/MEd5YWRDRFY5Y0syN25oS0RQNlVYRTVLNlBWV0dUcm9taXdmVVdoNFJzMD0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Anna Maria Masci</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/RU56dmNZOUQ5M0lIendtZ2ZkdFViNDFUaUFNcmlIR1lLL1FWempSQ2xJRT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Hong Yu</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/TU41dUJDdU80cEphd2lHRmxFZlVRcXNPVDdBbEQ4a1IxT1R1RmVvSkJNZz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Kaiyong Liu</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/Q2FUbk5RVzNPUHI3eTFsRFJNbVErTDZHNEk1VDlaRnNOMEJ6NCtlYnFEND0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Jianmin Wu</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/WWdxK0YvdVMySWJtY1BDVGJKbmJSU2NjSVB6bUpMNDdqRjZKNUxpZ05PTT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" s ...
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/alY0RjEyM0NIQm52aFFFUk5PRmVpWkNLVXhxQmE2ZHN4Q0hCYVV1M05waz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Felipe Carvalho Pellison</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/QWdxazdoVG1hYmpocGNoNmdBWE1jZ3ZoM24ySUNYbC9zc0paeDhLSE1Ucz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Rui Pedro Charters Lopes Rijo</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/Zkh0bk9jb204czd6b25NdEs2d0Z1Y3VJUlVuNmRIYWFCNXU5SElXZlNDTT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Vinicius Costa Lima</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/OUJOZXhTdHJybnozald5d1NNMHpBMEN6eW1rZU9ZWUhEWUZYR0huVzJSQT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Nathalia Yukie Crepaldi</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/UGlRSkI2Q1FWRCtCUjQ5Rm1aQlFNVTBlekhtZlB4Um9oZE05UE9mNWhvTT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Filipe Andrade Bernardi</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/bkVlSnBvTUkrTk1QN3FWVjI1U3FCQ2x6bW40YjExT1ZjTmdvcjAyemRvTT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Rafael Mello Galliez</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/dUJ4Tmw5Y3pSYUY0SWwyYTF2cy9Rd1N3ajM3ZlJ2Vno2cG9EbGtZS3BKcz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Afrânio Kritski</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/2550713" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Kumar Abhishek</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/dk5MdjR6aHh6Z1NOemt6bzhGTFNPVFBmNVN2TytXSElqNEt0UDN2VVh6Zz0=" rel="noopener noreferrer" target="_blank"><img class="scip ...
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/467999" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Andrew Iliadis</span></a></div>\n</div>]',
#  '[<div class="authors">\nAaron Sterling </div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/SXh2OEdsRDRjQmJmUFI2VVVvQUxiQnVrSmFFV3dvd1ZKYkducFVHTkEzbz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Hyunmin Cheong</span></a></div>\n, Adrian Butscher </div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/727080" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Richard de Rozario</span></a></div>\n</div>]',
#  '[<div class="authors">\nStanley Blum,\nKatharine Barker,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/blVZRUIzYVZrSzJSMGVGbm9FUkhPUGIrSlJ5OXhQMG5nOEtJbnlZNjFOUT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Steven J Baskauf</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/UjU0Zmt0NkxmdC9iTHlHeE9QTmN6d0gzY2JuQnZLVVlvQnpud0g0YU1OST0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Walter G. Berendsohn</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/Yy82U0xVa2VVTDJNeGxHYzBUeFZBWEZVdmhDNUdqdDgwRW5XZzNGdmJ5ND0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Pier Luigi Buttigieg</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/OEdpaDFQcGQ3cVJ2SkVFMDRacjNrdjVjU0p2aFN0ZDk3eElBR0wwTkFhYz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Markus Döring</span></a></div>\n, Gabriele Droege,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/TmdCMjAzQTY2N2hjUXBySG52SnV0NFAvSnk2bXptUnpsbm1LWElXWXN3QT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">David Fichtmueller</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/N09LL2R1MWlUY3QxQURCY1cxb0JrYTF6Z2V1TUpCaTNmWjB6eHFJRUtVVT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Falko Glöckler</span></a></div>\n,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/Z1RSdFZxSGJNckRBbUcrT2ljSTVzWUFOakxIWXFTOTR1dkFkaUZ3a1pZcz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Anton Güntsch</span></a></div>\n, Robert Guralnick,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/WjlBam9HSENnMCtobUZhWUNKdDB5QnJKU0xHZjZDZVh0bTlXNHpNT0d0ST0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Jana Hoffmann</span></a></div>\n, Niels Klazenga,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/NzdCcUlPNitJcVB ...
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/b0M3VHJnZ0xSSUdPM3hpSDhWdnNFei8rNi9wSDczcmVOeHU4eWJLZW9lMD0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Thomas J. Hagedorn</span></a></div>\n, Barry Smith, Sundar Krishnamurty, Ian Grosse </div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/RUFoMHlVd1ZtVk5mTHRIUWg5aVhFdFh1ZlRhTFI4Ly9PS0UzK0NWWFJSMD0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Douglas Orellana</span></a></div>\n, William Mandrick </div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/Q1NxaG5RUGx1MG1UWC8zZDN6UTRMWXBUcUMxWlFnOHRYeHBCRnl0cFVIST0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Barry Smith</span></a></div>\n</div>]',
#  '[<div class="authors">\nShaker El-Sappagh, Farman Ali, AbdelTawab Hendawi, Jun-Hyeog Jang,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/86237" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Kyung-Sup Kwak</span></a></div>\n</div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/1802147" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Linda Elmhadhbi</span></a></div>\n, Mohamed-Hedi Karray, Bernard Archimède </div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/aHY2ZUJubkFOSzVYWXBaNDNyZXBIMXJ3WlpIY1RYenJMazI2MWZrbEoxOD0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Jobst Landgrebe</span></a></div>\n, Barry Smith </div>]',
#  '[<div class="authors">\nAndrew Iliadis </div>]',
#  '[<div class="authors">\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/VzZ1aHZaalRMcGdaN3lLcFhXUVdHU2RMTDlDSW85SzFESGc1dkdTbEE0QT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Lars Vogt</span></a></div>\n</div>]',
#  '[<div class="authors">\nArkopaul Sarkar,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/ak5ENERmekRjT2xlTFNyWlUrUkppQT09" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Dušan Šormaz</span></a></div>\n</div>]',
#  '[<div class="authors">\nArkopaul Sarkar,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/ak5ENERmekRjT2xlTFNyWlUrUkppQT09" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Dušan Šormaz</span></a></div>\n</div>]',
#  '[<div class="authors">\nAaron Sterling </div>]',
#  '[<div class="authors">\nLinda Elmhadhbi,\n<div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/1854795" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="https://sciprofiles.com/profiles/1854795/thumb/Karray_Profile_photo.jpg" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Mohamed-Hedi Karray</span></a></div>\n, Bernard Archimède </div>]',
#  '[<div class="authors">\nQing Zou, Eun G. Park </div>]',
# ...
#   ,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/U01Rb1MvcnJzSEd4NnhaM3B1NjlHQT09" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Brian D. Athey</span></a></div>
#   ,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/QjAzSEh6OXlkNkltVnNPSi9kNHJKVSt5aDFueXFDWFF6MjRyUHRWZG9aVEdsaHFlSFY5eGN2NjdpcWtWSkZKUw==" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Lindsay Cowell</span></a></div>
#   ,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/eUpCb2d6K1NNditKSGhDUEczU0dqZnZvNjNWNXZMWlpvclZUSDJKTjRZdz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Gilbert S. Omenn</span></a></div>
#   ,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/TFFFcGVXNVN0SWlkYkhXNFlqdWtKSVVESFlPaWRWbTJTbDdnUEdYNjVWMD0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Alexander D. Diehl</span></a></div>
#   , Barry Smith, Harry Mobley,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/WG81M3hCVFg4b2JDekd2OFltN05KcVQ0ZlRqNXdUSWZwc2tydHR2K0ZBQT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Zuoshuang Xiang</span></a></div>
#   ,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/dHZzaTRKL2FOUjdDeTF3bEpjR2lWalVnL3AvbFdSMmY5SDFnQ3ExZzNJMD0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Bjoern Peters</span></a></div>
#   ,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/a3hsbGM5aGJ1MUVORVVkc0EwRHM1WXJCRHRvbU1JamtaRnAxVW4rSE1YZz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Alan Ruttenberg</span></a></div>
#   </div>],
#  [<div class="authors">
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/dzhQU2FERkx0dXVYQ1ZLTGNGWnYwdz09" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Eric G. Little</span></a></div>
#   , Galina L. Rogova </div>],
#  [<div class="authors">
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/dERJOFNNTHZ0TnVOd0ZUZEdpbEJYdUJUQVZ6V2psMDdKNHpiZHJ3eVV5RT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Werner Ceusters</span></a></div>
#   , Maria Capolupo,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/Q1NxaG5RUGx1MG1UWC8zZDN6UTRMWXBUcUMxWlFnOHRYeHBCRnl0cFVIST0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Barry Smith</span></a></div>
#   , Georges De Moor </div>],
#  [<div class="authors">
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/bWJJZ05ZQVNTZGw5a2QzcTFiUUYxT0EwZ2xKdW9NMndFMTNFZ3JsS1R0MGdHemdHdURSN2wycndCNEJzUmprQQ==" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">M. Boeker</span></a></div>
#   ,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/MUFpTFYweC95VGUyODZVUUt5dDFsMktCMGZDTWhIOXdFOFJzcXQwbGlqV2tDVDRjbFZZRzBGQWJHNkRyaGVSMA==" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">H. Stenzhorn</span></a></div>
#   , J. Niggemann,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/dTNvTUZTbm5EODdYQjB0SzFTMlpXKy9KT1p1TXZPOVBHQlg2dTN1VUFnbz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">S. Schulz</span></a></div>
#   </div>],
#  [<div class="authors">
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/eDhBMUJYUXBueHoyMVdSc0ZmMlFYYUdvT05rbjFRRFVJSytESlBGZERBZz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">William Hogan</span></a></div>
#   </div>],
#  [<div class="authors">
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/NzRkNXZDMkw5NzgyN2Jlb3Q2a1BKaDBYeFdEWlJSMEVOZXpPV1RqcW1zdz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Robert Arp</span></a></div>
#   ,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/Q1NxaG5RUGx1MG1UWC8zZDN6UTRMWXBUcUMxWlFnOHRYeHBCRnl0cFVIST0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Barry Smith</span></a></div>
#   </div>],
#  [<div class="authors">
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/dTNvTUZTbm5EODdYQjB0SzFTMlpXKy9KT1p1TXZPOVBHQlg2dTN1VUFnbz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Stefan Schulz</span></a></div>
#   ,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/bWJJZ05ZQVNTZGw5a2QzcTFiUUYxT0EwZ2xKdW9NMndFMTNFZ3JsS1R0MGdHemdHdURSN2wycndCNEJzUmprQQ==" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Martin Boeker</span></a></div>
#   ,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/MUFpTFYweC95VGUyODZVUUt5dDFsMktCMGZDTWhIOXdFOFJzcXQwbGlqV2tDVDRjbFZZRzBGQWJHNkRyaGVSMA==" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Holger Stenzhorn</span></a></div>
#   </div>],
#  [<div class="authors">
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/dERJOFNNTHZ0TnVOd0ZUZEdpbEJYdUJUQVZ6V2psMDdKNHpiZHJ3eVV5RT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Werner Ceusters</span></a></div>
#   , Peter Elkin,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/Q1NxaG5RUGx1MG1UWC8zZDN6UTRMWXBUcUMxWlFnOHRYeHBCRnl0cFVIST0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Barry Smith</span></a></div>
#   </div>],
#  [<div class="authors">
#   Amarnath Gupta,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/N1prZHpSL2lUUi85Q3Z6WFhIeDdiZVp6dGZ4VzlJSTFEeVdBZ25aRkZFWT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Stephen D. Larson</span></a></div>
#   ,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/U2tJUHREOUUwcWd4aUU1SlFsd1Z0dz09" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Christopher Condit</span></a></div>
#   , Sandeep Gupta,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/SE1vK1lLa1NjOU1GR1NvWEVVL1lKR2lZd2Z1Sk5VWHJSKzhUY090YjFKOD0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Lisa Fong</span></a></div>
#   ,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/RS9KMmVFM2EyVzQ4cWJzbzZRaUNGUT09" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Li Chen</span></a></div>
#   ,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/UjZHUGwvVWt4MDQ4bm85YVBtOFluTWFHU1E3T05RR2ROUndNS3RKWUlXWT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Maryann E. Martone</span></a></div>
#   </div>],
#  [<div class="authors">
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/dERJOFNNTHZ0TnVOd0ZUZEdpbEJYdUJUQVZ6V2psMDdKNHpiZHJ3eVV5RT0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Werner Ceusters</span></a></div>
#   ,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/Q1NxaG5RUGx1MG1UWC8zZDN6UTRMWXBUcUMxWlFnOHRYeHBCRnl0cFVIST0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Barry Smith</span></a></div>
#   </div>],
#  [<div class="authors">
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/RWFGRzQ5eFI5VCtJOWx4RWF2VVlVZTVxMmZ3angyejFiV0RTZzdUcDh1WmxORC9TU1ExQW5wdDZMQ3ppYW1vUw==" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Jonathan Simon</span></a></div>
#   , Mariana Dos Santos, James Fielding,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/Q1NxaG5RUGx1MG1UWC8zZDN6UTRMWXBUcUMxWlFnOHRYeHBCRnl0cFVIST0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Barry Smith</span></a></div>
#   </div>],
#  [<div class="authors">
#   Werner Ceusters, Barry Smith </div>],
#  [<div class="authors">
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/426754" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">John Bateman</span></a></div>
#   ,
#   <div class="sciprofiles-link" style="display: inline-block"><a class="sciprofiles-link__link" href="https://sciprofiles.com/profile/author/a3B3YlBPcXF1Z1NpSndXVGo1NXFoRFpDeHFZbllFMS84SmRSaWJKTzRuaz0=" rel="noopener noreferrer" target="_blank"><img class="sciprofiles-link__image" src="/bundles/mdpisciprofileslink/img/unknown-user.png" style="width: auto; height: 16px; border-radius: 50%;"/><span class="sciprofiles-link__name">Scott Farrar</span></a></div>
#   </div>],
#  [],
#  [<div class="authors">
#   Frank Oemig, Bernd Blobel </div>],
#  [<div class="authors">
#   Felix Gantner, Bettina Waldvogel, Rolf Meile, Patrick Laube </div>]]

# %%
for i in range(len(links_full)):
        link = links_full[i]["href"]
        links.append("https://www.scilit.net"+ link)
        i =+ 1

# %%
pub_info_full = list(map(str, pub_info_full))
for i in range(len(pub_info_full)):
    line = striphtml(pub_info_full[i])
    line = line.replace('by\n', '')
    line = line.replace('\n', '')
    pub_info.append(line)
    i += 1

# %%
for i in range(len(pub_date_full)):
    line = pub_date_full[i]
    line = line.replace('Published: ', '')
    line = line[-4:]
    pub_date.append(line)
    i += 1

for i in range(len(titles_full)):
    line = titles_full[i]
    line = line.replace('\n', '')
    titles.append(line)
    i += 1
author_full = list(map(str, author_full))
for i in range(len(author_full)): 
    line = striphtml(author_full[i])
    line = line.replace('\n', '')
    #line = line.replace(', ', ',')
    line = line.replace(' ]', ']')

    authors.append(line)
    i += 1

# %%
pub_date_full
# Out:
# ['Published: 28 October 2022',
#  'Published: 21 October 2022',
#  'Published: 9 October 2022',
#  'Published: 8 September 2022',
#  'Published: 23 July 2022',
#  'Published: 29 March 2022',
#  'Published: 25 March 2022',
#  'Published: 15 March 2022',
#  'Published: 20 January 2022',
#  'Published: 14 January 2022',
#  'Published: 14 January 2022',
#  'Published: 23 December 2021',
#  'Published: 15 December 2021',
#  'Published: 4 December 2021',
#  'Published: 29 November 2021',
#  'Published: 28 October 2021',
#  'Published: 19 October 2021',
#  'Published: 18 October 2021',
#  'Published: 23 September 2021',
#  'Published: 1 June 2021',
#  'Published: 16 January 2021',
#  'Published: 31 December 2020',
#  'Published: 22 December 2020',
#  'Published: 7 December 2020',
#  'Published: 20 November 2020',
#  'Published: 10 July 2020',
#  'Published: 6 July 2020',
#  'Published: 8 April 2020',
#  'Published: 1 January 2020',
#  'Published: 30 December 2019',
#  'Published: 24 November 2019',
#  'Published: 14 October 2019',
#  'Published: 1 October 2019',
#  'Published: 23 July 2019',
#  'Published: 18 July 2019',
#  'Published: 2 July 2019',
#  'Published: 14 June 2019',
#  'Published: 6 June 2019',
#  'Published: 5 June 2019',
#  'Published: 10 May 2019',
#  'Published: 26 April 2019',
#  'Published: 8 April 2019',
#  'Published: 31 January 2019',
#  'Published: 28 January 2019',
#  'Published: 1 January 2019',
#  'Published: 1 January 2019',
#  'Published: 1 January 2019',
#  'Published: 26 October 2018',
#  'Published: 25 October 2018',
#  'Published: 11 October 2018',
#  'Published: 31 August 2018',
#  'Published: 28 August 2018',
#  'Published: 5 July 2018',
#  'Published: 4 May 2018',
#  'Published: 16 April 2018',
#  'Published: 1 April 2018',
#  'Published: 27 March 2018',
#  'Published: 6 February 2018',
#  'Published: 1 January 2018',
#  'Published: 1 June 2017',
#  'Published: 4 April 2017',
#  'Published: 28 March 2017',
#  'Published: 3 January 2017',
#  'Published: 1 January 2017',
#  'Published: 15 November 2016',
#  'Published: 27 October 2016',
#  'Published: 24 October 2016',
#  'Published: 14 September 2016',
#  'Published: 1 September 2016',
#  'Published: 25 August 2016',
#  'Published: 21 August 2016',
#  'Published: 10 August 2016',
#  'Published: 12 July 2016',
#  'Published: 1 July 2016',
#  'Published: 22 June 2016',
#  'Published: 30 March 2016',
#  'Published: 9 March 2016',
#  'Published: 1 January 2016',
#  'Published: 1 January 2016',
#  'Published: 31 October 2015',
#  'Published: 5 October 2015',
#  'Published: 1 September 2015',
#  'Published: 24 August 2015',
#  'Published: 24 August 2015',
#  'Published: 24 August 2015',
#  'Published: 1 July 2015',
#  'Published: 1 February 2015',
#  'Published: 1 February 2015',
#  'Published: 1 January 2015',
#  'Published: 1 January 2015',
#  'Published: 1 January 2015',
#  'Published: 1 January 2015',
#  'Published: 1 January 2015',
#  'Published: 1 January 2015',
#  'Published: 30 November 2014',
#  'Published: 1 January 2014',
#  'Published: 26 November 2013',
#  'Published: 14 November 2013',
#  'Published: 1 October 2013',
#  'Published: 1 August 2013',
#  'Published: 31 May 2013',
#  'Published: 27 April 2013',
#  'Published: 14 March 2013',
#  'Published: 12 December 2012',
#  'Published: 23 November 2012',
#  'Published: 9 November 2012',
#  'Published: 6 November 2012',
#  'Published: 6 November 2012',
#  'Published: 23 May 2012',
#  'Published: 9 January 2012',
#  'Published: 1 January 2012',
#  'Published: 4 June 2011',
#  'Published: 21 April 2011',
#  'Published: 28 February 2011',
#  'Published: 28 February 2011',
#  'Published: 28 February 2011',
#  'Published: 28 February 2011',
#  'Published: 1 January 2011',
#  'Published: 10 August 2010',
#  'Published: 31 January 2010',
#  'Published: 1 January 2010',
#  'Published: 1 January 2010',
#  'Published: 1 January 2010',
#  'Published: 9 November 2009',
#  'Published: 1 September 2009',
#  'Published: 5 August 2009',
#  'Published: 31 January 2009',
#  'Published: 1 January 2009',
#  'Published: 1 January 2009',
#  'Published: 8 October 2008',
#  'Published: 3 June 2008',
#  'Published: 1 January 2008',
#  'Published: 31 December 2007',
#  'Published: 12 November 2007',
#  'Published: 30 September 2006',
#  'Published: 30 April 2006',
#  'Published: 1 January 2006',
#  'Published: 1 January 2005',
#  'Published: unknown date',
#  'Published: unknown date',
#  'Published: unknown date',
#  'Published: 28 October 2022',
#  'Published: 21 October 2022',
#  'Published: 9 October 2022',
#  'Published: 8 September 2022',
#  'Published: 23 July 2022',
#  'Published: 29 March 2022',
#  'Published: 25 March 2022',
#  'Published: 15 March 2022',
#  'Published: 20 January 2022',
#  'Published: 14 January 2022',
#  'Published: 14 January 2022',
#  'Published: 23 December 2021',
#  'Published: 15 December 2021',
#  'Published: 4 December 2021',
#  'Published: 29 November 2021',
#  'Published: 28 October 2021',
#  'Published: 19 October 2021',
#  'Published: 18 October 2021',
#  'Published: 23 September 2021',
#  'Published: 1 June 2021',
#  'Published: 16 January 2021',
#  'Published: 31 December 2020',
#  'Published: 22 December 2020',
#  'Published: 7 December 2020',
#  'Published: 20 November 2020',
#  'Published: 10 July 2020',
#  'Published: 6 July 2020',
#  'Published: 8 April 2020',
#  'Published: 1 January 2020',
#  'Published: 30 December 2019',
#  'Published: 24 November 2019',
#  'Published: 14 October 2019',
#  'Published: 1 October 2019',
#  'Published: 23 July 2019',
#  'Published: 18 July 2019',
#  'Published: 2 July 2019',
#  'Published: 14 June 2019',
#  'Published: 6 June 2019',
#  'Published: 5 June 2019',
#  'Published: 10 May 2019',
#  'Published: 26 April 2019',
#  'Published: 8 April 2019',
#  'Published: 31 January 2019',
#  'Published: 28 January 2019',
#  'Published: 1 January 2019',
#  'Published: 1 January 2019',
#  'Published: 1 January 2019',
#  'Published: 26 October 2018',
#  'Published: 25 October 2018',
#  'Published: 11 October 2018',
#  'Published: 31 August 2018',
#  'Published: 28 August 2018',
#  'Published: 5 July 2018',
#  'Published: 4 May 2018',
#  'Published: 16 April 2018',
#  'Published: 1 April 2018',
#  'Published: 27 March 2018',
#  'Published: 6 February 2018',
#  'Published: 1 January 2018',
#  'Published: 1 June 2017',
#  'Published: 4 April 2017',
#  'Published: 28 March 2017',
#  'Published: 3 January 2017',
#  'Published: 1 January 2017',
#  'Published: 15 November 2016',
#  'Published: 27 October 2016',
#  'Published: 24 October 2016',
#  'Published: 14 September 2016',
#  'Published: 1 September 2016',
#  'Published: 25 August 2016',
#  'Published: 21 August 2016',
#  'Published: 10 August 2016',
#  'Published: 12 July 2016',
#  'Published: 1 July 2016',
#  'Published: 22 June 2016',
#  'Published: 30 March 2016',
#  'Published: 9 March 2016',
#  'Published: 1 January 2016',
#  'Published: 1 January 2016',
#  'Published: 31 October 2015',
#  'Published: 5 October 2015',
#  'Published: 1 September 2015',
#  'Published: 24 August 2015',
#  'Published: 24 August 2015',
#  'Published: 24 August 2015',
#  'Published: 1 July 2015',
#  'Published: 1 February 2015',
#  'Published: 1 February 2015',
#  'Published: 1 January 2015',
#  'Published: 1 January 2015',
#  'Published: 1 January 2015',
#  'Published: 1 January 2015',
#  'Published: 1 January 2015',
#  'Published: 1 January 2015',
#  'Published: 30 November 2014',
#  'Published: 1 January 2014',
#  'Published: 26 November 2013',
#  'Published: 14 November 2013',
#  'Published: 1 October 2013',
#  'Published: 1 August 2013',
#  'Published: 31 May 2013',
#  'Published: 27 April 2013',
#  'Published: 14 March 2013',
#  'Published: 12 December 2012',
#  'Published: 23 November 2012',
#  'Published: 9 November 2012',
#  'Published: 6 November 2012',
#  'Published: 6 November 2012',
#  'Published: 23 May 2012',
#  'Published: 9 January 2012',
#  'Published: 1 January 2012',
#  'Published: 4 June 2011',
#  'Published: 21 April 2011',
#  'Published: 28 February 2011',
#  'Published: 28 February 2011',
#  'Published: 28 February 2011',
#  'Published: 28 February 2011',
#  'Published: 1 January 2011',
#  'Published: 10 August 2010',
#  'Published: 31 January 2010',
#  'Published: 1 January 2010',
#  'Published: 1 January 2010',
#  'Published: 1 January 2010',
#  'Published: 9 November 2009',
#  'Published: 1 September 2009',
#  'Published: 5 August 2009',
#  'Published: 31 January 2009',
#  'Published: 1 January 2009',
#  'Published: 1 January 2009',
#  'Published: 8 October 2008',
#  'Published: 3 June 2008',
#  'Published: 1 January 2008',
#  'Published: 31 December 2007',
#  'Published: 12 November 2007',
#  'Published: 30 September 2006',
#  'Published: 30 April 2006',
#  'Published: 1 January 2006',
#  'Published: 1 January 2005',
#  'Published: unknown date',
#  'Published: unknown date',
#  'Published: unknown date']

# %%
for i in range(len(pub_date)):
    pub_date[i] = pub_date[i][-4:]
    
pub_date
# Out:
# ['2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2014',
#  '2014',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2008',
#  '2008',
#  '2008',
#  '2007',
#  '2007',
#  '2006',
#  '2006',
#  '2006',
#  '2005',
#  'date',
#  'date',
#  'date',
#  '2022',
#  '2022',
#  '2019',
#  '2019',
#  '2016',
#  '2016',
#  '2015',
#  '1983',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2014',
#  '2014',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2008',
#  '2008',
#  '2008',
#  '2007',
#  '2007',
#  '2006',
#  '2006',
#  '2006',
#  '2005',
#  'date',
#  'date',
#  'date',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2014',
#  '2014',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2008',
#  '2008',
#  '2008',
#  '2007',
#  '2007',
#  '2006',
#  '2006',
#  '2006',
#  '2005',
#  'date',
#  'date',
#  'date',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2014',
#  '2014',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2008',
#  '2008',
#  '2008',
#  '2007',
#  '2007',
#  '2006',
#  '2006',
#  '2006',
#  '2005',
#  'date',
#  'date',
#  'date',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2014',
#  '2014',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2008',
#  '2008',
#  '2008',
#  '2007',
#  '2007',
#  '2006',
#  '2006',
#  '2006',
#  '2005',
#  'date',
#  'date',
#  'date',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2014',
#  '2014',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2008',
#  '2008',
#  '2008',
#  '2007',
#  '2007',
#  '2006',
#  '2006',
#  '2006',
#  '2005',
#  'date',
#  'date',
#  'date',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2014',
#  '2014',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2008',
#  '2008',
#  '2008',
#  '2007',
#  '2007',
#  '2006',
#  '2006',
#  '2006',
#  '2005',
#  'date',
#  'date',
#  'date']

# %%
for i in range(len(authors)):
    authors[i] = authors[i].strip('][').split(',')

# %%
authors
# Out:
# [['Michael Cullen Halvorson', ' Noah Moyers', ' I. Dale Thomas'],
#  ['Yongqun He',
#   'Hong Yu',
#   ' Anthony Huffman',
#   ' Asiyah Yu Lin',
#   ' Darren A. Natale',
#   ' John Beverley',
#   ' Ling Zheng',
#   ' Yehoshua Perl',
#   ' Zhigang Wang',
#   ' Yingtong Liu',
#   ' Edison Ong',
#   ' Yang Wang',
#   ' Philip Huang',
#   ' Long Tran',
#   ' Jinyang Du',
#   ' Zalan Shah',
#   ' Easheta Shah',
#   ' Roshan Desai',
#   ' Hsin-Hui Huang',
#   ' Yujia Tian',
#   ' et al.'],
#  ['Lidiia Vlasenko',
#   'Nataliia Lutska',
#   'Nataliia Zaiets',
#   'Igor Korobiichuk',
#   'Serhii Hrybkov'],
#  ['Patricia Romao',
#   ' Stefanie Neuenschwander',
#   ' Chantal Zbinden',
#   ' Kathleen Seidel',
#   'Murat Sariyar'],
#  ['Sachiko Lim', 'Paul Johansson'],
#  ['Edward Louis',
#   ' Ryan Colletti',
#   ' Mohammad Hussain',
#   ' Gregory Mocko',
#   ' Chris Paredis'],
#  ['Farhad Ameri', 'Evan Wallace', ' Reid Yoder', 'Frank Riddick'],
#  ['J. Neil Otte', ' John Beverley', ' Alan Ruttenberg'],
#  ['Meng Liu',
#   ' Jialin Liu',
#   ' Guitian Liu',
#   ' Hui Wang',
#   ' Xiaoli Wang',
#   'Zixin Deng',
#   'Yongqun He',
#   'Hong-Yu Ou'],
#  ['Astghik Sargsyan',
#   'Philipp Wegner',
#   'Stephan Gebel',
#   'Shounak Baksi',
#   ' Geena Mariya Jose',
#   'Vanessa Lange-Rupprecht',
#   ' Johannes Darms',
#   'Bruce Schultz',
#   ' Jürgen Klein',
#   'Marc Jacobs',
#   'Philippe Ryvlin',
#   ' Sumit Madan',
#   'Martin Hofmann-Apitius',
#   'Alpha Tom Kodamullil'],
#  ['Stefanie Neuenschwander',
#   ' Patricia Romao',
#   ' Jürgen Holm',
#   ' Murat Sariyar'],
#  ['Fumiaki Toyoshima',
#   ' Adrien Barton',
#   ' Ludger Jansen',
#   ' Jean-François Ethier'],
#  ['Caterina Pietra', 'Roberto De Lotto', 'Rakan Bahshwan'],
#  ['Fernando Cicconeto',
#   ' Lucas Valadares Vieira',
#   ' Mara Abel',
#   'Renata Dos Santos Alvarenga',
#   'Joel Luis Carbonera',
#   ' Luan Fonseca Garcia'],
#  ['Juan José Montero Jiménez',
#   ' Rob Vingerhoeds',
#   ' Bernard Grabot',
#   ' Sébastien Schwartz'],
#  ['Justine Flore Tchouanguem',
#   ' Mohamed Hedi Karray',
#   ' Bernard Kamsu Foguem',
#   ' Camille Magniont',
#   ' F. Henry Abanda',
#   ' Barry Smith'],
#  ['Linda Elmhadhbi',
#   'Mohamed-Hedi Karray',
#   'Bernard Archimède',
#   'J. Neil Otte',
#   'Barry Smith'],
#  ['Rosario Davide D’Amico', ' Pavan Addepalli', ' John Ahmet Erkoyuncu'],
#  ['Yan Zhu',
#   ' Lihong Liu',
#   ' Bo Gao',
#   ' Jing Liu',
#   ' Xingchao Qiao',
#   'Chaojie Lian',
#   'Yongqun He'],
#  ['Ling Wan',
#   ' Justin Song',
#   ' Virginia He',
#   ' Jennifer Roman',
#   ' Grace Whah',
#   ' Suyuan Peng',
#   ' Luxia Zhang',
#   'Yongqun He'],
#  ['Saoussen Dimassi',
#   'Frédéric Demoly',
#   ' Christophe Cruz',
#   ' H. Jerry Qi',
#   ' Kyoung-Yun Kim',
#   ' Jean-Claude André',
#   'Samuel Gomes'],
#  ['Nora Shoaip',
#   'Amira Rezk',
#   ' Shaker El-Sappagh',
#   'Louai Alarabi',
#   ' Sherif Barakat',
#   'Mohammed M. Elmogy'],
#  ['M. N. Roelofs', ' Roelof Vos'],
#  ['Janna Hastings', 'Sharon Cox', 'Robert West', 'Caitlin Notley'],
#  ['Jorge Lázaro', ' Hazel Barahona Gamboa', ' Gerardo Sierra Martínez'],
#  ['Munira Mohd Ali',
#   ' Ruoyu Yang',
#   ' Binbin Zhang',
#   ' Francesco Furini',
#   'Rahul Rai',
#   ' J. Neil Otte',
#   ' Barry Smith'],
#  ['Felipe Carvalho Pellison',
#   'Rui Pedro Charters Lopes Rijo',
#   'Vinicius Costa Lima',
#   'Nathalia Yukie Crepaldi',
#   'Filipe Andrade Bernardi',
#   'Rafael Mello Galliez',
#   'Afrânio Kritski',
#   'Kumar Abhishek',
#   'Domingos Alves'],
#  ['Adolfo Americano Brandão', ' Geilson Loureiro'],
#  ['Balanand Jha',
#   'Kumar Abhishek',
#   ' Akshay Deepak',
#   ' Shubhnkar Upadhyay',
#   ' Avadhesh Singh'],
#  ['Yongqun He',
#   'Haihe Wang',
#   'Jie Zheng',
#   'Daniel P. Beiting',
#   'Anna Maria Masci',
#   'Hong Yu',
#   'Kaiyong Liu',
#   'Jianmin Wu',
#   'Jeffrey L. Curtis',
#   'Barry Smith',
#   'Alexander V. Alekseyenko',
#   'Jihad S. Obeid'],
#  ['Felipe Carvalho Pellison',
#   'Rui Pedro Charters Lopes Rijo',
#   'Vinicius Costa Lima',
#   'Nathalia Yukie Crepaldi',
#   'Filipe Andrade Bernardi',
#   'Rafael Mello Galliez',
#   'Afrânio Kritski',
#   'Kumar Abhishek',
#   'Domingos Alves'],
#  ['Andrew Iliadis'],
#  ['Aaron Sterling'],
#  ['Hyunmin Cheong', ' Adrian Butscher'],
#  ['Richard de Rozario'],
#  ['Stanley Blum',
#   'Katharine Barker',
#   'Steven J Baskauf',
#   'Walter G. Berendsohn',
#   'Pier Luigi Buttigieg',
#   'Markus Döring',
#   ' Gabriele Droege',
#   'David Fichtmueller',
#   'Falko Glöckler',
#   'Anton Güntsch',
#   ' Robert Guralnick',
#   'Jana Hoffmann',
#   ' Niels Klazenga',
#   'James Macklin',
#   ' Paul J. Morris',
#   'Deborah L Paul',
#   'Mareike Petersen',
#   'Tim Robertson',
#   ' Joel Sachs',
#   'David Shorthouse',
#   ' et al.'],
#  ['Thomas J. Hagedorn', ' Barry Smith', ' Sundar Krishnamurty', ' Ian Grosse'],
#  ['Douglas Orellana', ' William Mandrick'],
#  ['Barry Smith'],
#  ['Shaker El-Sappagh',
#   ' Farman Ali',
#   ' AbdelTawab Hendawi',
#   ' Jun-Hyeog Jang',
#   'Kyung-Sup Kwak'],
#  ['Linda Elmhadhbi', ' Mohamed-Hedi Karray', ' Bernard Archimède'],
#  ['Jobst Landgrebe', ' Barry Smith'],
#  ['Andrew Iliadis'],
#  ['Lars Vogt'],
#  ['Arkopaul Sarkar', 'Dušan Šormaz'],
#  ['Arkopaul Sarkar', 'Dušan Šormaz'],
#  ['Aaron Sterling'],
#  ['Linda Elmhadhbi', 'Mohamed-Hedi Karray', ' Bernard Archimède'],
#  ['Qing Zou', ' Eun G. Park'],
#  ['Robert Stevens', 'Phillip Lord', 'James Malone', 'Nicolas Matentzoglu'],
#  ['Shaker H. Ali El-Sappagh',
#   'Francesco Franda',
#   'Farman Ali',
#   'Kyung-Sup Kwak'],
#  ['Maroua Masmoudi',
#   ' Sana Ben Abdallah Ben Lamine',
#   ' Hajer Baazaoui Zghal',
#   ' Mohamed Hedi Karray',
#   ' Bernard Archimede'],
#  ['David Stuart'],
#  ['Brian Donohue', ' Ronald Rudnicki', ' Mark Jensen', ' Alexander P. Cox'],
#  ['James C Schuler', ' Werner M Ceusters'],
#  ['Ricardo C. Waldemarin', 'Cléver R.G. de Farias'],
#  ['Ludger Jansen'],
#  ['Shaker H. Ali El-Sappagh', 'Daehan Kwak', 'Farman Ali', 'Kyung-Sup Kwak'],
#  ['Robert Stevens', ' Phillip Lord', ' James Malone', 'Nicolas Matentzoglu'],
#  ['Ana Correia', ' Dragan Stokic', ' Rebecca Siafaka', 'Sebastian Scholze'],
#  ['Lars Vogt'],
#  ['José M Parente de Oliveira', 'Barry Smith'],
#  ['Adrien Barton',
#   'Jean-François Ethier',
#   'Régis Duvauferrier',
#   'Anita Burgun'],
#  ['Stefan Schulz', 'Martin Boeker', ' Catalina Martinez-Costa'],
#  ['Robert B. Allen'],
#  ['Satoshi Mizuno',
#   'Soichi Ogishima',
#   ' Hidekazu Nishigori',
#   ' Daniel G. Jamieson',
#   ' Karin Verspoor',
#   ' Hiroshi Tanaka',
#   ' Nobuo Yaegashi',
#   ' Jun Nakaya'],
#  ['Robert B. Allen'],
#  ['Jie Zheng',
#   'Marcelline R. Harris',
#   'Anna Maria Masci',
#   'Yu Lin',
#   'Alfred Hero',
#   'Barry Smith',
#   'Yongqun He'],
#  ['Kun Zhang', 'Yoshifumi Nishida', 'Koji Kitamura', ' Yoshiki Mikami'],
#  ['Shaker El-Sappagh', 'Farman Ali'],
#  ['Francesco Furini',
#   ' Rahul Rai',
#   'Barry Smith',
#   'Giorgio Colombo',
#   'Venkat Krovi'],
#  ['Yoonmi Chu', ' Robert B. Allen'],
#  ['Amanda Hicks',
#   ' Josh Hanna',
#   ' Daniel Welch',
#   ' Mathias Brochhausen',
#   ' William R. Hogan'],
#  ['Yoonmi Chu', ' Robert B. Allen'],
#  ['Andrew D. Spear', 'Werner Ceusters', 'Barry Smith'],
#  ['Patrick L. Ray',
#   'Alexander P. Cox',
#   'Mark Jensen',
#   'Travis Allen',
#   'William Duncan',
#   'Alexander D. Diehl'],
#  ['Martin Frické'],
#  ['Jean Marie Rodrigues',
#   ' Neelam Dhingra-Kumar',
#   ' Stefan Schulz',
#   ' Julien Souvignet'],
#  ['James D. Smith'],
#  ['Selja Seppälä', 'Amanda Hicks'],
#  ['Yu Lin', 'Zuoshuang Xiang', 'Yongqun He'],
#  ['Qing Zou', ' Eun G. Park'],
#  ['Robert Arp', ' Barry Smith', 'Andrew D. Spear'],
#  ['Robert Arp', ' Barry Smith', 'Andrew D. Spear'],
#  ['Robert Arp', ' Barry Smith', 'Andrew D. Spear'],
#  ['Asami Suzuki', 'Takako Takai-Igarashi', 'Jun Nakaya', 'Hiroshi Tanaka'],
#  ['Andrej Machno',
#   'Pierre Jannin',
#   ' Olivier Dameron',
#   ' Werner Korb',
#   ' Gerik Scheuermann',
#   ' Jürgen Meixensberger'],
#  ['Robert B. Allen', ' Yoonmi Chu'],
#  ['Julien Souvignet', ' Jean-Marie Rodrigues'],
#  ['Robert Arp', 'Barry Smith', 'Andrew D. Spear'],
#  ['V. Curcin',
#   ' A. Barton',
#   ' M. M. McGilchrist',
#   ' H. Bastiaens',
#   'A. Andreasson',
#   ' J. Rossiter',
#   ' L. Zhao',
#   'T. N. Arvanitis',
#   'A. Taweel',
#   'B. C. Delaney',
#   'A. Burgun',
#   'J. -F. Ethier'],
#  ['Robert Arp', ' Barry Smith', ' Andrew D. Spear'],
#  [''],
#  ['Robert Arp', ' Barry Smith', ' Andrew D. Spear'],
#  ['Marcus C Chibucos',
#   'Adrienne E Zweifel',
#   'Jonathan C Herrera',
#   'William Meza',
#   'Shabnam Eslamfam',
#   'Peter Uetz',
#   'Deborah A Siegele',
#   'James C Hu',
#   'Michelle G Giglio'],
#  ['Catia Pesquita', 'João D Ferreira', 'Francisco M Couto', 'Mário J Silva'],
#  ['Erica Marcos', 'Bin Zhao', 'Yongqun He'],
#  ['Yongqun He', ' Zoushuang Xiang'],
#  ['Ratnesh Sahay',
#   ' Dimitrios Ntalaperas',
#   ' Eleni Kamateri',
#   ' Panagiotis Hasapis',
#   'Oya Deniz Beyan',
#   'Marie-Pierre F. Strippoli',
#   ' Christiana A. Demetriou',
#   ' Thomai Gklarou-Stavropoulou',
#   ' Matthias Brochhausen',
#   ' Konstantinos Tarabanis',
#   ' Thanassis Bouras',
#   'David Tian',
#   'Aristos Aristodimoux',
#   ' Athos Antoniadesx',
#   ' Christos Georgousopoulos',
#   ' Manfred Hauswirth',
#   'Stefan Decker'],
#  ['Kate Button', 'Robert W. van Deursen', 'Larisa Soldatova', 'Irena Spasić'],
#  ['John Deck',
#   ' Katharine Barker',
#   ' Reed Beaman',
#   'Pier Luigi Buttigieg',
#   ' Gabriele Dröge',
#   ' Robert Guralnick',
#   ' Chuck Miller',
#   ' Éamonn Ó Tuama',
#   ' Zack Murrell',
#   'Cynthia Parr',
#   ' Bob Robbins',
#   'Dmitry Schigel',
#   ' Brian Stucky',
#   ' Ramona Walls',
#   ' John Wieczorek',
#   'Norman Morrison',
#   ' John Wooley'],
#  ['Richard Okelo Angole', ' Peter Jehopio', 'Gilbert Maiga'],
#  ['Barry Smith'],
#  ['Lars Vogt', ' Peter Grobe', 'Björn Quast', ' Thomas Bartolomaeus'],
#  ['Janna Hastings',
#   ' Paula De Matos',
#   'Adriano Dekker',
#   'Marcus Ennis',
#   'Bhavana Harsha',
#   'Namrata Kale',
#   'Venkatesh Muthukrishnan',
#   'Gareth Owen',
#   ' Steve Turner',
#   ' Mark Williams',
#   'Christoph Steinbeck'],
#  ['Alejandra González-Beltrán',
#   'Eamonn Maguire',
#   'Philippe Rocca-Serra',
#   'Susanna-Assunta Sansone'],
#  ['Felix Gantner', 'Bettina Waldvogel', ' Rolf Meile', 'Patrick Laube'],
#  ['Barry Smith'],
#  ['Priti P Parikh',
#   'Jie Zheng',
#   'Flora Logan-Klumpler',
#   'Christian J StoeckertJr',
#   'Christos Louis',
#   'Pantelis Topalis',
#   'Anna V Protasio',
#   'Amit P Sheth',
#   'Mark Carrington',
#   'Matthew Berriman',
#   'Satya S Sahoo'],
#  ['Lars Vogt', ' Peter Grobe', 'Björn Quast', ' Thomas Bartolomaeus'],
#  ['Frank Oemig', 'Bernd Blobel'],
#  ['Jessica A. Turner', 'Angela R. Laird'],
#  ['Lars Vogt', ' Peter Grobe', 'Björn Quast', ' Thomas Bartolomaeus'],
#  ['Y. Megan Kong',
#   ' Carl Dahlke',
#   ' Qun Xiang',
#   ' Yu Qian',
#   ' David Karp',
#   'Richard H. Scheuermann'],
#  ['Dennis G. Thomas', ' Rohit V. Pappu', 'Nathan A. Baker'],
#  ['Albert Goldfain', 'Barry Smith', 'Lindsay G. Cowell'],
#  ['William R. Hogan'],
#  ['M. Capolupo', ' G. de Moor', ' J. Devlies', 'B. Smith', 'W. Ceusters'],
#  ['Pantelis Topalis',
#   'Elvira Mitraka',
#   'Ioana Bujila',
#   'Elena Deligianni',
#   'Emmanuel Dialynas',
#   'Inga Siden-Kiamos',
#   'Marita Troye-Blomberg',
#   'Christos Louis'],
#  ['Matthias Samwald',
#   ' Huajun Chen',
#   'Alan Ruttenberg',
#   ' Ernest Lim',
#   'Luis Marenco',
#   ' Perry Miller',
#   ' Gordon Shepherd',
#   ' Kei-Hoi Cheung'],
#  ['Werner Ceusters', 'Barry Smith'],
#  ['Frank Oemig', 'Bernd Blobel'],
#  ['Cui Tao',
#   ' Harold R. Solbrig',
#   ' Deepak K. Sharma',
#   ' Wei-Qi Wei',
#   ' Guergana K. Savova',
#   ' Christopher G. Chute'],
#  ['Werner Ceusters', ' Barry Smith'],
#  ['Dennis G. Thomas', ' Rohit V. Pappu', 'Nathan A. Baker'],
#  ['Yongqun He',
#   ' Fang Chen',
#   'Richard H. Scheuermann',
#   ' Thomas Todd',
#   'Ryan R. Brinkman',
#   ' Lesley Colby',
#   'Mélanie Courtot',
#   ' Howard Rush',
#   ' Chris Mungall',
#   '  Trish Whetzel',
#   'Mark A. Musen',
#   'Brian D. Athey',
#   'Lindsay Cowell',
#   'Gilbert S. Omenn',
#   'Alexander D. Diehl',
#   ' Barry Smith',
#   ' Harry Mobley',
#   'Zuoshuang Xiang',
#   'Bjoern Peters',
#   'Alan Ruttenberg'],
#  ['Eric G. Little', ' Galina L. Rogova'],
#  ['Werner Ceusters', ' Maria Capolupo', 'Barry Smith', ' Georges De Moor'],
#  ['M. Boeker', 'H. Stenzhorn', ' J. Niggemann', 'S. Schulz'],
#  ['William Hogan'],
#  ['Robert Arp', 'Barry Smith'],
#  ['Stefan Schulz', 'Martin Boeker', 'Holger Stenzhorn'],
#  ['Werner Ceusters', ' Peter Elkin', 'Barry Smith'],
#  ['Amarnath Gupta',
#   'Stephen D. Larson',
#   'Christopher Condit',
#   ' Sandeep Gupta',
#   'Lisa Fong',
#   'Li Chen',
#   'Maryann E. Martone'],
#  ['Werner Ceusters', 'Barry Smith'],
#  ['Jonathan Simon', ' Mariana Dos Santos', ' James Fielding', 'Barry Smith'],
#  ['Werner Ceusters', ' Barry Smith'],
#  ['John Bateman', 'Scott Farrar'],
#  [''],
#  ['Frank Oemig', ' Bernd Blobel'],
#  ['Felix Gantner', ' Bettina Waldvogel', ' Rolf Meile', ' Patrick Laube'],
#  ['Barry Smith'],
#  ['Barry Smith', ' Rita Giuffrida'],
#  ['Barry Smith'],
#  ['Barry Smith',
#   ' Farhad Ameri',
#   ' Hyunmin Cheong',
#   ' Dimitris Kiritsis',
#   ' Dusan Sormaz',
#   ' Chris Will',
#   ' J. Neil Otte'],
#  ['Niels Grewe', ' Ludger Jansen', ' Barry Smith'],
#  ['Ong Edison: Xiang', ' Zheng Jie', ' Barry Smith', ' He Yongqun'],
#  ['Robert Arp', ' Barry Smith', ' Andrew D. Spear'],
#  ['Barry Smith', ' Kevin Mulligan']]

# %%
for x in phil_authors:
    authors.append(x)
for x in phil_titles:
    titles.append(x)
for x in phil_pub_date:
    pub_date.append(x)
for x in phil_pub_info:
    pub_info.append(x)
for x in phil_links: 
    links.append(x)

# %%
print(len(authors))
print(len(titles))
print(len(pub_date))
print(len(pub_info))
print(len(links))
# Out:
# 149
# 149
# 149
# 149
# 149

# %%
articles = {}
articles["Authors"] = authors
articles["Title"] = titles
articles["Date"] = pub_date
articles["Publication"] = pub_info
articles["Link"] = links

# %%
browser.quit()

# %%
from flask import Flask, render_template, redirect, jsonify
from flask_pymongo import PyMongo

# %%
import requests
import os
from splinter import Browser
from selenium import webdriver
app = Flask(__name__, static_folder = "assets")

app.config["MONGO_URI"] = "mongodb://localhost:27017/bfo_papers"
mongo = PyMongo(app)

# %%
bfo_papers = mongo.db.bfo_papers

# %%
bfo_papers.update_many({}, {"$set": articles}, upsert=True)

# %%
### Users test

# %%
import pandas as pd
df = pd.read_csv("assets/users.csv")

# %%
df.head()
# Out:
#                                     name description  underneath  \
# 0         ACGT Master Ontology (ACGT MO)         NaN  Ontologies
# 1  Additive Manufacturing Ontology (AMO)         NaN  Ontologies
# 2   Adolescent Depression Ontology (ADO)         NaN  Ontologies
# 3        African Wildlife Ontology (AWO)         NaN  Ontologies
# 4         Agronomic Linked Data (AgroLD)         NaN  Ontologies
#
#                                                  url
# 0  http://bioportal.bioontology.org/ontologies/AC...
# 1  https://www.sciencedirect.com/science/article/...
# 2  https://www.jmir.org/article/viewFile/jmir_v19...
# 3               https://arxiv.org/pdf/1905.09519.pdf
# 4  https://www.biorxiv.org/content/10.1101/325423...

# %%
df = df.drop(columns = ["description", "underneath"])

# %%
df.sort_values('name', ascending = True)
# Out:
#                                                   name  \
# 97   (EXperimental ACTions) Biomedical Protocol Ont...
# 325                (Microbial) Typing Ontology (TypOn)
# 0                       ACGT Master Ontology (ACGT MO)
# 10                           AFO Foundational Ontology
# 419  ARIES (Arkansas Imaging Enterprise System) Kno...
# ..                                                 ...
# 139                     uc_FoodDrugInteractionOntology
# 140                                            uc_Milk
# 141                                      uc_Processing
# 142                                           uc_Sense
# 338                                               yOWL
#
#                                                    url
# 97   http://www.ncbi.nlm.nih.gov/pmc/articles/PMC42...
# 325                      http://www.phyloviz.net/typon
# 0    http://bioportal.bioontology.org/ontologies/AC...
# 10   http://esw.w3.org/topic/HCLS/AFO_Foundational_...
# 419  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8...
# ..                                                 ...
# 139  https://github.com/IC-FOODS/uc_FoodDrugInterac...
# 140                https://github.com/IC-FOODS/uc_Milk
# 141          https://github.com/IC-FOODS/uc_Processing
# 142               https://github.com/IC-FOODS/uc_Sense
# 338         http://www2007.org/workshops/paper_130.pdf
#
# [456 rows x 2 columns]

# %%
df["url"] = df["url"].fillna("no_link")

# %%
users = df.to_dict(orient='records')

# %%
users
# Out:
# [{'name': 'ACGT Master Ontology (ACGT MO)',
#   'url': 'http://bioportal.bioontology.org/ontologies/ACGT-MO'},
#  {'name': 'Additive Manufacturing Ontology (AMO)',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S0166361518301647'},
#  {'name': 'Adolescent Depression Ontology (ADO)',
#   'url': 'https://www.jmir.org/article/viewFile/jmir_v19i7e259/2'},
#  {'name': 'African Wildlife Ontology (AWO)',
#   'url': 'https://arxiv.org/pdf/1905.09519.pdf'},
#  {'name': 'Agronomic Linked Data (AgroLD)',
#   'url': 'https://www.biorxiv.org/content/10.1101/325423v3.full.pdf'},
#  {'name': 'Algorithm-Implementation-Execution Ontology Design Pattern',
#   'url': 'http://ontologydesignpatterns.org/wiki/images/4/41/WOP2016_paper_07.pdf'},
#  {'name': 'Animals in Context Ontology (ACO)',
#   'url': 'http://ceur-ws.org/Vol-897/session1-paper04.pdf'},
#  {'name': 'Autism-DSM-ADI-R Ontology (ADAR)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/26151311'},
#  {'name': 'Alzheimer Disease Ontology (ADO)',
#   'url': 'http://www.sciencedirect.com/science/article/pii/S155252601300085X'},
#  {'name': 'Adverse Event Reporting Ontology (AERO)',
#   'url': 'http://purl.obolibrary.org/obo/aero'},
#  {'name': 'AFO Foundational Ontology',
#   'url': 'http://esw.w3.org/topic/HCLS/AFO_Foundational_Ontology'},
#  {'name': 'Actionable Intelligence Retrieval System (AIRS)',
#   'url': 'http://ncor.buffalo.edu/ontologies/AIRS_Ontologies.pdf'},
#  {'name': 'Antimicrobial-Microorganism Ontology',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S1532046411001675'},
#  {'name': 'Apollo Structured Vocabulary (Apollo-SV)',
#   'url': 'http://jbiomedsem.biomedcentral.com/articles/10.1186/s13326-016-0092-y'},
#  {'name': 'Bacterial Clinical Infectious Diseases Ontology (BCIDO)',
#   'url': 'http://www.sciencedirect.com/science/article/pii/S1532046415001549'},
#  {'name': 'Behavior Perspective Model (BPM)',
#   'url': 'https://books.google.com/books?hl=en&lr=lang_en&id=u8xmCgAAQBAJ&oi=fnd&pg=PA366&ots=p35Xg1rqn0&sig=6VibTWt8Y6mpTSyPFFc68xHePDw#v=onepage&q&f=false'},
#  {'name': 'Bank Ontology', 'url': 'http://world-comp.org/p2011/IKE5165.pdf'},
#  {'name': 'Battle Management Ontology (BMO)',
#   'url': 'http://link.springer.com/article/10.1007/s10489-016-0834-7'},
#  {'name': 'Behavior Change Intervention Ontology (BCIO)',
#   'url': 'https://wellcomeopenresearch.org/articles/5-123'},
#  {'name': 'Beta Cell Genomics Application Ontology (BCGO)',
#   'url': 'http://obofoundry.org/ontology/bcgo.html'},
#  {'name': 'BioAssay Ontology', 'url': 'http://www.bioassayontology.org/'},
#  {'name': 'Bioinformatics Web Service Ontology (OBIWS)',
#   'url': 'http://code.google.com/p/obi-webservice'},
#  {'name': 'Biological Collections Ontology (BCO)',
#   'url': 'http://obofoundry.org/ontology/bco.html'},
#  {'name': 'Biomedical Ethics Ontology',
#   'url': 'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC2725426/'},
#  {'name': 'Biomedical Grid Terminology (BiomedGT, retired)',
#   'url': 'https://wiki.nci.nih.gov/pages/viewpage.action?pageId=63996208'},
#  {'name': 'Bio-Knowledge Network Ontology (BioKNO)',
#   'url': 'https://www.degruyter.com/view/journals/jib/15/3/article-20180023.xml'},
#  {'name': 'Biomimetic Ontology',
#   'url': 'http://link.springer.com/chapter/10.1007/978-3-319-31782-3_13'},
#  {'name': 'BioTop', 'url': 'http://ebooks.iospress.nl/publication/46379'},
#  {'name': 'BioTopLite2', 'url': 'http://purl.org/biotop/btl2.owl'},
#  {'name': 'BIRNLex',
#   'url': 'https://bioportal.bioontology.org/ontologies/BIRNLEX'},
#  {'name': 'Blood Ontology (BLO)', 'url': 'http://mba.eci.ufmg.br/BLO'},
#  {'name': 'Body Fluids Ontology (BFLO)',
#   'url': 'http://ontology.buffalo.edu/smith/articles/BFLO_ICBO_2011.pdf'},
#  {'name': 'Bone Dysplasia Ontology (BDO)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC3338382/'},
#  {'name': 'Cancer Cell Ontology (OncoCL)',
#   'url': 'http://ceur-ws.org/Vol-1060/icbo2013_submission_75.pdf'},
#  {'name': 'Categorical Temporal Phenomenology',
#   'url': 'http://www.roentgensemiotics.net/phenomenology.htm'},
#  {'name': 'Cancer Chemoprevention Ontology (CanCo)',
#   'url': 'http://bioportal.bioontology.org/ontologies/CANCO'},
#  {'name': 'Cardiovascular Disease Ontology (CVDO)',
#   'url': 'https://www.ebi.ac.uk/ols/ontologies/cvdo'},
#  {'name': 'Cell Behavior Ontology (CBO)',
#   'url': 'http://cbo.biocomplexity.indiana.edu/'},
#  {'name': 'Cell Culture Ontology (CCONT)',
#   'url': 'https://bioportal.bioontology.org/ontologies/CCONT'},
#  {'name': 'Cell Cycle Ontology',
#   'url': 'http://genomebiology.com/2009/10/5/R58'},
#  {'name': 'Cell Expression, Localization, Development and Anatomy Ontology (CELDA)',
#   'url': 'http://nar.oxfordjournals.org.gate.lib.buffalo.edu/content/early/2013/12/03/nar.gkt1264.full.pdf'},
#  {'name': 'Cell Line Ontology (CLO)',
#   'url': 'http://obofoundry.org/ontology/clo.html'},
#  {'name': 'Cell Ontology', 'url': 'http://obofoundry.org/ontology/cl.html'},
#  {'name': 'Cellular Microscopy Phenotype Ontology (CMPO)',
#   'url': 'http://jbiomedsem.biomedcentral.com/articles/10.1186/s13326-016-0074-0'},
#  {'name': 'Chemical Analysis Ontology (CAO)',
#   'url': 'http://champ-project.org/'},
#  {'name': 'Chemical Entities of Biological Interest (ChEBI)',
#   'url': 'http://www.ebi.ac.uk/chebi'},
#  {'name': 'Chemical Information Ontology (CHEMINF)',
#   'url': 'http://obofoundry.org/ontology/cheminf.html'},
#  {'name': 'Chemical Methods Ontology (CHMO)',
#   'url': 'http://obofoundry.org/ontology/chmo.html'},
#  {'name': 'CHRONIOUS Ontology Suite',
#   'url': 'http://ceur-ws.org/Vol-833/paper22.pdf'},
#  {'name': 'Cigarette Smoke Exposure Ontology (CSEO)',
#   'url': 'http://www.jbiomedsem.com/content/pdf/2041-1480-5-31.pdf'},
#  {'name': 'Clinical Data Integration Model (CDMO)',
#   'url': 'https://www.ncbi.nlm.nih.gov/pubmed/24954896'},
#  {'name': 'Clinical Narrative Temporal Relation Ontology (CNTRO)',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3248753/?'},
#  {'name': 'Clinical Trial Protocol Ontology (CTP-O)',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S1569190X18301114'},
#  {'name': 'Clusters of Orthologous Groups (COG) Analysis Ontology (CAO)',
#   'url': 'https://bioportal.bioontology.org/ontologies/CAO'},
#  {'name': 'Cognition-Guided Surgery (CGS) Ontology',
#   'url': 'http://archiv.ub.uni-heidelberg.de/volltextserver/22579'},
#  {'name': 'Cognitive Paradigm Ontology (COGPO)', 'url': 'http://cogpo.org/'},
#  {'name': 'Cognitive Process Ontology (CPO)', 'url': 'no_link'},
#  {'name': 'Common Anatomy Reference Ontology (CARO)',
#   'url': 'http://obofoundry.org/ontology/caro.html'},
#  {'name': 'Common Core Ontologies (CCO)',
#   'url': 'http://www.cubrc.org/index.php/data-science-and-information-fusion/ontology'},
#  {'name': 'Common Core Cyber Ontology (C3O)',
#   'url': 'https://www-spiedigitallibrary-org.gate.lib.buffalo.edu/conference-proceedings-of-spie/10635/106350F/A-common-core-based-cyber-ontology-in-support-of-cross/10.1117/12.2307719.full?SSO=1'},
#  {'name': 'Communication Standards Ontology (CSO)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20543345'},
#  {'name': 'Comparative Data Analysis Ontology (CDAO)',
#   'url': 'https://bioportal.bioontology.org/ontologies/CDAO'},
#  {'name': 'Computational Neuroscience Ontology (CNO)',
#   'url': 'https://bioportal.bioontology.org/ontologies/CNO'},
#  {'name': 'Computer Aided Engineering Modeling Language (CAEML) Ontology',
#   'url': 'https://www.clics-network.org/downloads/NAFEMS_2016_Towards%20Cognitive%20Computer%20Aided%20Engineering.pdf'},
#  {'name': 'Computer-Based Patient Record Ontology (CPRO)',
#   'url': 'https://code.google.com/archive/p/cpr-ontology/'},
#  {'name': 'Conceptual Model Ontology (CMO)',
#   'url': 'http://ceur-ws.org/Vol-833/paper25.pdf'},
#  {'name': 'Core Data Integration Model (CDIM)',
#   'url': 'https://www.researchgate.net/publication/263323866_Clinical_Data_Integration_Model_Core_Interoperability_Ontology_for_Research_Using_Primary_Care_Data'},
#  {'name': 'Coriell Cell Line Ontology',
#   'url': 'http://efo.sourceforge.net/coriell.htm'},
#  {'name': "CPR Ontology for the Institute of Medicine's (IOM) Computer-Based Patient Record Ontology",
#   'url': 'http://code.google.com/p/cpr-ontology'},
#  {'name': 'Coronavirus Infectious Disease Ontology (CIDO)',
#   'url': 'http://www.ontobee.org/ontology/cido '},
#  {'name': 'Data Model for Representing Biographical Information for Prosopography (Bio-CRM)',
#   'url': 'https://seco.cs.aalto.fi/publications/2018/tuominen-et-al-rrl-2018.pdf'},
#  {'name': 'Decision Ontology',
#   'url': 'https://doi.org/10.3390/systems6040046'},
#  {'name': 'Diabetes mellitus Diagnosis Ontology (DDO)',
#   'url': 'http://link.springer.com/article/10.1186/s40535-016-0021-2'},
#  {'name': 'Diabetes Mellitus Treatment Ontology (DMTO)',
#   'url': 'https://jbiomedsem.biomedcentral.com/articles/10.1186/s13326-018-0176-y'},
#  {'name': 'Digital Objects in Philosophy Ontology (DOPHO)',
#   'url': 'https://publiscologne.th-koeln.de/frontdoor/deliver/index/docId/1363/file/MAT_Seidlmayer.pdf'},
#  {'name': 'Document Act Ontology (D-Acts)',
#   'url': 'https://code.google.com/p/d-acts'},
#  {'name': 'Drug Interaction Ontology (DIO)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/15360854'},
#  {'name': 'Drug Ontology (DrOn)',
#   'url': 'http://obofoundry.org/ontology/dron.html'},
#  {'name': 'Drug-drug Interaction Evidence Ontology (DIDEO)',
#   'url': 'http://obofoundry.org/ontology/dideo.html'},
#  {'name': 'Drug-drug Interaction Ontology (DINTO)',
#   'url': 'http://www.obofoundry.org/ontology/dinto.html'},
#  {'name': 'Drug Repurposing Ontology (DRO)',
#   'url': 'https://www.researchgate.net/profile/Werner_Ceusters/publication/335079148_Foundations_for_a_Realism-based_Drug_Repurposing_Ontology/links/5d4d7ce44585153e5948eb68/Foundations-for-a-Realism-based-Drug-Repurposing-Ontology.pdf'},
#  {'name': 'Eagle-I Research Resource Ontology (ERO)',
#   'url': 'https://open.med.harvard.edu/wiki/display/eaglei/Ontology'},
#  {'name': 'Electrocardiography Ontology (ECG)',
#   'url': 'http://www.j-biomed-inform.com/article/S1532-0464(10)00118-8/abstract'},
#  {'name': 'Eligibility Criteria Ontology (EC-O)',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S1569190X18301114'},
#  {'name': 'Email Ontology',
#   'url': 'http://ncor.buffalo.edu/2013/STIDS/5-Email.pptx'},
#  {'name': 'Emotion Ontology (EMO)',
#   'url': 'http://www.obofoundry.org/ontology/mfoem.html'},
#  {'name': 'ENanoMapper (ENM)', 'url': 'https://github.com/enanomapper'},
#  {'name': 'End of Life (EoL) Domain Ontology',
#   'url': 'https://www.sciencedirect.com/science/article/abs/pii/S0167739X19326640'},
#  {'name': 'Engineering-to-BioMimetic Ontology (E2BMO)',
#   'url': 'https://www.mdpi.com/2411-9660/2/4/53'},
#  {'name': 'Environment Ontology',
#   'url': 'http://obofoundry.org/ontology/envo.html'},
#  {'name': 'Epidemiology Ontology (EPO)',
#   'url': 'http://obofoundry.org/ontology/epo.html'},
#  {'name': 'Epilepsy and Seizure Ontology (EPSO)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23686934'},
#  {'name': 'Event-Based Functional Behavior Ontology (EFBO)',
#   'url': 'http://ceur-ws.org/Vol-1660/caos-paper2.pdf'},
#  {'name': 'European Materials Modeling Ontology (EMMO)',
#   'url': 'https://emmc.info/wp-content/uploads/2017/12/EMMC_IntOp2017-Cambridge_Ghedini_Bologna.pdf'},
#  {'name': 'Event-Based Ontology for Historical Description (EOHD)',
#   'url': 'https://www.emeraldinsight.com/doi/abs/10.1108/DLP-02-2018-0005'},
#  {'name': 'Evolution Ontology (EO)',
#   'url': 'http://code.google.com/p/evolution-ontology'},
#  {'name': 'Experimental Factor Ontology (EFO)',
#   'url': 'http://www.ebi.ac.uk/efo'},
#  {'name': '(EXperimental ACTions) Biomedical Protocol Ontology (EXACT2)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC4255744'},
#  {'name': 'Exposé',
#   'url': 'https://lirias.kuleuven.be/bitstream/123456789/273222/1/sokd10.pdf'},
#  {'name': 'eXtended Formal Ontology (XFO)',
#   'url': 'https://www.researchgate.net/profile/Robert_Allen5/publication/325141757_XFO_Toward_Programming_Rich_Semantic_Models/links/5afa473d458515c00b6bd24f/XFO-Toward-Programming-Rich-Semantic-Models.pdf?origin=publication_detail'},
#  {'name': 'FASTO Ontology (incorporates BFO, FHIR, CPG,and SSN)',
#   'url': 'https://bioportal.bioontology.org/ontologies/FASTO'},
#  {'name': 'Fission Yeast Phenotype Ontology (FYPO)',
#   'url': 'http://www.pombase.org/documentation/gene-page-phenotypes'},
#  {'name': 'Flower-Visiting Domain Ontology (FV), Known Flower-Visiting Group Domain Ontology (KFG), Flower-Visiting Behavior Application Ontology (FVB) and Observation-Date Application Ontology (OBD)',
#   'url': 'http://www.sciencedirect.com/science/article/pii/S157495411400082X'},
#  {'name': 'Food-Energy-Water Systems Ontology (FEWsONT)',
#   'url': 'https://www.liebertpub.com/doi/full/10.1089/ees.2018.0551'},
#  {'name': 'Flybase Drosophila Anatomy Ontology (DAO)',
#   'url': 'http://obofoundry.org/ontology/fbbt.html'},
#  {'name': 'Flybase Drosophila Phenotype Ontology (FYPO)',
#   'url': 'http://obofoundry.org/ontology/fypo.html'},
#  {'name': 'Feedback Intervention Ontology (FIO)',
#   'url': 'https://github.com/Display-Lab'},
#  {'name': 'Food Ontology (FoodOn)',
#   'url': 'http://obofoundry.org/ontology/foodon.html'},
#  {'name': 'Foundational Model of Anatomy (FMA)',
#   'url': 'http://obofoundry.org/ontology/fma.html'},
#  {'name': 'Framework for Semantic Workflow Composition in the Geology Domain',
#   'url': 'http://ceur-ws.org/Vol-2228/abstract6.pdf'},
#  {'name': 'Gastrointestinal Endoscopy Ontology (GIEO)',
#   'url': 'http://ceur-ws.org/Vol-833/paper36.pdf'},
#  {'name': 'Gender, Sex, and Sexual Orientation (GSSO) ontology',
#   'url': 'https://academic-oup-com.gate.lib.buffalo.edu/jamia/advance-article-abstract/doi/10.1093/jamia/ocaa061/5858296'},
#  {'name': 'General Information Model (GIM)',
#   'url': 'http://jamia.bmj.com/content/20/5/986.full'},
#  {'name': 'Gene Ontology (GO)',
#   'url': 'http://obofoundry.org/ontology/go.html'},
#  {'name': 'Gene Regulation Ontology (GRO)',
#   'url': 'https://ub-madoc.bib.uni-mannheim.de/35191/1/dissertation_beisswanger.pdf'},
#  {'name': 'Genomic Epidemiology Ontology (GenEpiO)',
#   'url': 'http://obofoundry.org/ontology/genepio.html'},
#  {'name': 'Genomic Feature and Variation Ontology (GFVO)',
#   'url': 'https://peerj.com/articles/933/'},
#  {'name': 'Geographical Entity Ontology (GEO)',
#   'url': 'http://www.obofoundry.org/ontology/geo.html'},
#  {'name': 'Global Electronic Health Record Ontology (G-EHR-O)',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S1569190X18301114'},
#  {'name': 'Gestalt',
#   'url': 'https://ieeexplore.ieee.org/abstract/document/6956738'},
#  {'name': 'Health Data Ontology Trunk (HDOT)', 'url': 'http://purl.org/hdot'},
#  {'name': 'Hemocomponents and Hemoderivatives Ontology (HEMONTO)',
#   'url': 'http://mba.eci.ufmg.br/downloads/ontobras-2013_paper1.pdf'},
#  {'name': 'Host Pathogen Interactions Ontology (HPO)',
#   'url': 'http://bioportal.bioontology.org/ontologies/HPIO?p=classes'},
#  {'name': 'Human Disease Ontology (DOID)',
#   'url': 'http://www.obofoundry.org/ontology/doid.html'},
#  {'name': 'Human Activity and Infrastructure Foundry (HAIF)',
#   'url': 'https://arxiv.org/ftp/arxiv/papers/1809/1809.09548.pdf'},
#  {'name': 'Human Experience Realist Ontology (HERO)',
#   'url': 'https://www.researchgate.net/publication/316557588_A_Human_Experience_Realist_Ontology_in_Basic_Formal_Ontology'},
#  {'name': 'Human Interaction Network Ontology (HINO)',
#   'url': 'http://arxiv.org/pdf/1311.3355.pdf'},
#  {'name': 'Human Physiology Simulation Ontology (HuPSON)',
#   'url': 'http://www.jbiomedsem.com/content/pdf/2041-1480-4-35.pdf'},
#  {'name': 'Infectious Disease Ontology',
#   'url': 'http://obofoundry.org/ontology/ido.html'},
#  {'name': 'Information Artifact Ontology (IAO)',
#   'url': 'http://obofoundry.org/ontology/iao.html'},
#  {'name': 'Information Security Domain (ISD) ontology',
#   'url': 'https://ieeexplore.ieee.org/abstract/document/8795392'},
#  {'name': 'Informed Consent Ontology (ICO)',
#   'url': 'http://ceur-ws.org/Vol-2285/ICBO_2018_paper_59.pdf'},
#  {'name': 'Innovative Capabilities of Additive Manufacturing (ICAM) Ontology',
#   'url': 'http://computingengineering.asmedigitalcollection.asme.org/article.aspx?articleid=2674329'},
#  {'name': 'Integrated Framework for Additively Manufactured Products (IFAMP) ontology',
#   'url': 'https://buffalo.app.box.com/v/integrating-ontologies'},
#  {'name': 'Interaction Network Ontology (INO)',
#   'url': 'http://www.cmpe.boun.edu.tr/~ozgur/papers/VDOS2014.pdf'},
#  {'name': 'International Classification of Diseases Ontology (ICDO)',
#   'url': 'no_link'},
#  {'name': 'Interdisciplinary Prostate Ontology Project (IPOP)',
#   'url': 'http://ipop.ontodev.com/'},
#  {'name': 'International Center for Food Ontology, Operability, Data and Semantics (IC-FOODS)',
#   'url': 'http://www.ic-foods.org/'},
#  {'name': 'uc_Eating', 'url': 'https://github.com/IC-FOODS/uc_Eating'},
#  {'name': 'uc_FoodDrugInteractionOntology',
#   'url': 'https://github.com/IC-FOODS/uc_FoodDrugInteractionOntology'},
#  {'name': 'uc_Milk', 'url': 'https://github.com/IC-FOODS/uc_Milk'},
#  {'name': 'uc_Processing', 'url': 'https://github.com/IC-FOODS/uc_Processing'},
#  {'name': 'uc_Sense', 'url': 'https://github.com/IC-FOODS/uc_Sense'},
#  {'name': 'Intervention Setting Ontology',
#   'url': 'https://wellcomeopenresearch.org/articles/5-124'},
#  {'name': 'Intracranial Aneurysm (ICA) Ontology',
#   'url': 'http://www.sciencedirect.com/science/article/pii/S1532046415000519'},
#  {'name': 'Knowledge Base Of Biomedicine (KaBOB)',
#   'url': 'http://www.biomedcentral.com/content/pdf/s12859-015-0559-3.pdf'},
#  {'name': 'Knowledge Object Reference Ontology (KORO)',
#   'url': 'https://onlinelibrary.wiley.com/doi/full/10.1002/lrh2.10054'},
#  {'name': 'Library of Integrated Network-based Cellular Signatures',
#   'url': 'https://bmcbioinformatics.biomedcentral.com/articles/10.1186/s12859-017-1981-5'},
#  {'name': 'Lipid Ontology',
#   'url': 'http://obofoundry.org/ontology/lipro.html'},
#  {'name': 'Literary Theme Ontology (LTO)',
#   'url': 'https://github.com/theme-ontology/lto'},
#  {'name': 'Machine Learning Schema (ML-Schema) ontology',
#   'url': 'https://openreview.net/pdf?id=B1e8MrXVxQ'},
#  {'name': 'Major histocompatibility complex (MHC) Restriction Ontology (MRO)',
#   'url': 'http://obofoundry.org/ontology/mro.html'},
#  {'name': 'Malaria Ontology (IDOMAL)',
#   'url': 'http://obofoundry.org/ontology/idomal.html'},
#  {'name': 'Manufacturing Service Description Language (MSDL) ontology',
#   'url': 'https://link.springer.com/chapter/10.1007/978-3-319-99707-0_40'},
#  {'name': 'Manufacturing Supply Chain Ontology (MSCO)',
#   'url': 'https://buffalo.box.com/s/rbapg73v4jq18dvw0rf2jnszndvnxmb0'},
#  {'name': 'Medication Adherence Behavior Ontology (MAB-Ontology)',
#   'url': 'https://scholarworks.iupui.edu/bitstream/handle/1805/17767/Sawesi_iupui_0104D_10326.pdf'},
#  {'name': 'Mental Disease Ontology (MFO-MD)',
#   'url': 'http://obofoundry.org/ontology/mfomd.html'},
#  {'name': 'Mental Functioning Ontology (MF)',
#   'url': 'http://obofoundry.org/ontology/mf.html'},
#  {'name': 'Microbiology Ontology (MicrO)',
#   'url': 'http://jbiomedsem.biomedcentral.com/articles/10.1186/s13326-016-0060-6'},
#  {'name': 'Minimum Information Model for Patient Safety (MIMPS)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/27139388'},
#  {'name': 'miRNAO',
#   'url': 'http://iwbbio.ugr.es/2014/papers/IWBBIO_2014_paper_103.pdf'},
#  {'name': 'Middle Layer Ontology for Clinical Care (MLOCC)',
#   'url': 'http://p-medicine.eu/project/wp-4'},
#  {'name': 'Military Ontology',
#   'url': 'http://basic-formal-ontology.org/publications#salmen'},
#  {'name': 'Military Scenario Ontology (MSO)',
#   'url': 'http://link.springer.com/article/10.1007/s10489-016-0834-7'},
#  {'name': 'MIRO and IRbase',
#   'url': 'http://www.plosntds.org/article/info:doi/10.1371/journal.pntd.0000465'},
#  {'name': 'Mission and Means Framework (MMF) Ontology',
#   'url': 'https://ieeexplore.ieee.org/abstract/document/8455742/'},
#  {'name': 'Modal Relation Ontology (MRO)',
#   'url': 'https://www.spiedigitallibrary.org/conference-proceedings-of-spie/10635/106350H/Problems-with-prescriptions--disentangling-data-about-actual-versus-prescribed/10.1117/12.2307718.short?SSO=1'},
#  {'name': 'Mode of Delivery (MoD) Ontology',
#   'url': 'https://wellcomeopenresearch.org/articles/5-125'},
#  {'name': 'Modular Environmental Modeling Ontology (MEMOn)',
#   'url': 'https://ieeexplore-ieee-org.gate.lib.buffalo.edu/abstract/document/8599597'},
#  {'name': 'Model for Clinical Information (MCI)',
#   'url': 'http://bmcmedinformdecismak.biomedcentral.com/articles/10.1186/s12911-016-0248-9'},
#  {'name': 'Mouse Pathology Ontology (MPATH)',
#   'url': 'http://obofoundry.org/ontology/mpath.html'},
#  {'name': 'Name Reaction Ontology (RXNO)',
#   'url': 'http://obofoundry.org/ontology/rxno.html'},
#  {'name': 'Nanoparticle Ontology (NPO)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20211274'},
#  {'name': 'Neomark Oral Cancer Ontology (NEOMARK4)',
#   'url': 'https://bioportal.bioontology.org/ontologies/NEOMARK4'},
#  {'name': 'NeuroPsychological Testing Ontology (NPT)',
#   'url': 'http://www.unbsj.ca/sase/csas/data/ws/icbo2013/papers/research/icbo2013_submission_31.pdf'},
#  {'name': 'Neuroscience Information Framework',
#   'url': 'http://www.neuinfo.org/'},
#  {'name': 'Neuroscience Information Framework Cell Ontology (NIFCELL)',
#   'url': 'https://bioportal.bioontology.org/ontologies/NIFCELL'},
#  {'name': 'Neuroscience Information Framework Dysfunction Ontology (NIFDYS)',
#   'url': 'https://bioportal.bioontology.org/ontologies/NIFDYS'},
#  {'name': 'Neuroscience Information Framework Standard Ontology (NIFSTD)',
#   'url': 'http://bioportal.bioontology.org/ontologies/NIFSTD'},
#  {'name': 'Neural Electromagnetic Ontologies (NEMO)',
#   'url': 'http://nemo.nic.uoregon.edu/'},
#  {'name': 'Nanoparticles Impact on Human Cell morphology Ontology (NIHCO)',
#   'url': 'https://www.bjbabe.ro/wp-content/uploads/2017/10/18_RODINO.pdf'},
#  {'name': 'Next-Generation Biobanking Ontology (NGBO)',
#   'url': 'http://ceur-ws.org/Vol-2180/paper-02.pdf'},
#  {'name': 'Next Generation Sequencing Ontology (NGSONTO)',
#   'url': 'https://github.com/lindenb/ngs-ontology'},
#  {'name': 'Non-Coding RNA Ontology (NCRO)',
#   'url': 'http://soc.southalabama.edu/~huang/papers/BIBM-15-1.pdf'},
#  {'name': 'NMR-Instrument Component of Metabolomics Investigations Ontology',
#   'url': 'http://bioportal.bioontology.org/ontologies/NMR?p=classes&conceptid=root'},
#  {'name': 'Ocular Disease Ontology (ODO)',
#   'url': 'http://www.unbsj.ca/sase/csas/data/ws/icbo2013/papers/posters/icbo2013_submission_67.pdf'},
#  {'name': 'OncoCL-KB', 'url': 'http://ceur-ws.org/Vol-1546/poster_65.pdf'},
#  {'name': 'OBR Scolio (scoliosis) ontology',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S0169260719300665'},
#  {'name': 'OntoAlign++',
#   'url': 'http://ceur-ws.org/Vol-1041/ontobras-2013_paper52.pdf'},
#  {'name': 'OntoForInfoScience',
#   'url': 'http://www2.marilia.unesp.br/revistas/index.php/bjis/article/viewFile/5426/3970'},
#  {'name': 'Ontologies for Representing Surgical Procedure Models (OntoSPM)',
#   'url': 'https://ontospm.univ-rennes1.fr/doku.php?id=ontology'},
#  {'name': 'Ontologized Minimum Information About BIobank data Sharing (OMIABIS)',
#   'url': 'http://obofoundry.org/ontology/omiabis.html'},
#  {'name': 'Ontology for Adverse Events (OAE)',
#   'url': 'http://obofoundry.org/ontology/oae.html'},
#  {'name': 'Ontology for Autism Spectrum Disorder',
#   'url': 'http://www.sciencedirect.com/science/article/pii/S1532046415001367'},
#  {'name': 'Ontology for Biobanking (OBIB)',
#   'url': 'http://obofoundry.org/ontology/obib.html'},
#  {'name': 'Ontology for Biomedical Investigations (OBI)',
#   'url': 'http://obofoundry.org/ontology/obi.html'},
#  {'name': 'Ontology of Card Sleights',
#   'url': 'https://arxiv.org/abs/1903.08523'},
#  {'name': 'Ontology of Chinese Medicine for Rheumatism (OCMR)',
#   'url': 'https://bioportal.bioontology.org/ontologies/OCMR'},
#  {'name': 'Ontology of Card Sleights',
#   'url': 'https://arxiv.org/abs/1903.08523'},
#  {'name': 'Ontology for Computable Eligibility Criteria - Hepatitis C Virus (OCEC-HCV)',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6371316/'},
#  {'name': 'Ontology for Dengue Fever (IDODEN)',
#   'url': 'http://journals.plos.org/plosntds/article?id=10.1371/journal.pntd.0003479'},
#  {'name': 'Ontology for Documentation of Variable/Data Source Selection (ODVDS)',
#   'url': 'http://ceur-ws.org/Vol-2427/SEPDA_2019_paper_15.pdf'},
#  {'name': 'Ontology for Drug Discovery Investigations (DDI)',
#   'url': 'http://purl.org/ddi/home'},
#  {'name': 'Ontology for Energy Investigations (OEI)',
#   'url': 'https://www.researchgate.net/publication/234128482_Facilitating_Knowledge_Sharing_and_Analysis_in_Energy_Informatics_with_the_Ontology_for_Energy_Investigations_%28OEI%29'},
#  {'name': 'Ontology of Electronics (OOE)',
#   'url': 'https://github.com/ontology-of-electronics'},
#  {'name': 'Ontology for Functionally Graded Materials (OFGM)',
#   'url': 'https://www.academia.edu/27922525/Development_of_a_Manufacturing_Ontology_for_Functionally_Graded_Materials'},
#  {'name': 'Ontology for General Medical Science (OGMS)',
#   'url': 'http://obofoundry.org/ontology/ogms.html'},
#  {'name': 'Ontology of Cardiovascular Drug Adverse Events (OCVDAE)',
#   'url': 'https://www.nature.com/articles/s41598-017-12580-4'},
#  {'name': 'Ontology of Genes and Genomes (OGG)',
#   'url': 'http://obofoundry.org/ontology/ogg.html'},
#  {'name': 'Ontology for Genes and Genomes - Mouse (OGG-MM)',
#   'url': 'http://www.ontobee.org/ontology/OGG-Mm'},
#  {'name': 'Ontology of Genetic Disease Investigations (OGDI)',
#   'url': 'https://bioportal.bioontology.org/ontologies/OGDI'},
#  {'name': 'Ontology for Genetic Interval (OGI)',
#   'url': 'http://bioportal.bioontology.org/ontologies/OGI?p=classes&conceptid=root'},
#  {'name': 'Ontology of Genetic Susceptibility Factor (OGSF)',
#   'url': 'http://obofoundry.org/ontology/ogsf.html'},
#  {'name': 'Ontology for Guiding Appropriate Antibiotic Prescribing',
#   'url': 'http://www.sciencedirect.com/science/article/pii/S1532046411001675'},
#  {'name': 'Ontology for Laparoscopic Surgeries (LapOntoSPM)',
#   'url': 'http://link.springer.com/article/10.1007/s11548-015-1222-1'},
#  {'name': 'Ontology of Microbial Phenotypes (OMP)',
#   'url': 'http://obofoundry.org/ontology/omp.html'},
#  {'name': 'Ontology for MIcroRNA Target Prediction (OMIT)',
#   'url': 'http://obofoundry.org/ontology/omit.html'},
#  {'name': 'Ontology for Newborn Screening and Translational Research (ONSTR)',
#   'url': 'http://code.google.com/p/onstr'},
#  {'name': 'Ontology for Next Generation Sequencing Experiments (NGS Ontology)',
#   'url': 'https://github.com/lindenb/ngs-ontology'},
#  {'name': 'OBDMR: An Ontology-Based Data Model for Railways',
#   'url': 'https://doi.org/10.1166/jctn.2020.8662'},
#  {'name': 'Ontology Based Clinical Decision Support System for Geriatrics',
#   'url': 'https://www.ingentaconnect.com/contentone/asp/jctn/2020/00000017/00000001/art00042'},
#  {'name': 'Ontology-Based Operational Emergency Response (POLARISC)',
#   'url': 'https://onlinelibrary.wiley.com/doi/pdf/10.1002/9781119564034.ch52'},
#  {'name': 'Ontology for Pain and Related Disability, Mental Health and Quality of Life (OPMQoL)',
#   'url': 'http://www.referent-tracking.com/RTU/?page=projects.phtml#opmqol'},
#  {'name': 'Ontology for Periodontitis (PERIO)',
#   'url': 'http://www.jbiomedsem.com/content/6/1/30'},
#  {'name': 'Ontology of Arthropod Circulatory Systems (OArCS)',
#   'url': 'http://obofoundry.org/ontology/oarcs.html'},
#  {'name': 'Ontology of Clinical Research (OCRe)',
#   'url': 'http://code.google.com/p/ontology-of-clinical-research/source/browse/trunk/Archive/OCRe-with-BFO.owl'},
#  {'name': 'Ontology for Nutritional Studies (ONS)',
#   'url': 'https://genesandnutrition.biomedcentral.com/articles/10.1186/s12263-018-0601-y'},
#  {'name': 'Ontology for Parasite LifeCycle (OPL)',
#   'url': 'http://obofoundry.org/ontology/opl.html'},
#  {'name': 'Ontology for Thoracentesis',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S0933365717301525'},
#  {'name': 'Ontology of Biological and Clinical Statistics (OBCS)',
#   'url': 'http://obofoundry.org/ontology/obcs.html'},
#  {'name': 'Ontology of Cancer Related Socialecological Variables (OCRSEV)',
#   'url': 'http://ceur-ws.org/Vol-2137/ws_ONCONTO_paper_3.pdf'},
#  {'name': 'Ontology for Cancer research variables (OCRV)',
#   'url': 'https://bmcmedinformdecismak.biomedcentral.com/articles/10.1186/s12911-018-0636-4'},
#  {'name': 'Ontology of Data Mining (OntoDM)', 'url': 'http://www.ontodm.com/'},
#  {'name': 'OntoDM Core',
#   'url': 'http://www.ontodm.com/doku.php?id=ontodm-core'},
#  {'name': 'Ontology of Datatypes (OntoDT)', 'url': 'http://www.ontodt.com/'},
#  {'name': 'Ontology of Experimental Variables and Values (OOEVV)',
#   'url': 'https://bioportal.bioontology.org/ontologies/OOEVV'},
#  {'name': 'Ontology for Information Science (OntoforInforScience)',
#   'url': 'https://www.researchgate.net/publication/299534658_OntoforInfoScience_a_detailed_methodology_for_construction_of_ontologies_and_its_application_in_the_blood_domain'},
#  {'name': 'Ontology of Medical Microbiology (OntoMic)',
#   'url': 'http://rali.iro.umontreal.ca/rali/sites/default/files/publis/Levreault-MSc.pdf'},
#  {'name': 'Ontology of Medically Related Social Entities (OMRSE)',
#   'url': 'http://obofoundry.org/ontology/omrse.html'},
#  {'name': 'Ontology of Organizational Structures ofTrauma systems and Trauma centers (OOSTT)',
#   'url': 'http://ceur-ws.org/Vol-1747/IT504_ICBO2016.pdf'},
#  {'name': 'Ontology of Social Participation (OPS)',
#   'url': 'http://arxiv.org/pdf/1501.02662.pdf'},
#  {'name': 'Ontology for Stem Cell Investigations (OSCI)',
#   'url': 'https://bmcbioinformatics.biomedcentral.com/articles/10.1186/s12859-019-2723-7'},
#  {'name': 'Ontology of Systems Engineering',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S1877050919307380'},
#  {'name': 'Ontology of Vaccine Adverse Events (OVAE)',
#   'url': 'http://obofoundry.org/ontology/ovae.html'},
#  {'name': 'Ontology-Based Data Access (OBDA)',
#   'url': 'http://www.sciencedirect.com.gate.lib.buffalo.edu/science/article/pii/S1570826815000165'},
#  {'name': 'Ontology Based Decision Support System for Tuberculosis Management and Control',
#   'url': 'https://www.researchgate.net/publication/312296048'},
#  {'name': 'Ontology-Based eXtensible Data Model (OBX)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20460173'},
#  {'name': 'Ontology-Driven Information System (ODIS)/Ontology-Driven Scenario Generator (ODSG)',
#   'url': 'http://www.sciencedirect.com/science/article/pii/S0952197615000913'},
#  {'name': 'Operational Environment Ontology (OEO)',
#   'url': 'https://jsou.libguides.com/ld.php?content_id=37534351'},
#  {'name': 'Oral Health and Disease Ontology (OHD)',
#   'url': 'http://obofoundry.org/ontology/ohd.html'},
#  {'name': 'Parasite Experiment Ontology (PEO)',
#   'url': 'http://bioportal.bioontology.org/ontologies/1335'},
#  {'name': 'Part-Focused Manufacturing Process Ontology (PMPO)',
#   'url': 'https://www.tandfonline.com/doi/abs/10.1080/0951192X.2017.1357837'},
#  {'name': 'Patient Safetry Categorial Structure (PS-CAST)',
#   'url': 'http://person.hst.aau.dk/ska/MIE2015/Papers/SHTI210-0160.pdf'},
#  {'name': 'Petrochemical Ontology',
#   'url': 'http://books.google.com/books?id=XYOBAusxPCcC&pg=PA27&lpg=PA27&dq=bfo+ontology&source=bl&ots=4nFYXvfaMy&sig=xq4BZAmY8DH0J5DMj3DE_xB4Fes&hl=en&ei=ZFpjStvADMaltgem27SyAg&sa=X&oi=book_result&ct=result&resnum=2'},
#  {'name': 'PGxO Pharmacogenomics Ontology',
#   'url': 'https://www.biorxiv.org/content/biorxiv/early/2018/08/13/390971.full.pdf'},
#  {'name': 'Phenotypic Quality Ontology (PaTO)',
#   'url': 'http://obofoundry.org/ontology/pato.html'},
#  {'name': 'Physics-Based Simulation Ontology (PSO-Physics and PSO-Sim)',
#   'url': 'https://www.tandfonline.com/doi/abs/10.1080/09544828.2019.1644301?journalCode=cjen20'},
#  {'name': 'Plant Experimental Assay Ontology (PEAO)',
#   'url': 'http://bioportal.bioontology.org/ontologies/PEAO'},
#  {'name': 'Plant Ontology (PO)',
#   'url': 'http://obofoundry.org/ontology/po.html'},
#  {'name': 'Plastic Rock Deformation (PRD) ontology',
#   'url': 'https://www-sciencedirect-com.gate.lib.buffalo.edu/science/article/pii/S0098300416308482'},
#  {'name': 'Pneumonia Ontology',
#   'url': 'https://www.researchgate.net/profile/Sabrina_Azzi/publication/328171801_Design_of_a_Pneumonia_Ontology_for_Diagnosis_Decision_Support_System/links/5bbcb970299bf1049b785032/Design-of-a-Pneumonia-Ontology-for-Diagnosis-Decision-Support-System.pdf'},
#  {'name': 'Ponte Ontology Platform (PONTE)',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S1569190X18301114'},
#  {'name': 'POLARISC Emergency Response System Ontology',
#   'url': 'http://idl.iscram.org/files/elmhadhbilinda/2018/1598_ElmhadhbiLinda_etal2018.pdf'},
#  {'name': 'Population and Community Ontology (PCO)',
#   'url': 'http://obofoundry.org/ontology/pco.html'},
#  {'name': 'Population Health Record (PopHR)',
#   'url': 'http://onlinelibrary.wiley.com/doi/10.1111/nyas.13271/full'},
#  {'name': 'Porifera Ontology (PORO)',
#   'url': 'http://obofoundry.org/ontology/poro.html'},
#  {'name': 'Precision Medicine Ontology (PMO)',
#   'url': 'http://www.aimspress.com/fileOther/PDF/MBE/mbe-17-04-227.pdf'},
#  {'name': 'Pre-Eclampsia Ontology (PEO)',
#   'url': 'http://journals.plos.org/plosone/article%3Fid%3D10.1371/journal.pone.0162828'},
#  {'name': 'PreOptique Platform for Integrated Pre-surgery Reports',
#   'url': 'https://jbiomedsem.biomedcentral.com/articles/10.1186/s13326-019-0197-1'},
#  {'name': 'Prescription of Drugs Ontology (PRDO)',
#   'url': 'https://pdfs.semanticscholar.org/7100/59ad86c5c2ef7a5b1430d30a8950a88aa319.pdf'},
#  {'name': 'PRISM: A Platform for Imaging inPrecision Medicine',
#   'url': 'https://ascopubs.org/doi/pdfdirect/10.1200/CCI.20.00001'},
#  {'name': 'Product Life Cycle Ontology for Additive Manufacturing',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S0166361518301647'},
#  {'name': 'Product Service System (PSS) Ontology',
#   'url': 'https://www.diversity-project.eu/wp-content/uploads/2017/07/Ontology-for-Colaborative-Development-of-Product-Service-Systems-Based-on-Basic-Formal-Ontology.pdf'},
#  {'name': 'Process and Observation Ontology (PO2)',
#   'url': 'https://www.sciencedirect.com/science/article/abs/pii/S0958694619300032'},
#  {'name': 'Proper Name Ontology (PNO)',
#   'url': 'https://code.google.com/p/proper-name-ontology'},
#  {'name': 'PROSPECT-IDR: Personalised Prediction of Infectious Disease Risk',
#   'url': 'http://www.tara.tcd.ie/bitstream/handle/2262/86059/Final%20Version.pdf?sequence=1'},
#  {'name': 'Protein-Ligand Interaction Ontology (PLIO)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC3106195'},
#  {'name': 'Protein Ontology (PRO)',
#   'url': 'http://obofoundry.org/ontology/pr.html'},
#  {'name': 'Provenir ontology for provenance modeling',
#   'url': 'http://cci.case.edu/cci/images/a/aa/Janus.pdf'},
#  {'name': 'Public Safety and Emergency Management (PS/EM) Communications Ontology',
#   'url': 'https://www.ida.org/-/media/feature/publications/p/pu/public-safety-and-emergency-management-communications-ontology/d-8583.ashx'},
#  {'name': 'QROWD urban traffic and mobility ontology',
#   'url': 'http://qrowd-project.trackglobe.es/wp-content/uploads/2019/11/D4.3-Linked-Data-Generation.docx.pdf'},
#  {'name': 'Quality of Service (QoS) Ontology',
#   'url': 'http://www.waset.org/publications/10000168'},
#  {'name': 'Relations Ontology (RO)',
#   'url': 'http://www.obofoundry.org/ontology/ro.html'},
#  {'name': 'Reliability Assessment for Assembly Stations (RAAS) Ontology',
#   'url': 'https://infoscience.epfl.ch/record/265908/files/'},
#  {'name': 'RNA Ontology (RnaO)',
#   'url': 'http://obofoundry.org/ontology/rnao.html'},
#  {'name': 'Rock Plastic Deformation (RPD) ontology',
#   'url': 'http://www.sciencedirect.com/science/article/pii/S0098300416308482'},
#  {'name': 'ROMAIN industrial maintenance ontology',
#   'url': 'https://www.researchgate.net/publication/332390146_ROMAIN_Towards_a_BFO_compliant_reference_ontology_for_industrial_maintenance'},
#  {'name': 'Role Ontology (ROLEO)',
#   'url': 'https://bioportal.bioontology.org/ontologies/ROLEO'},
#  {'name': 'Saliva Ontology (SALO)',
#   'url': 'http://code.google.com/p/bodily/source/browse/trunk/src/ontology/salo.owl'},
#  {'name': 'Schistosomiasis Process Ontology (IDOSCHISTO)',
#   'url': 'http://ceur-ws.org/Vol-1747/IP01_ICBO2016.pdf'},
#  {'name': 'Scientific Evidence and Provenance Information Ontology (SEPIO)',
#   'url': 'http://ceur-ws.org/Vol-1747/IT605_ICBO2016.pdf'},
#  {'name': 'Semantic Electronic Health Record (SEHR) Model',
#   'url': 'http://www.linked2safety-project.eu/node/44'},
#  {'name': 'Senselab Ontology',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20006477'},
#  {'name': 'Semanticscience Integrated Ontology (SIO)',
#   'url': 'http://code.google.com/p/semanticscience/wiki/SIO'},
#  {'name': 'Semantic LAminated Composites Knowledge management System (SLACKS)',
#   'url': 'http://dl.acm.org/citation.cfm?id=2580238'},
#  {'name': 'Sentinel: Platform for Semantic Enrichment of Social Media Streams',
#   'url': 'http://ieeexplore.ieee.org/document/8232468/'},
#  {'name': 'Sequence Ontology (SO)',
#   'url': 'http://obofoundry.org/ontology/so.html'},
#  {'name': 'Shop-Floor Digital Twin (DT) ontology',
#   'url': 'http://ceur-ws.org/Vol-2615/paper5.pdf'},
#  {'name': 'Situated and Interactive Multimodal Conversations',
#   'url': 'https://arxiv.org/pdf/2006.01460.pdf '},
#  {'name': 'Situation Awareness Ontology (SAO)',
#   'url': 'http://link.springer.com/article/10.1007/s10489-016-0834-7'},
#  {'name': 'SMART Protocols',
#   'url': 'http://vocab.linkeddata.es/SMARTProtocols'},
#  {'name': 'Sketch Map Ontology',
#   'url': 'https://www.tandfonline.com/doi/abs/10.1080/13658816.2017.1309043?journalCode=tgis20'},
#  {'name': 'Skin Physiology Ontology (SPO)',
#   'url': 'https://bioportal.bioontology.org/ontologies/SPO'},
#  {'name': 'Sleep Domain Ontology (SDO)',
#   'url': 'http://bimib.disco.unimib.it/images/7/7c/SSFW09_Arabandi_SleepOntology.pdf'},
#  {'name': 'SNOMED CT (SCT) Standard Ontology',
#   'url': 'https://bmcmedinformdecismak.biomedcentral.com/articles/10.1186/s12911-018-0651-5'},
#  {'name': 'Social Psychology Ontology (SPO)',
#   'url': 'https://ubir.buffalo.edu/xmlui/handle/10477/79440'},
#  {'name': 'Software, Disabilities and Competences Ontology (SODIC)',
#   'url': 'http://dspace.ucuenca.edu.ec/bitstream/123456789/28548/1/Trabajo%20de%20Titulaci%C3%B3n.pdf'},
#  {'name': 'Software Ontology (SWO)',
#   'url': 'http://jbiomedsem.biomedcentral.com/articles/10.1186/2041-1480-5-25'},
#  {'name': 'Spatial Graph Adapter (SGA) Ontology Design Pattern',
#   'url': 'http://www.semantic-web-journal.net/system/files/swj1582.pdf'},
#  {'name': 'Spatiotemporal Ontology for the Administrative Units of Switzerland (SONADUS)',
#   'url': 'http://www.geo.uzh.ch/dam/jcr:6c3c9ef3-6bcd-4300-86e4-9de07d3f6f37/msc_felix_gantner_2011.pdf'},
#  {'name': 'Special Nuclear Materials Detection Ontology (SNM-DO)',
#   'url': 'http://ceur-ws.org/Vol-808/STIDS2011_CR_P2_WardEtAl.pdf'},
#  {'name': 'Statistics Ontology (STATO)',
#   'url': 'http://obofoundry.org/ontology/stato.html'},
#  {'name': 'STATO-LMM Linear Mixed Model Ontology',
#   'url': 'https://www.nature.com/articles/s41597-020-0409-7'},
#  {'name': 'Subcellular Anatomy Ontology (SAO)',
#   'url': 'http://obofoundry.org/ontology/sao.html'},
#  {'name': 'Suggested Ontology for Pharmacogenomics (SO-Pharm)',
#   'url': 'http://obofoundry.org/ontology/sopharm.html'},
#  {'name': 'Surface Water Ontology (SWO)',
#   'url': 'https://www.usgs.gov/media/files/surface-water-ontology'},
#  {'name': 'Survey Ontology',
#   'url': 'https://www.scitepress.org/papers/2017/65827/65827.pdf'},
#  {'name': 'Taxonomy for Rehabilitation of Knee Conditions (TRAK)',
#   'url': 'http://users.cs.cf.ac.uk/I.Spasic/trak'},
#  {'name': 'Time Event Ontology (TEO)',
#   'url': 'https://bioportal.bioontology.org/ontologies/TEO'},
#  {'name': 'Toxic Process Ontology (TXPO)',
#   'url': 'http://www.obofoundry.org/ontology/txpo.html'},
#  {'name': 'Trade-Space Analysis Tool for Constellations (TAT-C) ontology',
#   'url': 'https://arc.aiaa.org/doi/abs/10.2514/6.2019-1032'},
#  {'name': 'Translational Medicine Ontology (TMO)',
#   'url': 'http://esw.w3.org/topic/HCLSIG/PharmaOntology'},
#  {'name': 'Transportation System Ontology',
#   'url': 'http://www.ontobee.org/ontology/TSO'},
#  {'name': 'The Trope Ontology',
#   'url': 'https://www.mdpi.com/2409-9287/4/3/40'},
#  {'name': 'Tumour-Node-Metastasis Ontology (TNM-O)',
#   'url': 'https://jbiomedsem.biomedcentral.com/articles/10.1186/s13326-016-0106-9'},
#  {'name': '(Microbial) Typing Ontology (TypOn)',
#   'url': 'http://www.phyloviz.net/typon'},
#  {'name': 'United Nations SDG (Sustainable Development Goals) Ontology Framework',
#   'url': 'https://iswc2017.ai.wu.ac.at/wp-content/uploads/papers/MainProceedings/179.pdf'},
#  {'name': 'United Nations System Document Ontology (ONTO-UNDO)',
#   'url': 'https://unsceb-hlcm.github.io/onto-undo/'},
#  {'name': 'Universal Core Semantic Layer',
#   'url': 'http://sunsite.informatik.rwth-aachen.de/Publications/CEUR-WS/Vol-555/paper5.pdf'},
#  {'name': 'UMass Engineering Core Ontologies',
#   'url': 'https://www.mdpi.com/2079-8954/6/4/46/pdf'},
#  {'name': 'Vaccination Informed Consent Ontology (VICO)',
#   'url': 'http://jbiomedsem.biomedcentral.com/articles/10.1186/s13326-016-0062-4'},
#  {'name': 'Volcanism Ontology (VO)',
#   'url': 'https://scholarworks.gsu.edu/cgi/viewcontent.cgi?article=1124&context=geosciences_theses'},
#  {'name': 'Vaccine Ontology (VO)',
#   'url': 'http://obofoundry.org/ontology/vo.html'},
#  {'name': 'Visualized Emotion Ontology (VEO)',
#   'url': 'https://bmcmedinformdecismak.biomedcentral.com/articles/10.1186/s12911-018-0634-6'},
#  {'name': 'Vital Sign Ontology (VSO)',
#   'url': 'http://ontology.buffalo.edu/smith/articles/Vital_Sign_Ontology.pdf'},
#  {'name': 'VIVO Ontology',
#   'url': 'https://openreview.net/forum?id=SkgyVa-coV'},
#  {'name': 'Volcanism Ontology (VO)',
#   'url': 'https://scholarworks.gsu.edu/cgi/viewcontent.cgi?article=1124&context=geosciences_theses'},
#  {'name': 'Xenopus Anatomy Ontology (XAO)',
#   'url': 'http://obofoundry.org/ontology/xao.html'},
#  {'name': 'yOWL', 'url': 'http://www2007.org/workshops/paper_130.pdf'},
#  {'name': 'Air Force Research Laboratory, Rome, New York',
#   'url': 'http://www.wpafb.af.mil/afrl'},
#  {'name': 'Allotrope Foundation: Rethinking Scientific Data',
#   'url': 'https://www.allotrope.org/'},
#  {'name': 'AstraZeneca', 'url': 'http://www.astrazeneca.com/'},
#  {'name': 'Autodesk', 'url': 'https://www.autodesk.com/'},
#  {'name': 'Bentley Software, Inc.', 'url': 'no_link'},
#  {'name': 'Berkeley Bioinformatics Open-Source Projects (BBOP)',
#   'url': 'http://berkeleybop.org/'},
#  {'name': 'Biomedical Knowledge Engineering Lab at Seoul National University (SNU BiKE)',
#   'url': 'http://bike.snu.ac.kr/'},
#  {'name': 'Brain Operation Database (BODB)',
#   'url': 'http://neuroinformatics.usc.edu/resources/brain-operation-database-bodb'},
#  {'name': 'Center for e-Design', 'url': 'http://www.edesign.ecs.umass.edu/'},
#  {'name': 'CTSAconnect', 'url': 'http://www.ctsaconnect.org/'},
#  {'name': 'CUBRC',
#   'url': "http://www.cubrc.org/index.php/data-science-and-information-fusion/ontology/'94"},
#  {'name': 'Darwin Core (DwC)', 'url': 'http://rs.tdwg.org/dwc'},
#  {'name': 'DOQS', 'url': 'http://www.doqs.com/'},
#  {'name': 'DSpace at NTNUA',
#   'url': 'http://dspace.lib.ntua.gr/handle/123456789/3046'},
#  {'name': 'Dumontier Lab',
#   'url': 'http://dumontierlab.com/index.php?page=ontologies'},
#  {'name': 'eagle-i Research Resource Ontology',
#   'url': 'http://obofoundry.org/ontology/ero.html'},
#  {'name': 'Ecole polytechnique federale de Lausanne (EPFL)',
#   'url': 'https://people.epfl.ch/cgi-bin/people?id=105551&lang=en&cvlang=en'},
#  {'name': 'Elsevier Smart Content Strategy',
#   'url': 'http://www.elsevier.com/wps/find/authored_newsitem.cws_home/companynews05_01849'},
#  {'name': 'eNanoMapper', 'url': 'http://www.enanomapper.net/'},
#  {'name': 'EuPath Ontology',
#   'url': 'https://bioportal.bioontology.org/ontologies/EUPATH/?p=summary'},
#  {'name': 'Extensible Neuroimaging Archive Toolkit (XNAT)',
#   'url': 'http://www.aifb.kit.edu/images/e/e5/Sfb-infrastructure-spie2016.pdf'},
#  {'name': 'Good Ontology Design (GoodOD)',
#   'url': 'http://portal.uni-freiburg.de/imbi/sections/mi-en/projects/goodod?set_language=en'},
#  {'name': 'HIGHFLEET', 'url': 'http://www.highfleet.com/'},
#  {'name': 'Influenza Research Database (IRD)',
#   'url': 'http://www.fludb.org/brc/home.spg?decorator=influenza'},
#  {'name': 'Institute for Defense Analysis', 'url': 'http://www.ida.org/'},
#  {'name': 'INRIA Lorraine Research Unit',
#   'url': 'http://www.inria.fr/inria/organigramme/fiche_ur-lor.en.html'},
#  {'name': 'Japan Advanced Institute of Science and Technology (JAIST)',
#   'url': 'http://www.jaist.ac.jp/ks/english/'},
#  {'name': 'Johns Hopkins University Applied Physics Lab',
#   'url': 'http://www.jhuapl.edu/'},
#  {'name': 'Kobe University, Graduate School of Medicine, Department of Sociomedical Informatics',
#   'url': 'http://www.med.kobe-u.ac.jp/'},
#  {'name': 'L3 Data Tactics Corporation',
#   'url': 'https://www.data-tactics.com/'},
#  {'name': 'Language and Computing', 'url': 'http://www.landcglobal.com/'},
#  {'name': 'libryo', 'url': 'https://libryo.com/'},
#  {'name': 'Medical University Graz - Institute of Medical Informatics, Statistics and Documentation',
#   'url': 'http://user.medunigraz.at/stefan.schulz'},
#  {'name': 'National Center for Multi-Source Information Fusion',
#   'url': 'http://www.infofusion.buffalo.edu/'},
#  {'name': 'Ontology Research Group', 'url': 'http://org.buffalo.edu/'},
#  {'name': 'Ontology, Logic and Technology Unit',
#   'url': 'http://org.buffalo.edu/rarp/OLT%20Unit.html'},
#  {'name': 'Qualitative Spatiotemporal Reasoning Unit',
#   'url': 'http://org.buffalo.edu/rarp/QSRUnit%20Page.html'},
#  {'name': 'Referent Tracking Unit',
#   'url': 'http://org.buffalo.edu/RTU/index.html'},
#  {'name': 'SAIC', 'url': 'www.saic.com/'},
#  {'name': 'Thermo Fisher Scientific',
#   'url': 'https://www.thermofisher.com/us/en/home.html'},
#  {'name': 'TRADOC Operational Environment Center',
#   'url': 'www.tradoc.army.mil/g2/oetsc/videoTBOC_flv.aspx'},
#  {'name': 'OntoCAT', 'url': 'http://www.ontocat.org/'},
#  {'name': 'OntoCOG', 'url': 'http://ontobat.hegroup.org/'},
#  {'name': 'OntoMaton', 'url': 'http://isa-tools.org/'},
#  {'name': 'openEHR',
#   'url': 'http://www.openehr.org/wiki/display/ontol/Ontologies+Home'},
#  {'name': 'Open Access Journals Integrated service System Project (GoOA)',
#   'url': 'http://bioportal.bioontology.org/projects/PDOLAS'},
#  {'name': 'Open PHACTS', 'url': 'http://www.openphacts.org/'},
#  {'name': 'OSTHUS', 'url': 'https://www.youtube.com/watch?v=WKuK2G-NUk8'},
#  {'name': 'Praxis',
#   'url': 'http://www.infor-med.com/downloads/articles_downloads/Praxis_EMR_SUNY_Interoperability_Project.pdf'},
#  {'name': 'REMINE',
#   'url': 'http://www.ramit.be/index.cfm?objectid=D06D28B6-1143-DEB7-74B2690FF1EC5110'},
#  {'name': 'Saitama University - Faculty of Liberal Arts',
#   'url': 'http://www.saitama-u.ac.jp/'},
#  {'name': 'Science Applications International Corporation (SAIC)',
#   'url': 'https://www.saic.com'},
#  {'name': 'Science Commons', 'url': 'http://www.sciencecommons.org/'},
#  {'name': 'Securboration', 'url': 'http://www.securboration.com/'},
#  {'name': 'Skeletome',
#   'url': 'http://itee.uq.edu.au/~eresearch/projects/skeletome'},
#  {'name': 'SMART Protocols',
#   'url': 'http://www.swat4ls.org/wp-content/uploads/2015/10/SWAT4LS_2015_paper_15.pdf'},
#  {'name': 'U.S. Geological Survey (USGS) - Center of Excellence for Geospatial Information Science (CEGIS)',
#   'url': 'http://cegis.usgs.gov/ontology.html'},
#  {'name': 'University of Arkansas, Biomedical Informatics, Medical Center, Little Rock',
#   'url': 'http://www.uams.edu/cctr/infocore/infocore.asp'},
#  {'name': 'University of Augsburg - Computer Science - Software Methodologies for Distributed Systems',
#   'url': 'http://www.informatik.uni-augsburg.de/en/chairs/swt/ds'},
#  {'name': 'University of South Alabama - School of Computing - South Biomedical Informatics (SBI) Research Group',
#   'url': 'http://biomedical.cis.usouthal.edu/'},
#  {'name': 'University of Texas Southwestern Medical Center',
#   'url': 'http://www.utsouthwestern.edu/'},
#  {'name': 'University of Washington - Structural Informatics Group (SIG)',
#   'url': 'http://sig.biostr.washington.edu/'},
#  {'name': 'Virus Pathogen Resource (ViPR)',
#   'url': 'http://www.viprbrc.org/brc/home.do?decorator=vipr'},
#  {'name': 'VIVO', 'url': 'http://vivoweb.org/'},
#  {'name': 'Volley: AI-powered learning hub', 'url': 'http://volley.com/'},
#  {'name': 'Semantic Systems Engineering Ontology (SESO)',
#   'url': 'https://indico.esa.int/event/386/contributions/6243/attachments/4281/6391/1435%20-%20using%20semantic%20systems%20engineering%20techniques%20to%20verify%20the%20large%20aperture%20space%20telescope%20mission%20%E2%80%93%20current%20status.pdf'},
#  {'name': 'Rescue Ontology (ResOnt)',
#   'url': 'https://www.researchgate.net/profile/Samer-Chehade-2/publication/353571839'},
#  {'name': 'CybOnto (Cognitive Digital Twin Ontology for CyberSecurity)',
#   'url': 'https://arxiv.org/pdf/2108.00551.pdf'},
#  {'name': 'GeoCore Geology Ontology',
#   'url': 'https://www.lume.ufrgs.br/bitstream/handle/10183/225741/001129935.pdf'},
#  {'name': 'Data Use Ontology (DUO)',
#   'url': 'http://www.obofoundry.org/ontology/duo.html'},
#  {'name': 'Graphs, Objects, Points, Properties, Roles, and Relationships Ontology (GOPPRRE)',
#   'url': 'https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=9534721'},
#  {'name': 'RFID System Configuration Ontology (RFID SCO)',
#   'url': 'https://doi.org/10.1017/S0269888921000096'},
#  {'name': 'CICCONETO et al., 2020; CICCONETO, 2021) spatial relations ontology',
#   'url': 'no_link'},
#  {'name': 'Ocular Immune-Mediated Inflammatory Diseases Ontology (OcIMIDo)',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S001048252100336X'},
#  {'name': 'GeoReservoir Ontology',
#   'url': 'https://doi.org/10.1016/j.cageo.2021.105005'},
#  {'name': 'Spatial Relation Ontology',
#   'url': 'http://ceur-ws.org/Vol-2728/paper3.pdf'},
#  {'name': 'Value Stream Mapping (VSM) Ontology',
#   'url': 'https://era.library.ualberta.ca/items/5ad997be-0f3d-4456-8108-b3c69d851a98/view/060e801a-92a5-44ac-ba8a-0a00ab22765e/Abdelghani_Mohammad_202101_PhD.pdf'},
#  {'name': 'Addiction Ontology (AO)',
#   'url': 'https://www.taylorfrancis.com/chapters/edit/10.4324/9781003032762-46/addiction-ontology-unify-competing-conceptualizations-addiction-robert-kelly-janna-hastings-robert-west'},
#  {'name': 'Agronomy Ontology (AGRO)',
#   'url': 'https://bigdata.cgiar.org/resources/agronomy-ontology/'},
#  {'name': 'Anatomy of the Insect Skeleto-Muscular system ontology (AISM)',
#   'url': 'https://www.preprints.org/manuscript/202201.0254/v1'},
#  {'name': 'ARIES (Arkansas Imaging Enterprise System) Knowledge Graph',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8866818/'},
#  {'name': 'Asset Management Ontology (AMODO)',
#   'url': 'https://www.sciencedirect.com/science/article/abs/pii/S2452414X21000947'},
#  {'name': 'Biomedical Study - Lifecycle Management (BMS-LM) core ontology',
#   'url': 'https://doi.org/10.1016/j.jbi.2022.104007'},
#  {'name': 'Case Based Reasoning (CBR) Ontology',
#   'url': 'https://doi.org/10.1109/ISSE51541.2021.9582535'},
#  {'name': 'CIDO-COVID-19',
#   'url': 'https://ieeexplore.ieee.org/abstract/document/9629555'},
#  {'name': 'Collaborative Learning Healthcare Systems (CLHS) ontology',
#   'url': 'https://onlinelibrary.wiley.com/doi/full/10.1002/lrh2.10306'},
#  {'name': 'The Common Rule Ontology (CRO)',
#   'url': 'https://github.com/CRO-ontology/CRO'},
#  {'name': 'Crop Planning and Production Process Ontology (C3PO)',
#   'url': 'http://ceur-ws.org/Vol-2969/paper12-IFOW.pdf'},
#  {'name': 'Cybonto Cyber Security Ontology',
#   'url': 'https://arxiv.org/abs/2108.00551'},
#  {'name': 'Dairy Cattle Performance Ontology (DCPO)',
#   'url': 'http://ceur-ws.org/Vol-3073/paper3.pdf'},
#  {'name': 'Data Integration Aggregated Model for Nuclear Deployment (DIAMOND)',
#   'url': 'https://link.springer.com/chapter/10.1007/978-3-030-82083-1_2'},
#  {'name': 'EifcOWL (Enhanced Ontology for the Construction Industry Foundation Classes)',
#   'url': 'https://content.iospress.com/articles/applied-ontology/ao210254'},
#  {'name': 'ENVOn (3D shape ontology)',
#   'url': 'http://www.semantic-web-journal.net/system/files/swj3043.pdf'},
#  {'name': 'Epilepsy Ontology (EPIO)',
#   'url': 'https://www.researchsquare.com/article/rs-1259791/v1'},
#  {'name': 'Financial Documents Ontology (FIN)',
#   'url': 'http://ceur-ws.org/Vol-2969/paper57-SoLEE.pdf'},
#  {'name': 'Food Recipe Ingredient Substitution Ontology (FRISO)',
#   'url': 'https://doi.org/10.3390/s22031095'},
#  {'name': 'GeoReservoir ontology for deep-marine depositional system geometry',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S0098300421002880'},
#  {'name': 'HERMES 4D Printing Ontology',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S0264127521007486'},
#  {'name': 'Interoperative Neuromonitoring Ontology (IOM)',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/35062118/'},
#  {'name': 'Maintenance Activity Reference Ontology',
#   'url': 'http://www.semantic-web-journal.net/system/files/swj3067.pdf'},
#  {'name': 'MOCA (Multi-attribute Ontology-based Criticality Analysis)',
#   'url': 'https://link.springer.com/article/10.1007/s43684-022-00021-7'},
#  {'name': 'Model for Describing Insect Anatomical Structures (MoDIAS)',
#   'url': 'https://www.preprints.org/manuscript/202201.0254/v1'},
#  {'name': 'Ontology for Nutritional Epidemiology (ONE)',
#   'url': 'https://obofoundry.org/ontology/one.html'},
#  {'name': 'Ontology of Hemotherapy (HEMONTO)',
#   'url': 'https://1library.net/document/q5946wgz-hemocomponents-hemoderivatives-ontology-hemonto-ontology-blood-components.html'},
#  {'name': 'Ontology of Commercial Exchange (OCE)',
#   'url': 'https://philarchive.org/archive/MERCCC'},
#  {'name': 'Open Model-Based Engineering Environment (OpenMBEE)',
#   'url': 'https://link.springer.com/chapter/10.1007/978-3-030-82083-1_56'},
#  {'name': 'Organization Ontology Based on ROR',
#   'url': 'https://figshare.com/articles/presentation/An_Organization_Ontology_based_on_ROR/14839359'},
#  {'name': 'Semantic Reference Model for Individualization of Information Processes',
#   'url': 'https://www.mdpi.com/2079-9292/10/20/2523'},
#  {'name': 'Smart Ultrasound in Obstetrics and Gynecology (SUOG) Ontology',
#   'url': 'https://icbo2021.inf.unibz.it/wp-content/uploads/2021/09/169_S1_ElGhosh_paper_8.pdf'},
#  {'name': 'Space Domain Ontologies (SDO)',
#   'url': 'https://philpapers.org/rec/COXTSD-2'},
#  {'name': 'Space Object Ontology (SOO)',
#   'url': 'https://ieeexplore.ieee.org/document/7527882'},
#  {'name': 'Supply Chain Traceability Ontology',
#   'url': 'https://asmedigitalcollection.asme.org/computingengineering/article-abstract/22/5/051002/1139465/Enabling-Traceability-in-Agri-Food-Supply-Chains'},
#  {'name': 'Traditional Chinese Drugs Ontology (TCDO)',
#   'url': 'https://www.hindawi.com/journals/ecam/2021/6637810/'},
#  {'name': 'Xenopus Phenotype Ontology (XPO)',
#   'url': 'https://www.biorxiv.org/content/biorxiv/early/2021/11/13/2021.11.12.467727.full.pdf'},
#  {'name': 'ZEMELA Intelligent Agriculture Platform',
#   'url': 'https://ieeexplore.ieee.org/abstract/document/9627248'},
#  {'name': 'Iranian Traditional Medicine General Ontology (IrGO)',
#   'url': 'https://jbiomedsem.biomedcentral.com/articles/10.1186/s13326-021-00237-1'},
#  {'name': "Alzheimer's Disease Diagnosis Ontology (ADDO)",
#   'url': 'https://ma.x-mol.com/paper/1366901247607140352'}]

# %%
for user in users: 
    if user["url"] == "no_link": 
        del user['url']

# %%
users
# Out:
# [{'name': 'ACGT Master Ontology (ACGT MO)',
#   'url': 'http://bioportal.bioontology.org/ontologies/ACGT-MO'},
#  {'name': 'Additive Manufacturing Ontology (AMO)',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S0166361518301647'},
#  {'name': 'Adolescent Depression Ontology (ADO)',
#   'url': 'https://www.jmir.org/article/viewFile/jmir_v19i7e259/2'},
#  {'name': 'African Wildlife Ontology (AWO)',
#   'url': 'https://arxiv.org/pdf/1905.09519.pdf'},
#  {'name': 'Agronomic Linked Data (AgroLD)',
#   'url': 'https://www.biorxiv.org/content/10.1101/325423v3.full.pdf'},
#  {'name': 'Algorithm-Implementation-Execution Ontology Design Pattern',
#   'url': 'http://ontologydesignpatterns.org/wiki/images/4/41/WOP2016_paper_07.pdf'},
#  {'name': 'Animals in Context Ontology (ACO)',
#   'url': 'http://ceur-ws.org/Vol-897/session1-paper04.pdf'},
#  {'name': 'Autism-DSM-ADI-R Ontology (ADAR)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/26151311'},
#  {'name': 'Alzheimer Disease Ontology (ADO)',
#   'url': 'http://www.sciencedirect.com/science/article/pii/S155252601300085X'},
#  {'name': 'Adverse Event Reporting Ontology (AERO)',
#   'url': 'http://purl.obolibrary.org/obo/aero'},
#  {'name': 'AFO Foundational Ontology',
#   'url': 'http://esw.w3.org/topic/HCLS/AFO_Foundational_Ontology'},
#  {'name': 'Actionable Intelligence Retrieval System (AIRS)',
#   'url': 'http://ncor.buffalo.edu/ontologies/AIRS_Ontologies.pdf'},
#  {'name': 'Antimicrobial-Microorganism Ontology',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S1532046411001675'},
#  {'name': 'Apollo Structured Vocabulary (Apollo-SV)',
#   'url': 'http://jbiomedsem.biomedcentral.com/articles/10.1186/s13326-016-0092-y'},
#  {'name': 'Bacterial Clinical Infectious Diseases Ontology (BCIDO)',
#   'url': 'http://www.sciencedirect.com/science/article/pii/S1532046415001549'},
#  {'name': 'Behavior Perspective Model (BPM)',
#   'url': 'https://books.google.com/books?hl=en&lr=lang_en&id=u8xmCgAAQBAJ&oi=fnd&pg=PA366&ots=p35Xg1rqn0&sig=6VibTWt8Y6mpTSyPFFc68xHePDw#v=onepage&q&f=false'},
#  {'name': 'Bank Ontology', 'url': 'http://world-comp.org/p2011/IKE5165.pdf'},
#  {'name': 'Battle Management Ontology (BMO)',
#   'url': 'http://link.springer.com/article/10.1007/s10489-016-0834-7'},
#  {'name': 'Behavior Change Intervention Ontology (BCIO)',
#   'url': 'https://wellcomeopenresearch.org/articles/5-123'},
#  {'name': 'Beta Cell Genomics Application Ontology (BCGO)',
#   'url': 'http://obofoundry.org/ontology/bcgo.html'},
#  {'name': 'BioAssay Ontology', 'url': 'http://www.bioassayontology.org/'},
#  {'name': 'Bioinformatics Web Service Ontology (OBIWS)',
#   'url': 'http://code.google.com/p/obi-webservice'},
#  {'name': 'Biological Collections Ontology (BCO)',
#   'url': 'http://obofoundry.org/ontology/bco.html'},
#  {'name': 'Biomedical Ethics Ontology',
#   'url': 'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC2725426/'},
#  {'name': 'Biomedical Grid Terminology (BiomedGT, retired)',
#   'url': 'https://wiki.nci.nih.gov/pages/viewpage.action?pageId=63996208'},
#  {'name': 'Bio-Knowledge Network Ontology (BioKNO)',
#   'url': 'https://www.degruyter.com/view/journals/jib/15/3/article-20180023.xml'},
#  {'name': 'Biomimetic Ontology',
#   'url': 'http://link.springer.com/chapter/10.1007/978-3-319-31782-3_13'},
#  {'name': 'BioTop', 'url': 'http://ebooks.iospress.nl/publication/46379'},
#  {'name': 'BioTopLite2', 'url': 'http://purl.org/biotop/btl2.owl'},
#  {'name': 'BIRNLex',
#   'url': 'https://bioportal.bioontology.org/ontologies/BIRNLEX'},
#  {'name': 'Blood Ontology (BLO)', 'url': 'http://mba.eci.ufmg.br/BLO'},
#  {'name': 'Body Fluids Ontology (BFLO)',
#   'url': 'http://ontology.buffalo.edu/smith/articles/BFLO_ICBO_2011.pdf'},
#  {'name': 'Bone Dysplasia Ontology (BDO)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC3338382/'},
#  {'name': 'Cancer Cell Ontology (OncoCL)',
#   'url': 'http://ceur-ws.org/Vol-1060/icbo2013_submission_75.pdf'},
#  {'name': 'Categorical Temporal Phenomenology',
#   'url': 'http://www.roentgensemiotics.net/phenomenology.htm'},
#  {'name': 'Cancer Chemoprevention Ontology (CanCo)',
#   'url': 'http://bioportal.bioontology.org/ontologies/CANCO'},
#  {'name': 'Cardiovascular Disease Ontology (CVDO)',
#   'url': 'https://www.ebi.ac.uk/ols/ontologies/cvdo'},
#  {'name': 'Cell Behavior Ontology (CBO)',
#   'url': 'http://cbo.biocomplexity.indiana.edu/'},
#  {'name': 'Cell Culture Ontology (CCONT)',
#   'url': 'https://bioportal.bioontology.org/ontologies/CCONT'},
#  {'name': 'Cell Cycle Ontology',
#   'url': 'http://genomebiology.com/2009/10/5/R58'},
#  {'name': 'Cell Expression, Localization, Development and Anatomy Ontology (CELDA)',
#   'url': 'http://nar.oxfordjournals.org.gate.lib.buffalo.edu/content/early/2013/12/03/nar.gkt1264.full.pdf'},
#  {'name': 'Cell Line Ontology (CLO)',
#   'url': 'http://obofoundry.org/ontology/clo.html'},
#  {'name': 'Cell Ontology', 'url': 'http://obofoundry.org/ontology/cl.html'},
#  {'name': 'Cellular Microscopy Phenotype Ontology (CMPO)',
#   'url': 'http://jbiomedsem.biomedcentral.com/articles/10.1186/s13326-016-0074-0'},
#  {'name': 'Chemical Analysis Ontology (CAO)',
#   'url': 'http://champ-project.org/'},
#  {'name': 'Chemical Entities of Biological Interest (ChEBI)',
#   'url': 'http://www.ebi.ac.uk/chebi'},
#  {'name': 'Chemical Information Ontology (CHEMINF)',
#   'url': 'http://obofoundry.org/ontology/cheminf.html'},
#  {'name': 'Chemical Methods Ontology (CHMO)',
#   'url': 'http://obofoundry.org/ontology/chmo.html'},
#  {'name': 'CHRONIOUS Ontology Suite',
#   'url': 'http://ceur-ws.org/Vol-833/paper22.pdf'},
#  {'name': 'Cigarette Smoke Exposure Ontology (CSEO)',
#   'url': 'http://www.jbiomedsem.com/content/pdf/2041-1480-5-31.pdf'},
#  {'name': 'Clinical Data Integration Model (CDMO)',
#   'url': 'https://www.ncbi.nlm.nih.gov/pubmed/24954896'},
#  {'name': 'Clinical Narrative Temporal Relation Ontology (CNTRO)',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3248753/?'},
#  {'name': 'Clinical Trial Protocol Ontology (CTP-O)',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S1569190X18301114'},
#  {'name': 'Clusters of Orthologous Groups (COG) Analysis Ontology (CAO)',
#   'url': 'https://bioportal.bioontology.org/ontologies/CAO'},
#  {'name': 'Cognition-Guided Surgery (CGS) Ontology',
#   'url': 'http://archiv.ub.uni-heidelberg.de/volltextserver/22579'},
#  {'name': 'Cognitive Paradigm Ontology (COGPO)', 'url': 'http://cogpo.org/'},
#  {'name': 'Cognitive Process Ontology (CPO)'},
#  {'name': 'Common Anatomy Reference Ontology (CARO)',
#   'url': 'http://obofoundry.org/ontology/caro.html'},
#  {'name': 'Common Core Ontologies (CCO)',
#   'url': 'http://www.cubrc.org/index.php/data-science-and-information-fusion/ontology'},
#  {'name': 'Common Core Cyber Ontology (C3O)',
#   'url': 'https://www-spiedigitallibrary-org.gate.lib.buffalo.edu/conference-proceedings-of-spie/10635/106350F/A-common-core-based-cyber-ontology-in-support-of-cross/10.1117/12.2307719.full?SSO=1'},
#  {'name': 'Communication Standards Ontology (CSO)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20543345'},
#  {'name': 'Comparative Data Analysis Ontology (CDAO)',
#   'url': 'https://bioportal.bioontology.org/ontologies/CDAO'},
#  {'name': 'Computational Neuroscience Ontology (CNO)',
#   'url': 'https://bioportal.bioontology.org/ontologies/CNO'},
#  {'name': 'Computer Aided Engineering Modeling Language (CAEML) Ontology',
#   'url': 'https://www.clics-network.org/downloads/NAFEMS_2016_Towards%20Cognitive%20Computer%20Aided%20Engineering.pdf'},
#  {'name': 'Computer-Based Patient Record Ontology (CPRO)',
#   'url': 'https://code.google.com/archive/p/cpr-ontology/'},
#  {'name': 'Conceptual Model Ontology (CMO)',
#   'url': 'http://ceur-ws.org/Vol-833/paper25.pdf'},
#  {'name': 'Core Data Integration Model (CDIM)',
#   'url': 'https://www.researchgate.net/publication/263323866_Clinical_Data_Integration_Model_Core_Interoperability_Ontology_for_Research_Using_Primary_Care_Data'},
#  {'name': 'Coriell Cell Line Ontology',
#   'url': 'http://efo.sourceforge.net/coriell.htm'},
#  {'name': "CPR Ontology for the Institute of Medicine's (IOM) Computer-Based Patient Record Ontology",
#   'url': 'http://code.google.com/p/cpr-ontology'},
#  {'name': 'Coronavirus Infectious Disease Ontology (CIDO)',
#   'url': 'http://www.ontobee.org/ontology/cido '},
#  {'name': 'Data Model for Representing Biographical Information for Prosopography (Bio-CRM)',
#   'url': 'https://seco.cs.aalto.fi/publications/2018/tuominen-et-al-rrl-2018.pdf'},
#  {'name': 'Decision Ontology',
#   'url': 'https://doi.org/10.3390/systems6040046'},
#  {'name': 'Diabetes mellitus Diagnosis Ontology (DDO)',
#   'url': 'http://link.springer.com/article/10.1186/s40535-016-0021-2'},
#  {'name': 'Diabetes Mellitus Treatment Ontology (DMTO)',
#   'url': 'https://jbiomedsem.biomedcentral.com/articles/10.1186/s13326-018-0176-y'},
#  {'name': 'Digital Objects in Philosophy Ontology (DOPHO)',
#   'url': 'https://publiscologne.th-koeln.de/frontdoor/deliver/index/docId/1363/file/MAT_Seidlmayer.pdf'},
#  {'name': 'Document Act Ontology (D-Acts)',
#   'url': 'https://code.google.com/p/d-acts'},
#  {'name': 'Drug Interaction Ontology (DIO)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/15360854'},
#  {'name': 'Drug Ontology (DrOn)',
#   'url': 'http://obofoundry.org/ontology/dron.html'},
#  {'name': 'Drug-drug Interaction Evidence Ontology (DIDEO)',
#   'url': 'http://obofoundry.org/ontology/dideo.html'},
#  {'name': 'Drug-drug Interaction Ontology (DINTO)',
#   'url': 'http://www.obofoundry.org/ontology/dinto.html'},
#  {'name': 'Drug Repurposing Ontology (DRO)',
#   'url': 'https://www.researchgate.net/profile/Werner_Ceusters/publication/335079148_Foundations_for_a_Realism-based_Drug_Repurposing_Ontology/links/5d4d7ce44585153e5948eb68/Foundations-for-a-Realism-based-Drug-Repurposing-Ontology.pdf'},
#  {'name': 'Eagle-I Research Resource Ontology (ERO)',
#   'url': 'https://open.med.harvard.edu/wiki/display/eaglei/Ontology'},
#  {'name': 'Electrocardiography Ontology (ECG)',
#   'url': 'http://www.j-biomed-inform.com/article/S1532-0464(10)00118-8/abstract'},
#  {'name': 'Eligibility Criteria Ontology (EC-O)',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S1569190X18301114'},
#  {'name': 'Email Ontology',
#   'url': 'http://ncor.buffalo.edu/2013/STIDS/5-Email.pptx'},
#  {'name': 'Emotion Ontology (EMO)',
#   'url': 'http://www.obofoundry.org/ontology/mfoem.html'},
#  {'name': 'ENanoMapper (ENM)', 'url': 'https://github.com/enanomapper'},
#  {'name': 'End of Life (EoL) Domain Ontology',
#   'url': 'https://www.sciencedirect.com/science/article/abs/pii/S0167739X19326640'},
#  {'name': 'Engineering-to-BioMimetic Ontology (E2BMO)',
#   'url': 'https://www.mdpi.com/2411-9660/2/4/53'},
#  {'name': 'Environment Ontology',
#   'url': 'http://obofoundry.org/ontology/envo.html'},
#  {'name': 'Epidemiology Ontology (EPO)',
#   'url': 'http://obofoundry.org/ontology/epo.html'},
#  {'name': 'Epilepsy and Seizure Ontology (EPSO)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23686934'},
#  {'name': 'Event-Based Functional Behavior Ontology (EFBO)',
#   'url': 'http://ceur-ws.org/Vol-1660/caos-paper2.pdf'},
#  {'name': 'European Materials Modeling Ontology (EMMO)',
#   'url': 'https://emmc.info/wp-content/uploads/2017/12/EMMC_IntOp2017-Cambridge_Ghedini_Bologna.pdf'},
#  {'name': 'Event-Based Ontology for Historical Description (EOHD)',
#   'url': 'https://www.emeraldinsight.com/doi/abs/10.1108/DLP-02-2018-0005'},
#  {'name': 'Evolution Ontology (EO)',
#   'url': 'http://code.google.com/p/evolution-ontology'},
#  {'name': 'Experimental Factor Ontology (EFO)',
#   'url': 'http://www.ebi.ac.uk/efo'},
#  {'name': '(EXperimental ACTions) Biomedical Protocol Ontology (EXACT2)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC4255744'},
#  {'name': 'Exposé',
#   'url': 'https://lirias.kuleuven.be/bitstream/123456789/273222/1/sokd10.pdf'},
#  {'name': 'eXtended Formal Ontology (XFO)',
#   'url': 'https://www.researchgate.net/profile/Robert_Allen5/publication/325141757_XFO_Toward_Programming_Rich_Semantic_Models/links/5afa473d458515c00b6bd24f/XFO-Toward-Programming-Rich-Semantic-Models.pdf?origin=publication_detail'},
#  {'name': 'FASTO Ontology (incorporates BFO, FHIR, CPG,and SSN)',
#   'url': 'https://bioportal.bioontology.org/ontologies/FASTO'},
#  {'name': 'Fission Yeast Phenotype Ontology (FYPO)',
#   'url': 'http://www.pombase.org/documentation/gene-page-phenotypes'},
#  {'name': 'Flower-Visiting Domain Ontology (FV), Known Flower-Visiting Group Domain Ontology (KFG), Flower-Visiting Behavior Application Ontology (FVB) and Observation-Date Application Ontology (OBD)',
#   'url': 'http://www.sciencedirect.com/science/article/pii/S157495411400082X'},
#  {'name': 'Food-Energy-Water Systems Ontology (FEWsONT)',
#   'url': 'https://www.liebertpub.com/doi/full/10.1089/ees.2018.0551'},
#  {'name': 'Flybase Drosophila Anatomy Ontology (DAO)',
#   'url': 'http://obofoundry.org/ontology/fbbt.html'},
#  {'name': 'Flybase Drosophila Phenotype Ontology (FYPO)',
#   'url': 'http://obofoundry.org/ontology/fypo.html'},
#  {'name': 'Feedback Intervention Ontology (FIO)',
#   'url': 'https://github.com/Display-Lab'},
#  {'name': 'Food Ontology (FoodOn)',
#   'url': 'http://obofoundry.org/ontology/foodon.html'},
#  {'name': 'Foundational Model of Anatomy (FMA)',
#   'url': 'http://obofoundry.org/ontology/fma.html'},
#  {'name': 'Framework for Semantic Workflow Composition in the Geology Domain',
#   'url': 'http://ceur-ws.org/Vol-2228/abstract6.pdf'},
#  {'name': 'Gastrointestinal Endoscopy Ontology (GIEO)',
#   'url': 'http://ceur-ws.org/Vol-833/paper36.pdf'},
#  {'name': 'Gender, Sex, and Sexual Orientation (GSSO) ontology',
#   'url': 'https://academic-oup-com.gate.lib.buffalo.edu/jamia/advance-article-abstract/doi/10.1093/jamia/ocaa061/5858296'},
#  {'name': 'General Information Model (GIM)',
#   'url': 'http://jamia.bmj.com/content/20/5/986.full'},
#  {'name': 'Gene Ontology (GO)',
#   'url': 'http://obofoundry.org/ontology/go.html'},
#  {'name': 'Gene Regulation Ontology (GRO)',
#   'url': 'https://ub-madoc.bib.uni-mannheim.de/35191/1/dissertation_beisswanger.pdf'},
#  {'name': 'Genomic Epidemiology Ontology (GenEpiO)',
#   'url': 'http://obofoundry.org/ontology/genepio.html'},
#  {'name': 'Genomic Feature and Variation Ontology (GFVO)',
#   'url': 'https://peerj.com/articles/933/'},
#  {'name': 'Geographical Entity Ontology (GEO)',
#   'url': 'http://www.obofoundry.org/ontology/geo.html'},
#  {'name': 'Global Electronic Health Record Ontology (G-EHR-O)',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S1569190X18301114'},
#  {'name': 'Gestalt',
#   'url': 'https://ieeexplore.ieee.org/abstract/document/6956738'},
#  {'name': 'Health Data Ontology Trunk (HDOT)', 'url': 'http://purl.org/hdot'},
#  {'name': 'Hemocomponents and Hemoderivatives Ontology (HEMONTO)',
#   'url': 'http://mba.eci.ufmg.br/downloads/ontobras-2013_paper1.pdf'},
#  {'name': 'Host Pathogen Interactions Ontology (HPO)',
#   'url': 'http://bioportal.bioontology.org/ontologies/HPIO?p=classes'},
#  {'name': 'Human Disease Ontology (DOID)',
#   'url': 'http://www.obofoundry.org/ontology/doid.html'},
#  {'name': 'Human Activity and Infrastructure Foundry (HAIF)',
#   'url': 'https://arxiv.org/ftp/arxiv/papers/1809/1809.09548.pdf'},
#  {'name': 'Human Experience Realist Ontology (HERO)',
#   'url': 'https://www.researchgate.net/publication/316557588_A_Human_Experience_Realist_Ontology_in_Basic_Formal_Ontology'},
#  {'name': 'Human Interaction Network Ontology (HINO)',
#   'url': 'http://arxiv.org/pdf/1311.3355.pdf'},
#  {'name': 'Human Physiology Simulation Ontology (HuPSON)',
#   'url': 'http://www.jbiomedsem.com/content/pdf/2041-1480-4-35.pdf'},
#  {'name': 'Infectious Disease Ontology',
#   'url': 'http://obofoundry.org/ontology/ido.html'},
#  {'name': 'Information Artifact Ontology (IAO)',
#   'url': 'http://obofoundry.org/ontology/iao.html'},
#  {'name': 'Information Security Domain (ISD) ontology',
#   'url': 'https://ieeexplore.ieee.org/abstract/document/8795392'},
#  {'name': 'Informed Consent Ontology (ICO)',
#   'url': 'http://ceur-ws.org/Vol-2285/ICBO_2018_paper_59.pdf'},
#  {'name': 'Innovative Capabilities of Additive Manufacturing (ICAM) Ontology',
#   'url': 'http://computingengineering.asmedigitalcollection.asme.org/article.aspx?articleid=2674329'},
#  {'name': 'Integrated Framework for Additively Manufactured Products (IFAMP) ontology',
#   'url': 'https://buffalo.app.box.com/v/integrating-ontologies'},
#  {'name': 'Interaction Network Ontology (INO)',
#   'url': 'http://www.cmpe.boun.edu.tr/~ozgur/papers/VDOS2014.pdf'},
#  {'name': 'International Classification of Diseases Ontology (ICDO)'},
#  {'name': 'Interdisciplinary Prostate Ontology Project (IPOP)',
#   'url': 'http://ipop.ontodev.com/'},
#  {'name': 'International Center for Food Ontology, Operability, Data and Semantics (IC-FOODS)',
#   'url': 'http://www.ic-foods.org/'},
#  {'name': 'uc_Eating', 'url': 'https://github.com/IC-FOODS/uc_Eating'},
#  {'name': 'uc_FoodDrugInteractionOntology',
#   'url': 'https://github.com/IC-FOODS/uc_FoodDrugInteractionOntology'},
#  {'name': 'uc_Milk', 'url': 'https://github.com/IC-FOODS/uc_Milk'},
#  {'name': 'uc_Processing', 'url': 'https://github.com/IC-FOODS/uc_Processing'},
#  {'name': 'uc_Sense', 'url': 'https://github.com/IC-FOODS/uc_Sense'},
#  {'name': 'Intervention Setting Ontology',
#   'url': 'https://wellcomeopenresearch.org/articles/5-124'},
#  {'name': 'Intracranial Aneurysm (ICA) Ontology',
#   'url': 'http://www.sciencedirect.com/science/article/pii/S1532046415000519'},
#  {'name': 'Knowledge Base Of Biomedicine (KaBOB)',
#   'url': 'http://www.biomedcentral.com/content/pdf/s12859-015-0559-3.pdf'},
#  {'name': 'Knowledge Object Reference Ontology (KORO)',
#   'url': 'https://onlinelibrary.wiley.com/doi/full/10.1002/lrh2.10054'},
#  {'name': 'Library of Integrated Network-based Cellular Signatures',
#   'url': 'https://bmcbioinformatics.biomedcentral.com/articles/10.1186/s12859-017-1981-5'},
#  {'name': 'Lipid Ontology',
#   'url': 'http://obofoundry.org/ontology/lipro.html'},
#  {'name': 'Literary Theme Ontology (LTO)',
#   'url': 'https://github.com/theme-ontology/lto'},
#  {'name': 'Machine Learning Schema (ML-Schema) ontology',
#   'url': 'https://openreview.net/pdf?id=B1e8MrXVxQ'},
#  {'name': 'Major histocompatibility complex (MHC) Restriction Ontology (MRO)',
#   'url': 'http://obofoundry.org/ontology/mro.html'},
#  {'name': 'Malaria Ontology (IDOMAL)',
#   'url': 'http://obofoundry.org/ontology/idomal.html'},
#  {'name': 'Manufacturing Service Description Language (MSDL) ontology',
#   'url': 'https://link.springer.com/chapter/10.1007/978-3-319-99707-0_40'},
#  {'name': 'Manufacturing Supply Chain Ontology (MSCO)',
#   'url': 'https://buffalo.box.com/s/rbapg73v4jq18dvw0rf2jnszndvnxmb0'},
#  {'name': 'Medication Adherence Behavior Ontology (MAB-Ontology)',
#   'url': 'https://scholarworks.iupui.edu/bitstream/handle/1805/17767/Sawesi_iupui_0104D_10326.pdf'},
#  {'name': 'Mental Disease Ontology (MFO-MD)',
#   'url': 'http://obofoundry.org/ontology/mfomd.html'},
#  {'name': 'Mental Functioning Ontology (MF)',
#   'url': 'http://obofoundry.org/ontology/mf.html'},
#  {'name': 'Microbiology Ontology (MicrO)',
#   'url': 'http://jbiomedsem.biomedcentral.com/articles/10.1186/s13326-016-0060-6'},
#  {'name': 'Minimum Information Model for Patient Safety (MIMPS)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/27139388'},
#  {'name': 'miRNAO',
#   'url': 'http://iwbbio.ugr.es/2014/papers/IWBBIO_2014_paper_103.pdf'},
#  {'name': 'Middle Layer Ontology for Clinical Care (MLOCC)',
#   'url': 'http://p-medicine.eu/project/wp-4'},
#  {'name': 'Military Ontology',
#   'url': 'http://basic-formal-ontology.org/publications#salmen'},
#  {'name': 'Military Scenario Ontology (MSO)',
#   'url': 'http://link.springer.com/article/10.1007/s10489-016-0834-7'},
#  {'name': 'MIRO and IRbase',
#   'url': 'http://www.plosntds.org/article/info:doi/10.1371/journal.pntd.0000465'},
#  {'name': 'Mission and Means Framework (MMF) Ontology',
#   'url': 'https://ieeexplore.ieee.org/abstract/document/8455742/'},
#  {'name': 'Modal Relation Ontology (MRO)',
#   'url': 'https://www.spiedigitallibrary.org/conference-proceedings-of-spie/10635/106350H/Problems-with-prescriptions--disentangling-data-about-actual-versus-prescribed/10.1117/12.2307718.short?SSO=1'},
#  {'name': 'Mode of Delivery (MoD) Ontology',
#   'url': 'https://wellcomeopenresearch.org/articles/5-125'},
#  {'name': 'Modular Environmental Modeling Ontology (MEMOn)',
#   'url': 'https://ieeexplore-ieee-org.gate.lib.buffalo.edu/abstract/document/8599597'},
#  {'name': 'Model for Clinical Information (MCI)',
#   'url': 'http://bmcmedinformdecismak.biomedcentral.com/articles/10.1186/s12911-016-0248-9'},
#  {'name': 'Mouse Pathology Ontology (MPATH)',
#   'url': 'http://obofoundry.org/ontology/mpath.html'},
#  {'name': 'Name Reaction Ontology (RXNO)',
#   'url': 'http://obofoundry.org/ontology/rxno.html'},
#  {'name': 'Nanoparticle Ontology (NPO)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20211274'},
#  {'name': 'Neomark Oral Cancer Ontology (NEOMARK4)',
#   'url': 'https://bioportal.bioontology.org/ontologies/NEOMARK4'},
#  {'name': 'NeuroPsychological Testing Ontology (NPT)',
#   'url': 'http://www.unbsj.ca/sase/csas/data/ws/icbo2013/papers/research/icbo2013_submission_31.pdf'},
#  {'name': 'Neuroscience Information Framework',
#   'url': 'http://www.neuinfo.org/'},
#  {'name': 'Neuroscience Information Framework Cell Ontology (NIFCELL)',
#   'url': 'https://bioportal.bioontology.org/ontologies/NIFCELL'},
#  {'name': 'Neuroscience Information Framework Dysfunction Ontology (NIFDYS)',
#   'url': 'https://bioportal.bioontology.org/ontologies/NIFDYS'},
#  {'name': 'Neuroscience Information Framework Standard Ontology (NIFSTD)',
#   'url': 'http://bioportal.bioontology.org/ontologies/NIFSTD'},
#  {'name': 'Neural Electromagnetic Ontologies (NEMO)',
#   'url': 'http://nemo.nic.uoregon.edu/'},
#  {'name': 'Nanoparticles Impact on Human Cell morphology Ontology (NIHCO)',
#   'url': 'https://www.bjbabe.ro/wp-content/uploads/2017/10/18_RODINO.pdf'},
#  {'name': 'Next-Generation Biobanking Ontology (NGBO)',
#   'url': 'http://ceur-ws.org/Vol-2180/paper-02.pdf'},
#  {'name': 'Next Generation Sequencing Ontology (NGSONTO)',
#   'url': 'https://github.com/lindenb/ngs-ontology'},
#  {'name': 'Non-Coding RNA Ontology (NCRO)',
#   'url': 'http://soc.southalabama.edu/~huang/papers/BIBM-15-1.pdf'},
#  {'name': 'NMR-Instrument Component of Metabolomics Investigations Ontology',
#   'url': 'http://bioportal.bioontology.org/ontologies/NMR?p=classes&conceptid=root'},
#  {'name': 'Ocular Disease Ontology (ODO)',
#   'url': 'http://www.unbsj.ca/sase/csas/data/ws/icbo2013/papers/posters/icbo2013_submission_67.pdf'},
#  {'name': 'OncoCL-KB', 'url': 'http://ceur-ws.org/Vol-1546/poster_65.pdf'},
#  {'name': 'OBR Scolio (scoliosis) ontology',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S0169260719300665'},
#  {'name': 'OntoAlign++',
#   'url': 'http://ceur-ws.org/Vol-1041/ontobras-2013_paper52.pdf'},
#  {'name': 'OntoForInfoScience',
#   'url': 'http://www2.marilia.unesp.br/revistas/index.php/bjis/article/viewFile/5426/3970'},
#  {'name': 'Ontologies for Representing Surgical Procedure Models (OntoSPM)',
#   'url': 'https://ontospm.univ-rennes1.fr/doku.php?id=ontology'},
#  {'name': 'Ontologized Minimum Information About BIobank data Sharing (OMIABIS)',
#   'url': 'http://obofoundry.org/ontology/omiabis.html'},
#  {'name': 'Ontology for Adverse Events (OAE)',
#   'url': 'http://obofoundry.org/ontology/oae.html'},
#  {'name': 'Ontology for Autism Spectrum Disorder',
#   'url': 'http://www.sciencedirect.com/science/article/pii/S1532046415001367'},
#  {'name': 'Ontology for Biobanking (OBIB)',
#   'url': 'http://obofoundry.org/ontology/obib.html'},
#  {'name': 'Ontology for Biomedical Investigations (OBI)',
#   'url': 'http://obofoundry.org/ontology/obi.html'},
#  {'name': 'Ontology of Card Sleights',
#   'url': 'https://arxiv.org/abs/1903.08523'},
#  {'name': 'Ontology of Chinese Medicine for Rheumatism (OCMR)',
#   'url': 'https://bioportal.bioontology.org/ontologies/OCMR'},
#  {'name': 'Ontology of Card Sleights',
#   'url': 'https://arxiv.org/abs/1903.08523'},
#  {'name': 'Ontology for Computable Eligibility Criteria - Hepatitis C Virus (OCEC-HCV)',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6371316/'},
#  {'name': 'Ontology for Dengue Fever (IDODEN)',
#   'url': 'http://journals.plos.org/plosntds/article?id=10.1371/journal.pntd.0003479'},
#  {'name': 'Ontology for Documentation of Variable/Data Source Selection (ODVDS)',
#   'url': 'http://ceur-ws.org/Vol-2427/SEPDA_2019_paper_15.pdf'},
#  {'name': 'Ontology for Drug Discovery Investigations (DDI)',
#   'url': 'http://purl.org/ddi/home'},
#  {'name': 'Ontology for Energy Investigations (OEI)',
#   'url': 'https://www.researchgate.net/publication/234128482_Facilitating_Knowledge_Sharing_and_Analysis_in_Energy_Informatics_with_the_Ontology_for_Energy_Investigations_%28OEI%29'},
#  {'name': 'Ontology of Electronics (OOE)',
#   'url': 'https://github.com/ontology-of-electronics'},
#  {'name': 'Ontology for Functionally Graded Materials (OFGM)',
#   'url': 'https://www.academia.edu/27922525/Development_of_a_Manufacturing_Ontology_for_Functionally_Graded_Materials'},
#  {'name': 'Ontology for General Medical Science (OGMS)',
#   'url': 'http://obofoundry.org/ontology/ogms.html'},
#  {'name': 'Ontology of Cardiovascular Drug Adverse Events (OCVDAE)',
#   'url': 'https://www.nature.com/articles/s41598-017-12580-4'},
#  {'name': 'Ontology of Genes and Genomes (OGG)',
#   'url': 'http://obofoundry.org/ontology/ogg.html'},
#  {'name': 'Ontology for Genes and Genomes - Mouse (OGG-MM)',
#   'url': 'http://www.ontobee.org/ontology/OGG-Mm'},
#  {'name': 'Ontology of Genetic Disease Investigations (OGDI)',
#   'url': 'https://bioportal.bioontology.org/ontologies/OGDI'},
#  {'name': 'Ontology for Genetic Interval (OGI)',
#   'url': 'http://bioportal.bioontology.org/ontologies/OGI?p=classes&conceptid=root'},
#  {'name': 'Ontology of Genetic Susceptibility Factor (OGSF)',
#   'url': 'http://obofoundry.org/ontology/ogsf.html'},
#  {'name': 'Ontology for Guiding Appropriate Antibiotic Prescribing',
#   'url': 'http://www.sciencedirect.com/science/article/pii/S1532046411001675'},
#  {'name': 'Ontology for Laparoscopic Surgeries (LapOntoSPM)',
#   'url': 'http://link.springer.com/article/10.1007/s11548-015-1222-1'},
#  {'name': 'Ontology of Microbial Phenotypes (OMP)',
#   'url': 'http://obofoundry.org/ontology/omp.html'},
#  {'name': 'Ontology for MIcroRNA Target Prediction (OMIT)',
#   'url': 'http://obofoundry.org/ontology/omit.html'},
#  {'name': 'Ontology for Newborn Screening and Translational Research (ONSTR)',
#   'url': 'http://code.google.com/p/onstr'},
#  {'name': 'Ontology for Next Generation Sequencing Experiments (NGS Ontology)',
#   'url': 'https://github.com/lindenb/ngs-ontology'},
#  {'name': 'OBDMR: An Ontology-Based Data Model for Railways',
#   'url': 'https://doi.org/10.1166/jctn.2020.8662'},
#  {'name': 'Ontology Based Clinical Decision Support System for Geriatrics',
#   'url': 'https://www.ingentaconnect.com/contentone/asp/jctn/2020/00000017/00000001/art00042'},
#  {'name': 'Ontology-Based Operational Emergency Response (POLARISC)',
#   'url': 'https://onlinelibrary.wiley.com/doi/pdf/10.1002/9781119564034.ch52'},
#  {'name': 'Ontology for Pain and Related Disability, Mental Health and Quality of Life (OPMQoL)',
#   'url': 'http://www.referent-tracking.com/RTU/?page=projects.phtml#opmqol'},
#  {'name': 'Ontology for Periodontitis (PERIO)',
#   'url': 'http://www.jbiomedsem.com/content/6/1/30'},
#  {'name': 'Ontology of Arthropod Circulatory Systems (OArCS)',
#   'url': 'http://obofoundry.org/ontology/oarcs.html'},
#  {'name': 'Ontology of Clinical Research (OCRe)',
#   'url': 'http://code.google.com/p/ontology-of-clinical-research/source/browse/trunk/Archive/OCRe-with-BFO.owl'},
#  {'name': 'Ontology for Nutritional Studies (ONS)',
#   'url': 'https://genesandnutrition.biomedcentral.com/articles/10.1186/s12263-018-0601-y'},
#  {'name': 'Ontology for Parasite LifeCycle (OPL)',
#   'url': 'http://obofoundry.org/ontology/opl.html'},
#  {'name': 'Ontology for Thoracentesis',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S0933365717301525'},
#  {'name': 'Ontology of Biological and Clinical Statistics (OBCS)',
#   'url': 'http://obofoundry.org/ontology/obcs.html'},
#  {'name': 'Ontology of Cancer Related Socialecological Variables (OCRSEV)',
#   'url': 'http://ceur-ws.org/Vol-2137/ws_ONCONTO_paper_3.pdf'},
#  {'name': 'Ontology for Cancer research variables (OCRV)',
#   'url': 'https://bmcmedinformdecismak.biomedcentral.com/articles/10.1186/s12911-018-0636-4'},
#  {'name': 'Ontology of Data Mining (OntoDM)', 'url': 'http://www.ontodm.com/'},
#  {'name': 'OntoDM Core',
#   'url': 'http://www.ontodm.com/doku.php?id=ontodm-core'},
#  {'name': 'Ontology of Datatypes (OntoDT)', 'url': 'http://www.ontodt.com/'},
#  {'name': 'Ontology of Experimental Variables and Values (OOEVV)',
#   'url': 'https://bioportal.bioontology.org/ontologies/OOEVV'},
#  {'name': 'Ontology for Information Science (OntoforInforScience)',
#   'url': 'https://www.researchgate.net/publication/299534658_OntoforInfoScience_a_detailed_methodology_for_construction_of_ontologies_and_its_application_in_the_blood_domain'},
#  {'name': 'Ontology of Medical Microbiology (OntoMic)',
#   'url': 'http://rali.iro.umontreal.ca/rali/sites/default/files/publis/Levreault-MSc.pdf'},
#  {'name': 'Ontology of Medically Related Social Entities (OMRSE)',
#   'url': 'http://obofoundry.org/ontology/omrse.html'},
#  {'name': 'Ontology of Organizational Structures ofTrauma systems and Trauma centers (OOSTT)',
#   'url': 'http://ceur-ws.org/Vol-1747/IT504_ICBO2016.pdf'},
#  {'name': 'Ontology of Social Participation (OPS)',
#   'url': 'http://arxiv.org/pdf/1501.02662.pdf'},
#  {'name': 'Ontology for Stem Cell Investigations (OSCI)',
#   'url': 'https://bmcbioinformatics.biomedcentral.com/articles/10.1186/s12859-019-2723-7'},
#  {'name': 'Ontology of Systems Engineering',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S1877050919307380'},
#  {'name': 'Ontology of Vaccine Adverse Events (OVAE)',
#   'url': 'http://obofoundry.org/ontology/ovae.html'},
#  {'name': 'Ontology-Based Data Access (OBDA)',
#   'url': 'http://www.sciencedirect.com.gate.lib.buffalo.edu/science/article/pii/S1570826815000165'},
#  {'name': 'Ontology Based Decision Support System for Tuberculosis Management and Control',
#   'url': 'https://www.researchgate.net/publication/312296048'},
#  {'name': 'Ontology-Based eXtensible Data Model (OBX)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20460173'},
#  {'name': 'Ontology-Driven Information System (ODIS)/Ontology-Driven Scenario Generator (ODSG)',
#   'url': 'http://www.sciencedirect.com/science/article/pii/S0952197615000913'},
#  {'name': 'Operational Environment Ontology (OEO)',
#   'url': 'https://jsou.libguides.com/ld.php?content_id=37534351'},
#  {'name': 'Oral Health and Disease Ontology (OHD)',
#   'url': 'http://obofoundry.org/ontology/ohd.html'},
#  {'name': 'Parasite Experiment Ontology (PEO)',
#   'url': 'http://bioportal.bioontology.org/ontologies/1335'},
#  {'name': 'Part-Focused Manufacturing Process Ontology (PMPO)',
#   'url': 'https://www.tandfonline.com/doi/abs/10.1080/0951192X.2017.1357837'},
#  {'name': 'Patient Safetry Categorial Structure (PS-CAST)',
#   'url': 'http://person.hst.aau.dk/ska/MIE2015/Papers/SHTI210-0160.pdf'},
#  {'name': 'Petrochemical Ontology',
#   'url': 'http://books.google.com/books?id=XYOBAusxPCcC&pg=PA27&lpg=PA27&dq=bfo+ontology&source=bl&ots=4nFYXvfaMy&sig=xq4BZAmY8DH0J5DMj3DE_xB4Fes&hl=en&ei=ZFpjStvADMaltgem27SyAg&sa=X&oi=book_result&ct=result&resnum=2'},
#  {'name': 'PGxO Pharmacogenomics Ontology',
#   'url': 'https://www.biorxiv.org/content/biorxiv/early/2018/08/13/390971.full.pdf'},
#  {'name': 'Phenotypic Quality Ontology (PaTO)',
#   'url': 'http://obofoundry.org/ontology/pato.html'},
#  {'name': 'Physics-Based Simulation Ontology (PSO-Physics and PSO-Sim)',
#   'url': 'https://www.tandfonline.com/doi/abs/10.1080/09544828.2019.1644301?journalCode=cjen20'},
#  {'name': 'Plant Experimental Assay Ontology (PEAO)',
#   'url': 'http://bioportal.bioontology.org/ontologies/PEAO'},
#  {'name': 'Plant Ontology (PO)',
#   'url': 'http://obofoundry.org/ontology/po.html'},
#  {'name': 'Plastic Rock Deformation (PRD) ontology',
#   'url': 'https://www-sciencedirect-com.gate.lib.buffalo.edu/science/article/pii/S0098300416308482'},
#  {'name': 'Pneumonia Ontology',
#   'url': 'https://www.researchgate.net/profile/Sabrina_Azzi/publication/328171801_Design_of_a_Pneumonia_Ontology_for_Diagnosis_Decision_Support_System/links/5bbcb970299bf1049b785032/Design-of-a-Pneumonia-Ontology-for-Diagnosis-Decision-Support-System.pdf'},
#  {'name': 'Ponte Ontology Platform (PONTE)',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S1569190X18301114'},
#  {'name': 'POLARISC Emergency Response System Ontology',
#   'url': 'http://idl.iscram.org/files/elmhadhbilinda/2018/1598_ElmhadhbiLinda_etal2018.pdf'},
#  {'name': 'Population and Community Ontology (PCO)',
#   'url': 'http://obofoundry.org/ontology/pco.html'},
#  {'name': 'Population Health Record (PopHR)',
#   'url': 'http://onlinelibrary.wiley.com/doi/10.1111/nyas.13271/full'},
#  {'name': 'Porifera Ontology (PORO)',
#   'url': 'http://obofoundry.org/ontology/poro.html'},
#  {'name': 'Precision Medicine Ontology (PMO)',
#   'url': 'http://www.aimspress.com/fileOther/PDF/MBE/mbe-17-04-227.pdf'},
#  {'name': 'Pre-Eclampsia Ontology (PEO)',
#   'url': 'http://journals.plos.org/plosone/article%3Fid%3D10.1371/journal.pone.0162828'},
#  {'name': 'PreOptique Platform for Integrated Pre-surgery Reports',
#   'url': 'https://jbiomedsem.biomedcentral.com/articles/10.1186/s13326-019-0197-1'},
#  {'name': 'Prescription of Drugs Ontology (PRDO)',
#   'url': 'https://pdfs.semanticscholar.org/7100/59ad86c5c2ef7a5b1430d30a8950a88aa319.pdf'},
#  {'name': 'PRISM: A Platform for Imaging inPrecision Medicine',
#   'url': 'https://ascopubs.org/doi/pdfdirect/10.1200/CCI.20.00001'},
#  {'name': 'Product Life Cycle Ontology for Additive Manufacturing',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S0166361518301647'},
#  {'name': 'Product Service System (PSS) Ontology',
#   'url': 'https://www.diversity-project.eu/wp-content/uploads/2017/07/Ontology-for-Colaborative-Development-of-Product-Service-Systems-Based-on-Basic-Formal-Ontology.pdf'},
#  {'name': 'Process and Observation Ontology (PO2)',
#   'url': 'https://www.sciencedirect.com/science/article/abs/pii/S0958694619300032'},
#  {'name': 'Proper Name Ontology (PNO)',
#   'url': 'https://code.google.com/p/proper-name-ontology'},
#  {'name': 'PROSPECT-IDR: Personalised Prediction of Infectious Disease Risk',
#   'url': 'http://www.tara.tcd.ie/bitstream/handle/2262/86059/Final%20Version.pdf?sequence=1'},
#  {'name': 'Protein-Ligand Interaction Ontology (PLIO)',
#   'url': 'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC3106195'},
#  {'name': 'Protein Ontology (PRO)',
#   'url': 'http://obofoundry.org/ontology/pr.html'},
#  {'name': 'Provenir ontology for provenance modeling',
#   'url': 'http://cci.case.edu/cci/images/a/aa/Janus.pdf'},
#  {'name': 'Public Safety and Emergency Management (PS/EM) Communications Ontology',
#   'url': 'https://www.ida.org/-/media/feature/publications/p/pu/public-safety-and-emergency-management-communications-ontology/d-8583.ashx'},
#  {'name': 'QROWD urban traffic and mobility ontology',
#   'url': 'http://qrowd-project.trackglobe.es/wp-content/uploads/2019/11/D4.3-Linked-Data-Generation.docx.pdf'},
#  {'name': 'Quality of Service (QoS) Ontology',
#   'url': 'http://www.waset.org/publications/10000168'},
#  {'name': 'Relations Ontology (RO)',
#   'url': 'http://www.obofoundry.org/ontology/ro.html'},
#  {'name': 'Reliability Assessment for Assembly Stations (RAAS) Ontology',
#   'url': 'https://infoscience.epfl.ch/record/265908/files/'},
#  {'name': 'RNA Ontology (RnaO)',
#   'url': 'http://obofoundry.org/ontology/rnao.html'},
#  {'name': 'Rock Plastic Deformation (RPD) ontology',
#   'url': 'http://www.sciencedirect.com/science/article/pii/S0098300416308482'},
#  {'name': 'ROMAIN industrial maintenance ontology',
#   'url': 'https://www.researchgate.net/publication/332390146_ROMAIN_Towards_a_BFO_compliant_reference_ontology_for_industrial_maintenance'},
#  {'name': 'Role Ontology (ROLEO)',
#   'url': 'https://bioportal.bioontology.org/ontologies/ROLEO'},
#  {'name': 'Saliva Ontology (SALO)',
#   'url': 'http://code.google.com/p/bodily/source/browse/trunk/src/ontology/salo.owl'},
#  {'name': 'Schistosomiasis Process Ontology (IDOSCHISTO)',
#   'url': 'http://ceur-ws.org/Vol-1747/IP01_ICBO2016.pdf'},
#  {'name': 'Scientific Evidence and Provenance Information Ontology (SEPIO)',
#   'url': 'http://ceur-ws.org/Vol-1747/IT605_ICBO2016.pdf'},
#  {'name': 'Semantic Electronic Health Record (SEHR) Model',
#   'url': 'http://www.linked2safety-project.eu/node/44'},
#  {'name': 'Senselab Ontology',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/20006477'},
#  {'name': 'Semanticscience Integrated Ontology (SIO)',
#   'url': 'http://code.google.com/p/semanticscience/wiki/SIO'},
#  {'name': 'Semantic LAminated Composites Knowledge management System (SLACKS)',
#   'url': 'http://dl.acm.org/citation.cfm?id=2580238'},
#  {'name': 'Sentinel: Platform for Semantic Enrichment of Social Media Streams',
#   'url': 'http://ieeexplore.ieee.org/document/8232468/'},
#  {'name': 'Sequence Ontology (SO)',
#   'url': 'http://obofoundry.org/ontology/so.html'},
#  {'name': 'Shop-Floor Digital Twin (DT) ontology',
#   'url': 'http://ceur-ws.org/Vol-2615/paper5.pdf'},
#  {'name': 'Situated and Interactive Multimodal Conversations',
#   'url': 'https://arxiv.org/pdf/2006.01460.pdf '},
#  {'name': 'Situation Awareness Ontology (SAO)',
#   'url': 'http://link.springer.com/article/10.1007/s10489-016-0834-7'},
#  {'name': 'SMART Protocols',
#   'url': 'http://vocab.linkeddata.es/SMARTProtocols'},
#  {'name': 'Sketch Map Ontology',
#   'url': 'https://www.tandfonline.com/doi/abs/10.1080/13658816.2017.1309043?journalCode=tgis20'},
#  {'name': 'Skin Physiology Ontology (SPO)',
#   'url': 'https://bioportal.bioontology.org/ontologies/SPO'},
#  {'name': 'Sleep Domain Ontology (SDO)',
#   'url': 'http://bimib.disco.unimib.it/images/7/7c/SSFW09_Arabandi_SleepOntology.pdf'},
#  {'name': 'SNOMED CT (SCT) Standard Ontology',
#   'url': 'https://bmcmedinformdecismak.biomedcentral.com/articles/10.1186/s12911-018-0651-5'},
#  {'name': 'Social Psychology Ontology (SPO)',
#   'url': 'https://ubir.buffalo.edu/xmlui/handle/10477/79440'},
#  {'name': 'Software, Disabilities and Competences Ontology (SODIC)',
#   'url': 'http://dspace.ucuenca.edu.ec/bitstream/123456789/28548/1/Trabajo%20de%20Titulaci%C3%B3n.pdf'},
#  {'name': 'Software Ontology (SWO)',
#   'url': 'http://jbiomedsem.biomedcentral.com/articles/10.1186/2041-1480-5-25'},
#  {'name': 'Spatial Graph Adapter (SGA) Ontology Design Pattern',
#   'url': 'http://www.semantic-web-journal.net/system/files/swj1582.pdf'},
#  {'name': 'Spatiotemporal Ontology for the Administrative Units of Switzerland (SONADUS)',
#   'url': 'http://www.geo.uzh.ch/dam/jcr:6c3c9ef3-6bcd-4300-86e4-9de07d3f6f37/msc_felix_gantner_2011.pdf'},
#  {'name': 'Special Nuclear Materials Detection Ontology (SNM-DO)',
#   'url': 'http://ceur-ws.org/Vol-808/STIDS2011_CR_P2_WardEtAl.pdf'},
#  {'name': 'Statistics Ontology (STATO)',
#   'url': 'http://obofoundry.org/ontology/stato.html'},
#  {'name': 'STATO-LMM Linear Mixed Model Ontology',
#   'url': 'https://www.nature.com/articles/s41597-020-0409-7'},
#  {'name': 'Subcellular Anatomy Ontology (SAO)',
#   'url': 'http://obofoundry.org/ontology/sao.html'},
#  {'name': 'Suggested Ontology for Pharmacogenomics (SO-Pharm)',
#   'url': 'http://obofoundry.org/ontology/sopharm.html'},
#  {'name': 'Surface Water Ontology (SWO)',
#   'url': 'https://www.usgs.gov/media/files/surface-water-ontology'},
#  {'name': 'Survey Ontology',
#   'url': 'https://www.scitepress.org/papers/2017/65827/65827.pdf'},
#  {'name': 'Taxonomy for Rehabilitation of Knee Conditions (TRAK)',
#   'url': 'http://users.cs.cf.ac.uk/I.Spasic/trak'},
#  {'name': 'Time Event Ontology (TEO)',
#   'url': 'https://bioportal.bioontology.org/ontologies/TEO'},
#  {'name': 'Toxic Process Ontology (TXPO)',
#   'url': 'http://www.obofoundry.org/ontology/txpo.html'},
#  {'name': 'Trade-Space Analysis Tool for Constellations (TAT-C) ontology',
#   'url': 'https://arc.aiaa.org/doi/abs/10.2514/6.2019-1032'},
#  {'name': 'Translational Medicine Ontology (TMO)',
#   'url': 'http://esw.w3.org/topic/HCLSIG/PharmaOntology'},
#  {'name': 'Transportation System Ontology',
#   'url': 'http://www.ontobee.org/ontology/TSO'},
#  {'name': 'The Trope Ontology',
#   'url': 'https://www.mdpi.com/2409-9287/4/3/40'},
#  {'name': 'Tumour-Node-Metastasis Ontology (TNM-O)',
#   'url': 'https://jbiomedsem.biomedcentral.com/articles/10.1186/s13326-016-0106-9'},
#  {'name': '(Microbial) Typing Ontology (TypOn)',
#   'url': 'http://www.phyloviz.net/typon'},
#  {'name': 'United Nations SDG (Sustainable Development Goals) Ontology Framework',
#   'url': 'https://iswc2017.ai.wu.ac.at/wp-content/uploads/papers/MainProceedings/179.pdf'},
#  {'name': 'United Nations System Document Ontology (ONTO-UNDO)',
#   'url': 'https://unsceb-hlcm.github.io/onto-undo/'},
#  {'name': 'Universal Core Semantic Layer',
#   'url': 'http://sunsite.informatik.rwth-aachen.de/Publications/CEUR-WS/Vol-555/paper5.pdf'},
#  {'name': 'UMass Engineering Core Ontologies',
#   'url': 'https://www.mdpi.com/2079-8954/6/4/46/pdf'},
#  {'name': 'Vaccination Informed Consent Ontology (VICO)',
#   'url': 'http://jbiomedsem.biomedcentral.com/articles/10.1186/s13326-016-0062-4'},
#  {'name': 'Volcanism Ontology (VO)',
#   'url': 'https://scholarworks.gsu.edu/cgi/viewcontent.cgi?article=1124&context=geosciences_theses'},
#  {'name': 'Vaccine Ontology (VO)',
#   'url': 'http://obofoundry.org/ontology/vo.html'},
#  {'name': 'Visualized Emotion Ontology (VEO)',
#   'url': 'https://bmcmedinformdecismak.biomedcentral.com/articles/10.1186/s12911-018-0634-6'},
#  {'name': 'Vital Sign Ontology (VSO)',
#   'url': 'http://ontology.buffalo.edu/smith/articles/Vital_Sign_Ontology.pdf'},
#  {'name': 'VIVO Ontology',
#   'url': 'https://openreview.net/forum?id=SkgyVa-coV'},
#  {'name': 'Volcanism Ontology (VO)',
#   'url': 'https://scholarworks.gsu.edu/cgi/viewcontent.cgi?article=1124&context=geosciences_theses'},
#  {'name': 'Xenopus Anatomy Ontology (XAO)',
#   'url': 'http://obofoundry.org/ontology/xao.html'},
#  {'name': 'yOWL', 'url': 'http://www2007.org/workshops/paper_130.pdf'},
#  {'name': 'Air Force Research Laboratory, Rome, New York',
#   'url': 'http://www.wpafb.af.mil/afrl'},
#  {'name': 'Allotrope Foundation: Rethinking Scientific Data',
#   'url': 'https://www.allotrope.org/'},
#  {'name': 'AstraZeneca', 'url': 'http://www.astrazeneca.com/'},
#  {'name': 'Autodesk', 'url': 'https://www.autodesk.com/'},
#  {'name': 'Bentley Software, Inc.'},
#  {'name': 'Berkeley Bioinformatics Open-Source Projects (BBOP)',
#   'url': 'http://berkeleybop.org/'},
#  {'name': 'Biomedical Knowledge Engineering Lab at Seoul National University (SNU BiKE)',
#   'url': 'http://bike.snu.ac.kr/'},
#  {'name': 'Brain Operation Database (BODB)',
#   'url': 'http://neuroinformatics.usc.edu/resources/brain-operation-database-bodb'},
#  {'name': 'Center for e-Design', 'url': 'http://www.edesign.ecs.umass.edu/'},
#  {'name': 'CTSAconnect', 'url': 'http://www.ctsaconnect.org/'},
#  {'name': 'CUBRC',
#   'url': "http://www.cubrc.org/index.php/data-science-and-information-fusion/ontology/'94"},
#  {'name': 'Darwin Core (DwC)', 'url': 'http://rs.tdwg.org/dwc'},
#  {'name': 'DOQS', 'url': 'http://www.doqs.com/'},
#  {'name': 'DSpace at NTNUA',
#   'url': 'http://dspace.lib.ntua.gr/handle/123456789/3046'},
#  {'name': 'Dumontier Lab',
#   'url': 'http://dumontierlab.com/index.php?page=ontologies'},
#  {'name': 'eagle-i Research Resource Ontology',
#   'url': 'http://obofoundry.org/ontology/ero.html'},
#  {'name': 'Ecole polytechnique federale de Lausanne (EPFL)',
#   'url': 'https://people.epfl.ch/cgi-bin/people?id=105551&lang=en&cvlang=en'},
#  {'name': 'Elsevier Smart Content Strategy',
#   'url': 'http://www.elsevier.com/wps/find/authored_newsitem.cws_home/companynews05_01849'},
#  {'name': 'eNanoMapper', 'url': 'http://www.enanomapper.net/'},
#  {'name': 'EuPath Ontology',
#   'url': 'https://bioportal.bioontology.org/ontologies/EUPATH/?p=summary'},
#  {'name': 'Extensible Neuroimaging Archive Toolkit (XNAT)',
#   'url': 'http://www.aifb.kit.edu/images/e/e5/Sfb-infrastructure-spie2016.pdf'},
#  {'name': 'Good Ontology Design (GoodOD)',
#   'url': 'http://portal.uni-freiburg.de/imbi/sections/mi-en/projects/goodod?set_language=en'},
#  {'name': 'HIGHFLEET', 'url': 'http://www.highfleet.com/'},
#  {'name': 'Influenza Research Database (IRD)',
#   'url': 'http://www.fludb.org/brc/home.spg?decorator=influenza'},
#  {'name': 'Institute for Defense Analysis', 'url': 'http://www.ida.org/'},
#  {'name': 'INRIA Lorraine Research Unit',
#   'url': 'http://www.inria.fr/inria/organigramme/fiche_ur-lor.en.html'},
#  {'name': 'Japan Advanced Institute of Science and Technology (JAIST)',
#   'url': 'http://www.jaist.ac.jp/ks/english/'},
#  {'name': 'Johns Hopkins University Applied Physics Lab',
#   'url': 'http://www.jhuapl.edu/'},
#  {'name': 'Kobe University, Graduate School of Medicine, Department of Sociomedical Informatics',
#   'url': 'http://www.med.kobe-u.ac.jp/'},
#  {'name': 'L3 Data Tactics Corporation',
#   'url': 'https://www.data-tactics.com/'},
#  {'name': 'Language and Computing', 'url': 'http://www.landcglobal.com/'},
#  {'name': 'libryo', 'url': 'https://libryo.com/'},
#  {'name': 'Medical University Graz - Institute of Medical Informatics, Statistics and Documentation',
#   'url': 'http://user.medunigraz.at/stefan.schulz'},
#  {'name': 'National Center for Multi-Source Information Fusion',
#   'url': 'http://www.infofusion.buffalo.edu/'},
#  {'name': 'Ontology Research Group', 'url': 'http://org.buffalo.edu/'},
#  {'name': 'Ontology, Logic and Technology Unit',
#   'url': 'http://org.buffalo.edu/rarp/OLT%20Unit.html'},
#  {'name': 'Qualitative Spatiotemporal Reasoning Unit',
#   'url': 'http://org.buffalo.edu/rarp/QSRUnit%20Page.html'},
#  {'name': 'Referent Tracking Unit',
#   'url': 'http://org.buffalo.edu/RTU/index.html'},
#  {'name': 'SAIC', 'url': 'www.saic.com/'},
#  {'name': 'Thermo Fisher Scientific',
#   'url': 'https://www.thermofisher.com/us/en/home.html'},
#  {'name': 'TRADOC Operational Environment Center',
#   'url': 'www.tradoc.army.mil/g2/oetsc/videoTBOC_flv.aspx'},
#  {'name': 'OntoCAT', 'url': 'http://www.ontocat.org/'},
#  {'name': 'OntoCOG', 'url': 'http://ontobat.hegroup.org/'},
#  {'name': 'OntoMaton', 'url': 'http://isa-tools.org/'},
#  {'name': 'openEHR',
#   'url': 'http://www.openehr.org/wiki/display/ontol/Ontologies+Home'},
#  {'name': 'Open Access Journals Integrated service System Project (GoOA)',
#   'url': 'http://bioportal.bioontology.org/projects/PDOLAS'},
#  {'name': 'Open PHACTS', 'url': 'http://www.openphacts.org/'},
#  {'name': 'OSTHUS', 'url': 'https://www.youtube.com/watch?v=WKuK2G-NUk8'},
#  {'name': 'Praxis',
#   'url': 'http://www.infor-med.com/downloads/articles_downloads/Praxis_EMR_SUNY_Interoperability_Project.pdf'},
#  {'name': 'REMINE',
#   'url': 'http://www.ramit.be/index.cfm?objectid=D06D28B6-1143-DEB7-74B2690FF1EC5110'},
#  {'name': 'Saitama University - Faculty of Liberal Arts',
#   'url': 'http://www.saitama-u.ac.jp/'},
#  {'name': 'Science Applications International Corporation (SAIC)',
#   'url': 'https://www.saic.com'},
#  {'name': 'Science Commons', 'url': 'http://www.sciencecommons.org/'},
#  {'name': 'Securboration', 'url': 'http://www.securboration.com/'},
#  {'name': 'Skeletome',
#   'url': 'http://itee.uq.edu.au/~eresearch/projects/skeletome'},
#  {'name': 'SMART Protocols',
#   'url': 'http://www.swat4ls.org/wp-content/uploads/2015/10/SWAT4LS_2015_paper_15.pdf'},
#  {'name': 'U.S. Geological Survey (USGS) - Center of Excellence for Geospatial Information Science (CEGIS)',
#   'url': 'http://cegis.usgs.gov/ontology.html'},
#  {'name': 'University of Arkansas, Biomedical Informatics, Medical Center, Little Rock',
#   'url': 'http://www.uams.edu/cctr/infocore/infocore.asp'},
#  {'name': 'University of Augsburg - Computer Science - Software Methodologies for Distributed Systems',
#   'url': 'http://www.informatik.uni-augsburg.de/en/chairs/swt/ds'},
#  {'name': 'University of South Alabama - School of Computing - South Biomedical Informatics (SBI) Research Group',
#   'url': 'http://biomedical.cis.usouthal.edu/'},
#  {'name': 'University of Texas Southwestern Medical Center',
#   'url': 'http://www.utsouthwestern.edu/'},
#  {'name': 'University of Washington - Structural Informatics Group (SIG)',
#   'url': 'http://sig.biostr.washington.edu/'},
#  {'name': 'Virus Pathogen Resource (ViPR)',
#   'url': 'http://www.viprbrc.org/brc/home.do?decorator=vipr'},
#  {'name': 'VIVO', 'url': 'http://vivoweb.org/'},
#  {'name': 'Volley: AI-powered learning hub', 'url': 'http://volley.com/'},
#  {'name': 'Semantic Systems Engineering Ontology (SESO)',
#   'url': 'https://indico.esa.int/event/386/contributions/6243/attachments/4281/6391/1435%20-%20using%20semantic%20systems%20engineering%20techniques%20to%20verify%20the%20large%20aperture%20space%20telescope%20mission%20%E2%80%93%20current%20status.pdf'},
#  {'name': 'Rescue Ontology (ResOnt)',
#   'url': 'https://www.researchgate.net/profile/Samer-Chehade-2/publication/353571839'},
#  {'name': 'CybOnto (Cognitive Digital Twin Ontology for CyberSecurity)',
#   'url': 'https://arxiv.org/pdf/2108.00551.pdf'},
#  {'name': 'GeoCore Geology Ontology',
#   'url': 'https://www.lume.ufrgs.br/bitstream/handle/10183/225741/001129935.pdf'},
#  {'name': 'Data Use Ontology (DUO)',
#   'url': 'http://www.obofoundry.org/ontology/duo.html'},
#  {'name': 'Graphs, Objects, Points, Properties, Roles, and Relationships Ontology (GOPPRRE)',
#   'url': 'https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=9534721'},
#  {'name': 'RFID System Configuration Ontology (RFID SCO)',
#   'url': 'https://doi.org/10.1017/S0269888921000096'},
#  {'name': 'CICCONETO et al., 2020; CICCONETO, 2021) spatial relations ontology'},
#  {'name': 'Ocular Immune-Mediated Inflammatory Diseases Ontology (OcIMIDo)',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S001048252100336X'},
#  {'name': 'GeoReservoir Ontology',
#   'url': 'https://doi.org/10.1016/j.cageo.2021.105005'},
#  {'name': 'Spatial Relation Ontology',
#   'url': 'http://ceur-ws.org/Vol-2728/paper3.pdf'},
#  {'name': 'Value Stream Mapping (VSM) Ontology',
#   'url': 'https://era.library.ualberta.ca/items/5ad997be-0f3d-4456-8108-b3c69d851a98/view/060e801a-92a5-44ac-ba8a-0a00ab22765e/Abdelghani_Mohammad_202101_PhD.pdf'},
#  {'name': 'Addiction Ontology (AO)',
#   'url': 'https://www.taylorfrancis.com/chapters/edit/10.4324/9781003032762-46/addiction-ontology-unify-competing-conceptualizations-addiction-robert-kelly-janna-hastings-robert-west'},
#  {'name': 'Agronomy Ontology (AGRO)',
#   'url': 'https://bigdata.cgiar.org/resources/agronomy-ontology/'},
#  {'name': 'Anatomy of the Insect Skeleto-Muscular system ontology (AISM)',
#   'url': 'https://www.preprints.org/manuscript/202201.0254/v1'},
#  {'name': 'ARIES (Arkansas Imaging Enterprise System) Knowledge Graph',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8866818/'},
#  {'name': 'Asset Management Ontology (AMODO)',
#   'url': 'https://www.sciencedirect.com/science/article/abs/pii/S2452414X21000947'},
#  {'name': 'Biomedical Study - Lifecycle Management (BMS-LM) core ontology',
#   'url': 'https://doi.org/10.1016/j.jbi.2022.104007'},
#  {'name': 'Case Based Reasoning (CBR) Ontology',
#   'url': 'https://doi.org/10.1109/ISSE51541.2021.9582535'},
#  {'name': 'CIDO-COVID-19',
#   'url': 'https://ieeexplore.ieee.org/abstract/document/9629555'},
#  {'name': 'Collaborative Learning Healthcare Systems (CLHS) ontology',
#   'url': 'https://onlinelibrary.wiley.com/doi/full/10.1002/lrh2.10306'},
#  {'name': 'The Common Rule Ontology (CRO)',
#   'url': 'https://github.com/CRO-ontology/CRO'},
#  {'name': 'Crop Planning and Production Process Ontology (C3PO)',
#   'url': 'http://ceur-ws.org/Vol-2969/paper12-IFOW.pdf'},
#  {'name': 'Cybonto Cyber Security Ontology',
#   'url': 'https://arxiv.org/abs/2108.00551'},
#  {'name': 'Dairy Cattle Performance Ontology (DCPO)',
#   'url': 'http://ceur-ws.org/Vol-3073/paper3.pdf'},
#  {'name': 'Data Integration Aggregated Model for Nuclear Deployment (DIAMOND)',
#   'url': 'https://link.springer.com/chapter/10.1007/978-3-030-82083-1_2'},
#  {'name': 'EifcOWL (Enhanced Ontology for the Construction Industry Foundation Classes)',
#   'url': 'https://content.iospress.com/articles/applied-ontology/ao210254'},
#  {'name': 'ENVOn (3D shape ontology)',
#   'url': 'http://www.semantic-web-journal.net/system/files/swj3043.pdf'},
#  {'name': 'Epilepsy Ontology (EPIO)',
#   'url': 'https://www.researchsquare.com/article/rs-1259791/v1'},
#  {'name': 'Financial Documents Ontology (FIN)',
#   'url': 'http://ceur-ws.org/Vol-2969/paper57-SoLEE.pdf'},
#  {'name': 'Food Recipe Ingredient Substitution Ontology (FRISO)',
#   'url': 'https://doi.org/10.3390/s22031095'},
#  {'name': 'GeoReservoir ontology for deep-marine depositional system geometry',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S0098300421002880'},
#  {'name': 'HERMES 4D Printing Ontology',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S0264127521007486'},
#  {'name': 'Interoperative Neuromonitoring Ontology (IOM)',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/35062118/'},
#  {'name': 'Maintenance Activity Reference Ontology',
#   'url': 'http://www.semantic-web-journal.net/system/files/swj3067.pdf'},
#  {'name': 'MOCA (Multi-attribute Ontology-based Criticality Analysis)',
#   'url': 'https://link.springer.com/article/10.1007/s43684-022-00021-7'},
#  {'name': 'Model for Describing Insect Anatomical Structures (MoDIAS)',
#   'url': 'https://www.preprints.org/manuscript/202201.0254/v1'},
#  {'name': 'Ontology for Nutritional Epidemiology (ONE)',
#   'url': 'https://obofoundry.org/ontology/one.html'},
#  {'name': 'Ontology of Hemotherapy (HEMONTO)',
#   'url': 'https://1library.net/document/q5946wgz-hemocomponents-hemoderivatives-ontology-hemonto-ontology-blood-components.html'},
#  {'name': 'Ontology of Commercial Exchange (OCE)',
#   'url': 'https://philarchive.org/archive/MERCCC'},
#  {'name': 'Open Model-Based Engineering Environment (OpenMBEE)',
#   'url': 'https://link.springer.com/chapter/10.1007/978-3-030-82083-1_56'},
#  {'name': 'Organization Ontology Based on ROR',
#   'url': 'https://figshare.com/articles/presentation/An_Organization_Ontology_based_on_ROR/14839359'},
#  {'name': 'Semantic Reference Model for Individualization of Information Processes',
#   'url': 'https://www.mdpi.com/2079-9292/10/20/2523'},
#  {'name': 'Smart Ultrasound in Obstetrics and Gynecology (SUOG) Ontology',
#   'url': 'https://icbo2021.inf.unibz.it/wp-content/uploads/2021/09/169_S1_ElGhosh_paper_8.pdf'},
#  {'name': 'Space Domain Ontologies (SDO)',
#   'url': 'https://philpapers.org/rec/COXTSD-2'},
#  {'name': 'Space Object Ontology (SOO)',
#   'url': 'https://ieeexplore.ieee.org/document/7527882'},
#  {'name': 'Supply Chain Traceability Ontology',
#   'url': 'https://asmedigitalcollection.asme.org/computingengineering/article-abstract/22/5/051002/1139465/Enabling-Traceability-in-Agri-Food-Supply-Chains'},
#  {'name': 'Traditional Chinese Drugs Ontology (TCDO)',
#   'url': 'https://www.hindawi.com/journals/ecam/2021/6637810/'},
#  {'name': 'Xenopus Phenotype Ontology (XPO)',
#   'url': 'https://www.biorxiv.org/content/biorxiv/early/2021/11/13/2021.11.12.467727.full.pdf'},
#  {'name': 'ZEMELA Intelligent Agriculture Platform',
#   'url': 'https://ieeexplore.ieee.org/abstract/document/9627248'},
#  {'name': 'Iranian Traditional Medicine General Ontology (IrGO)',
#   'url': 'https://jbiomedsem.biomedcentral.com/articles/10.1186/s13326-021-00237-1'},
#  {'name': "Alzheimer's Disease Diagnosis Ontology (ADDO)",
#   'url': 'https://ma.x-mol.com/paper/1366901247607140352'}]
