# %%
import pandas as pd

# %%
df = pd.read_csv("users.csv")

# %%
df
# Out:
#                                                   name description  \
# 0                       ACGT Master Ontology (ACGT MO)         NaN
# 1                Additive Manufacturing Ontology (AMO)         NaN
# 2                 Adolescent Depression Ontology (ADO)         NaN
# 3                      African Wildlife Ontology (AWO)         NaN
# 4                       Agronomic Linked Data (AgroLD)         NaN
# ..                                                 ...         ...
# 451          Traditional Chinese Drugs Ontology (TCDO)         NaN
# 452                   Xenopus Phenotype Ontology (XPO)         NaN
# 453            ZEMELA Intelligent Agriculture Platform         NaN
# 454  Iranian Traditional Medicine General Ontology ...         NaN
# 455      Alzheimer's Disease Diagnosis Ontology (ADDO)         NaN
#
#      underneath                                                url
# 0    Ontologies  http://bioportal.bioontology.org/ontologies/AC...
# ...

# %%
df = df.drop(columns = ["description", "underneath"])

# %%
df = df.sort_values('name')

# %%
url_list = df['url'].tolist()

# %%
url_list
# Out:
# ['http://www.ncbi.nlm.nih.gov/pmc/articles/PMC4255744',
#  'http://www.phyloviz.net/typon',
#  'http://bioportal.bioontology.org/ontologies/ACGT-MO',
#  'http://esw.w3.org/topic/HCLS/AFO_Foundational_Ontology',
#  'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8866818/',
#  'http://ncor.buffalo.edu/ontologies/AIRS_Ontologies.pdf',
#  'https://www.taylorfrancis.com/chapters/edit/10.4324/9781003032762-46/addiction-ontology-unify-competing-conceptualizations-addiction-robert-kelly-janna-hastings-robert-west',
#  'https://www.sciencedirect.com/science/article/pii/S0166361518301647',
#  'https://www.jmir.org/article/viewFile/jmir_v19i7e259/2',
#  'http://purl.obolibrary.org/obo/aero',
#  'https://arxiv.org/pdf/1905.09519.pdf',
#  'https://www.biorxiv.org/content/10.1101/325423v3.full.pdf',
#  'https://bigdata.cgiar.org/resources/agronomy-ontology/',
#  'http://www.wpafb.af.mil/afrl',
#  'http://ontologydesignpatterns.org/wiki/images/4/41/WOP2016_paper_07.pdf',
# ...

# %%
url_hyperlink = []

for url in url_list: 
    url = f'<a href="{str(url).strip()}">{url}</a>'
    url_hyperlink.append(url)

# %%
url_hyperlink
# Out:
# ['<a href="http://www.ncbi.nlm.nih.gov/pmc/articles/PMC4255744">http://www.ncbi.nlm.nih.gov/pmc/articles/PMC4255744</a>',
#  '<a href="http://www.phyloviz.net/typon">http://www.phyloviz.net/typon</a>',
#  '<a href="http://bioportal.bioontology.org/ontologies/ACGT-MO">http://bioportal.bioontology.org/ontologies/ACGT-MO</a>',
#  '<a href="http://esw.w3.org/topic/HCLS/AFO_Foundational_Ontology">http://esw.w3.org/topic/HCLS/AFO_Foundational_Ontology</a>',
#  '<a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8866818/">https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8866818/</a>',
#  '<a href="http://ncor.buffalo.edu/ontologies/AIRS_Ontologies.pdf">http://ncor.buffalo.edu/ontologies/AIRS_Ontologies.pdf</a>',
# ...

# %%
df = df.drop(columns = ["url"])

# %%
url_hyperlink
# Out:
# ['<a href="http://www.ncbi.nlm.nih.gov/pmc/articles/PMC4255744">http://www.ncbi.nlm.nih.gov/pmc/articles/PMC4255744</a>',
#  '<a href="http://www.phyloviz.net/typon">http://www.phyloviz.net/typon</a>',
#  '<a href="http://bioportal.bioontology.org/ontologies/ACGT-MO">http://bioportal.bioontology.org/ontologies/ACGT-MO</a>',
#  '<a href="http://esw.w3.org/topic/HCLS/AFO_Foundational_Ontology">http://esw.w3.org/topic/HCLS/AFO_Foundational_Ontology</a>',
#  '<a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8866818/">https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8866818/</a>',
#  '<a href="http://ncor.buffalo.edu/ontologies/AIRS_Ontologies.pdf">http://ncor.buffalo.edu/ontologies/AIRS_Ontologies.pdf</a>',
# ...

# %%
df["url"] = url_hyperlink

# %%
df
# Out:
#                                                   name  \
# 97   (EXperimental ACTions) Biomedical Protocol Ont...
# 325                (Microbial) Typing Ontology (TypOn)
# 0                       ACGT Master Ontology (ACGT MO)
# 10                           AFO Foundational Ontology
# 419  ARIES (Arkansas Imaging Enterprise System) Kno...
# ..                                                 ...
# 139                     uc_FoodDrugInteractionOntology
# 140                                            uc_Milk
# 141                                      uc_Processing
# 142                                           uc_Sense
# 338                                               yOWL
#
#                                                    url
# 97   <a href="http://www.ncbi.nlm.nih.gov/pmc/artic...
# 325  <a href="http://www.phyloviz.net/typon">http:/...
# 0    <a href="http://bioportal.bioontology.org/onto...
# 10   <a href="http://esw.w3.org/topic/HCLS/AFO_Foun...
# ...

# %%
df.to_csv("users_cleaned.csv", index = False)

# %%
html_string = df.to_html(index = False)

# %%
print(html_string)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>(EXperimental ACTions) Biomedical Protocol Ontology (EXACT2)</td>
#       <td>&lt;a href="http://www.ncbi.nlm.nih.gov/pmc/articles/PMC4255744"&gt;http://www.ncbi.nlm.nih.gov/pmc/articles/PMC4255744&lt;/a&gt;</td>
#     </tr>
#     <tr>
#       <td>(Microbial) Typing Ontology (TypOn)</td>
#       <td>&lt;a href="http://www.phyloviz.net/typon"&gt;http://www.phyloviz.net/typon&lt;/a&gt;</td>
#     </tr>
#     <tr>
#       <td>ACGT Master Ontology (ACGT MO)</td>
#       <td>&lt;a href="http://bioportal.bioontology.org/ontologies/ACGT-MO"&gt;http://bioportal.bioontology.org/ontologies/ACGT-MO&lt;/a&gt;</td>
#     </tr>
#     <tr>
#       <td>AFO Foundational Ontology</td>
# ...
